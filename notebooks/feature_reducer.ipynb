# %%
import pandas as pd

# %%
# read list of values from features.csv
features = pd.read_csv('../features.csv', header=None)
feature_list = features.values.tolist()
unique_features = features[0].unique().tolist()
print('Number of features: ', len(feature_list))
print('Number of unique features: ', len(unique_features))
# Out:
# Number of features:  4110
# Number of unique features:  4110

# %%
def get_str_prfx(s, pct):
    if len(s) > 1:
        index = int(len(s)*pct)
        return s[:index]
    else:
        return s

# %%
# group features that have 75% or more similarity
feature_groups = {}
threshold = 0.9
frst_str = get_str_prfx(unique_features[0], threshold)

for feat in unique_features:
    prfx = get_str_prfx(feat, threshold)
    if prfx in feature_groups:
        print('Adding feature: ', feat, ' to group: ', prfx)
        feature_groups[prfx].append(feat)
    else:
        print('Creating new group: ', prfx, ' with feature: ', feat)
        feature_groups[prfx] = [feat]

print('Number of feature groups: ', len(feature_groups))
# Out:
# Creating new group:  0  with feature:  0
# Creating new group:  breaker_coun  with feature:  breaker_counts
# Creating new group:  fuse_coun  with feature:  fuse_counts
# Creating new group:  switch_coun  with feature:  switch_counts
# Creating new group:  transformer_coun  with feature:  transformer_counts
# Creating new group:  recloser_coun  with feature:  recloser_counts
# Creating new group:  pole_coun  with feature:  pole_counts
# Creating new group:  poly_ewk  with feature:  poly_ewkt
# Creating new group:  point_ewk  with feature:  point_ewkt
# Creating new group:  grid_i  with feature:  grid_id
# Creating new group:  outage_cou  with feature:  outage_count
# Creating new group:  SimStartDa  with feature:  SimStartDate
# Creating new group:  outage_start_ti  with feature:  outage_start_time
# Creating new group:  outage_end_ti  with feature:  outage_end_time
# Creating new group:  weather_start_ti  with feature:  weather_start_time
# Creating new group:  weather_end_ti  with feature:  weather_end_time
# Creating new group:  event_typ  with feature:  event_type
# Creating new group:  x  with feature:  x
# Creating new group:  y  with feature:  y
# Creating new group:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m_  with feature:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m_cogt_5
# Adding feature:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m_cogt_9  to group:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m_
# Creating new group:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m_c  with feature:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m_cogt_13
# Adding feature:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m_cogt_18  to group:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m_c
# Creating new group:  10 metre wind speed_m s**-1 (max)_lambert_level 10   with feature:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m_gt_5
# Adding feature:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m_gt_9  to group:  10 metre wind speed_m s**-1 (max)_lambert_level 10
# Creating new group:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m  with feature:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m_gt_13
# Adding feature:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m_gt_18  to group:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m
# Creating new group:  Wind speed (gust)_m s**-1 (max)_lambert_level 10 m  with feature:  Wind speed (gust)_m s**-1 (max)_lambert_level 10 m_gt_13
# Adding feature:  Wind speed (gust)_m s**-1 (max)_lambert_level 10 m_gt_17  to group:  Wind speed (gust)_m s**-1 (max)_lambert_level 10 m
# Adding feature:  Wind speed (gust)_m s**-1 (max)_lambert_level 10 m_gt_22  to group:  Wind speed (gust)_m s**-1 (max)_lambert_level 10 m
# Adding feature:  Wind speed (gust)_m s**-1 (max)_lambert_level 10 m_gt_27  to group:  Wind speed (gust)_m s**-1 (max)_lambert_level 10 m
# Adding feature:  Wind speed (gust)_m s**-1 (max)_lambert_level 10 m_gt_35  to group:  Wind speed (gust)_m s**-1 (max)_lambert_level 10 m
# Adding feature:  Wind speed (gust)_m s**-1 (max)_lambert_level 10 m_gt_44  to group:  Wind speed (gust)_m s**-1 (max)_lambert_level 10 m
# Creating new group:  221_221 (min)_lambert_levels 0-40000-filtered_2-me  with feature:  221_221 (min)_lambert_levels 0-40000-filtered_2-mean_sum
# Creating new group:  221_221 (min)_lambert_levels 0-40000-filtered_2-mea  with feature:  221_221 (min)_lambert_levels 0-40000-filtered_2-mean_mean
# Adding feature:  221_221 (min)_lambert_levels 0-40000-filtered_2-mean_max  to group:  221_221 (min)_lambert_levels 0-40000-filtered_2-me
# Adding feature:  221_221 (min)_lambert_levels 0-40000-filtered_2-mean_min  to group:  221_221 (min)_lambert_levels 0-40000-filtered_2-me
# Adding feature:  221_221 (min)_lambert_levels 0-40000-filtered_2-mean_var  to group:  221_221 (min)_lambert_levels 0-40000-filtered_2-me
# Creating new group:  HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-mi  with feature:  HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-min_sum
# Creating new group:  HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-min  with feature:  HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-min_mean
# Adding feature:  HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-min_max  to group:  HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-mi
# Adding feature:  HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-min_min  to group:  HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-mi
# Adding feature:  HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-min_var  to group:  HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-mi
# Creating new group:  AIR_DENSITY kg/m3-filtered_2-mean  with feature:  AIR_DENSITY kg/m3-filtered_2-mean_sum
# Creating new group:  AIR_DENSITY kg/m3-filtered_2-mean_  with feature:  AIR_DENSITY kg/m3-filtered_2-mean_mean
# Adding feature:  AIR_DENSITY kg/m3-filtered_2-mean_max  to group:  AIR_DENSITY kg/m3-filtered_2-mean
# Adding feature:  AIR_DENSITY kg/m3-filtered_2-mean_min  to group:  AIR_DENSITY kg/m3-filtered_2-mean
# Adding feature:  AIR_DENSITY kg/m3-filtered_2-mean_var  to group:  AIR_DENSITY kg/m3-filtered_2-mean
# Creating new group:  Snow depth_m (instant)_lambert_level 0-filtered_8-m  with feature:  Snow depth_m (instant)_lambert_level 0-filtered_8-max_sum
# Creating new group:  Snow depth_m (instant)_lambert_level 0-filtered_8-ma  with feature:  Snow depth_m (instant)_lambert_level 0-filtered_8-max_mean
# Adding feature:  Snow depth_m (instant)_lambert_level 0-filtered_8-max_max  to group:  Snow depth_m (instant)_lambert_level 0-filtered_8-m
# Adding feature:  Snow depth_m (instant)_lambert_level 0-filtered_8-max_min  to group:  Snow depth_m (instant)_lambert_level 0-filtered_8-m
# Adding feature:  Snow depth_m (instant)_lambert_level 0-filtered_8-max_var  to group:  Snow depth_m (instant)_lambert_level 0-filtered_8-m
# Creating new group:  4_4 (max)_lambert_level 0-filtered_2-mea  with feature:  4_4 (max)_lambert_level 0-filtered_2-mean_sum
# Creating new group:  4_4 (max)_lambert_level 0-filtered_2-mean  with feature:  4_4 (max)_lambert_level 0-filtered_2-mean_mean
# Adding feature:  4_4 (max)_lambert_level 0-filtered_2-mean_max  to group:  4_4 (max)_lambert_level 0-filtered_2-mea
# Adding feature:  4_4 (max)_lambert_level 0-filtered_2-mean_min  to group:  4_4 (max)_lambert_level 0-filtered_2-mea
# Adding feature:  4_4 (max)_lambert_level 0-filtered_2-mean_var  to group:  4_4 (max)_lambert_level 0-filtered_2-mea
# Creating new group:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_16-m  with feature:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_16-mean_sum
# Creating new group:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_16-me  with feature:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_16-mean_mean
# Adding feature:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_16-mean_max  to group:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_16-m
# Adding feature:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_16-mean_min  to group:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_16-m
# Adding feature:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_16-mean_var  to group:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_16-m
# Creating new group:  Snow depth_m (instant)_lambert_level 0-filtered_8-me  with feature:  Snow depth_m (instant)_lambert_level 0-filtered_8-mean_sum
# Creating new group:  Snow depth_m (instant)_lambert_level 0-filtered_8-mea  with feature:  Snow depth_m (instant)_lambert_level 0-filtered_8-mean_mean
# Adding feature:  Snow depth_m (instant)_lambert_level 0-filtered_8-mean_max  to group:  Snow depth_m (instant)_lambert_level 0-filtered_8-me
# Adding feature:  Snow depth_m (instant)_lambert_level 0-filtered_8-mean_min  to group:  Snow depth_m (instant)_lambert_level 0-filtered_8-me
# Adding feature:  Snow depth_m (instant)_lambert_level 0-filtered_8-mean_var  to group:  Snow depth_m (instant)_lambert_level 0-filtered_8-me
# Creating new group:  Total cloud cover_% (instant)_lambert_level 0-filtered_16-m  with feature:  Total cloud cover_% (instant)_lambert_level 0-filtered_16-mean_sum
# Creating new group:  Total cloud cover_% (instant)_lambert_level 0-filtered_16-me  with feature:  Total cloud cover_% (instant)_lambert_level 0-filtered_16-mean_mean
# Adding feature:  Total cloud cover_% (instant)_lambert_level 0-filtered_16-mean_max  to group:  Total cloud cover_% (instant)_lambert_level 0-filtered_16-m
# Adding feature:  Total cloud cover_% (instant)_lambert_level 0-filtered_16-mean_min  to group:  Total cloud cover_% (instant)_lambert_level 0-filtered_16-m
# Adding feature:  Total cloud cover_% (instant)_lambert_level 0-filtered_16-mean_var  to group:  Total cloud cover_% (instant)_lambert_level 0-filtered_16-m
# Creating new group:  2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_2  with feature:  2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_2-max_sum
# Creating new group:  2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_2-  with feature:  2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_2-max_mean
# Adding feature:  2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_2-max_max  to group:  2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_2
# Adding feature:  2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_2-max_min  to group:  2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_2
# Adding feature:  2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_2-max_var  to group:  2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_2
# Creating new group:  Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_8-m  with feature:  Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_8-mean_sum
# Adding feature:  Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_8-mean_mean  to group:  Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_8-m
# Adding feature:  Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_8-mean_max  to group:  Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_8-m
# Adding feature:  Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_8-mean_min  to group:  Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_8-m
# Adding feature:  Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_8-mean_var  to group:  Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_8-m
# Creating new group:  Total cloud cover_% (instant)_lambert_level 0-filtered_32-  with feature:  Total cloud cover_% (instant)_lambert_level 0-filtered_32-min_sum
# Creating new group:  Total cloud cover_% (instant)_lambert_level 0-filtered_32-m  with feature:  Total cloud cover_% (instant)_lambert_level 0-filtered_32-min_mean
# Adding feature:  Total cloud cover_% (instant)_lambert_level 0-filtered_32-min_max  to group:  Total cloud cover_% (instant)_lambert_level 0-filtered_32-
# Adding feature:  Total cloud cover_% (instant)_lambert_level 0-filtered_32-min_min  to group:  Total cloud cover_% (instant)_lambert_level 0-filtered_32-
# Adding feature:  Total cloud cover_% (instant)_lambert_level 0-filtered_32-min_var  to group:  Total cloud cover_% (instant)_lambert_level 0-filtered_32-
# Creating new group:  0_0 (instant)_lambert_level 0-filtered_16-ma  with feature:  0_0 (instant)_lambert_level 0-filtered_16-max_sum
# Creating new group:  0_0 (instant)_lambert_level 0-filtered_16-max  with feature:  0_0 (instant)_lambert_level 0-filtered_16-max_mean
# Adding feature:  0_0 (instant)_lambert_level 0-filtered_16-max_max  to group:  0_0 (instant)_lambert_level 0-filtered_16-ma
# Adding feature:  0_0 (instant)_lambert_level 0-filtered_16-max_min  to group:  0_0 (instant)_lambert_level 0-filtered_16-ma
# Adding feature:  0_0 (instant)_lambert_level 0-filtered_16-max_var  to group:  0_0 (instant)_lambert_level 0-filtered_16-ma
# Creating new group:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_2  with feature:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_24-min_sum
# Creating new group:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_24  with feature:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_24-min_mean
# Adding feature:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_24-min_max  to group:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_2
# Adding feature:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_24-min_min  to group:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_2
# Adding feature:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_24-min_var  to group:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_2
# Creating new group:  HOURLY_SNOW_ACCUM_RATE m/h-filtered_16-ma  with feature:  HOURLY_SNOW_ACCUM_RATE m/h-filtered_16-max_sum
# Creating new group:  HOURLY_SNOW_ACCUM_RATE m/h-filtered_16-max  with feature:  HOURLY_SNOW_ACCUM_RATE m/h-filtered_16-max_mean
# Adding feature:  HOURLY_SNOW_ACCUM_RATE m/h-filtered_16-max_max  to group:  HOURLY_SNOW_ACCUM_RATE m/h-filtered_16-ma
# Adding feature:  HOURLY_SNOW_ACCUM_RATE m/h-filtered_16-max_min  to group:  HOURLY_SNOW_ACCUM_RATE m/h-filtered_16-ma
# Adding feature:  HOURLY_SNOW_ACCUM_RATE m/h-filtered_16-max_var  to group:  HOURLY_SNOW_ACCUM_RATE m/h-filtered_16-ma
# Creating new group:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/  with feature:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h_sum
# Adding feature:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h_mean  to group:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/
# Adding feature:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h_max  to group:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/
# Adding feature:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h_min  to group:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/
# Adding feature:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h_var  to group:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/
# Creating new group:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filte  with feature:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filtered_8-mean_sum
# Creating new group:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filter  with feature:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filtered_8-mean_mean
# Adding feature:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filtered_8-mean_max  to group:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filte
# Adding feature:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filtered_8-mean_min  to group:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filte
# Adding feature:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filtered_8-mean_var  to group:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filte
# Creating new group:  Water equivalent of accumulated snow depth_kg m**-2 (instant)_lambert_level 0-filtered_  with feature:  Water equivalent of accumulated snow depth_kg m**-2 (instant)_lambert_level 0-filtered_8-mean_sum
# Creating new group:  Water equivalent of accumulated snow depth_kg m**-2 (instant)_lambert_level 0-filtered_8  with feature:  Water equivalent of accumulated snow depth_kg m**-2 (instant)_lambert_level 0-filtered_8-mean_mean
# Adding feature:  Water equivalent of accumulated snow depth_kg m**-2 (instant)_lambert_level 0-filtered_8-mean_max  to group:  Water equivalent of accumulated snow depth_kg m**-2 (instant)_lambert_level 0-filtered_
# Adding feature:  Water equivalent of accumulated snow depth_kg m**-2 (instant)_lambert_level 0-filtered_8-mean_min  to group:  Water equivalent of accumulated snow depth_kg m**-2 (instant)_lambert_level 0-filtered_
# Adding feature:  Water equivalent of accumulated snow depth_kg m**-2 (instant)_lambert_level 0-filtered_8-mean_var  to group:  Water equivalent of accumulated snow depth_kg m**-2 (instant)_lambert_level 0-filtered_
# Creating new group:  AIR_DENSITY kg/m3-filtered_32-max  with feature:  AIR_DENSITY kg/m3-filtered_32-max_sum
# Creating new group:  AIR_DENSITY kg/m3-filtered_32-max_  with feature:  AIR_DENSITY kg/m3-filtered_32-max_mean
# Adding feature:  AIR_DENSITY kg/m3-filtered_32-max_max  to group:  AIR_DENSITY kg/m3-filtered_32-max
# Adding feature:  AIR_DENSITY kg/m3-filtered_32-max_min  to group:  AIR_DENSITY kg/m3-filtered_32-max
# Adding feature:  AIR_DENSITY kg/m3-filtered_32-max_var  to group:  AIR_DENSITY kg/m3-filtered_32-max
# Creating new group:  220_220 (max)_lambert_levels 0-40000-filtered_16-m  with feature:  220_220 (max)_lambert_levels 0-40000-filtered_16-max_sum
# Creating new group:  220_220 (max)_lambert_levels 0-40000-filtered_16-ma  with feature:  220_220 (max)_lambert_levels 0-40000-filtered_16-max_mean
# Adding feature:  220_220 (max)_lambert_levels 0-40000-filtered_16-max_max  to group:  220_220 (max)_lambert_levels 0-40000-filtered_16-m
# Adding feature:  220_220 (max)_lambert_levels 0-40000-filtered_16-max_min  to group:  220_220 (max)_lambert_levels 0-40000-filtered_16-m
# Adding feature:  220_220 (max)_lambert_levels 0-40000-filtered_16-max_var  to group:  220_220 (max)_lambert_levels 0-40000-filtered_16-m
# Creating new group:  AIR_DENSITY kg/m3-filtered_8-max  with feature:  AIR_DENSITY kg/m3-filtered_8-max_sum
# Creating new group:  AIR_DENSITY kg/m3-filtered_8-max_  with feature:  AIR_DENSITY kg/m3-filtered_8-max_mean
# Adding feature:  AIR_DENSITY kg/m3-filtered_8-max_max  to group:  AIR_DENSITY kg/m3-filtered_8-max
# Adding feature:  AIR_DENSITY kg/m3-filtered_8-max_min  to group:  AIR_DENSITY kg/m3-filtered_8-max
# Adding feature:  AIR_DENSITY kg/m3-filtered_8-max_var  to group:  AIR_DENSITY kg/m3-filtered_8-max
# Creating new group:  HOURLY_SNOW_ACCUM_RATE m/h-filtered_8-mi  with feature:  HOURLY_SNOW_ACCUM_RATE m/h-filtered_8-min_sum
# Creating new group:  HOURLY_SNOW_ACCUM_RATE m/h-filtered_8-min  with feature:  HOURLY_SNOW_ACCUM_RATE m/h-filtered_8-min_mean
# Adding feature:  HOURLY_SNOW_ACCUM_RATE m/h-filtered_8-min_max  to group:  HOURLY_SNOW_ACCUM_RATE m/h-filtered_8-mi
# Adding feature:  HOURLY_SNOW_ACCUM_RATE m/h-filtered_8-min_min  to group:  HOURLY_SNOW_ACCUM_RATE m/h-filtered_8-mi
# Adding feature:  HOURLY_SNOW_ACCUM_RATE m/h-filtered_8-min_var  to group:  HOURLY_SNOW_ACCUM_RATE m/h-filtered_8-mi
# Creating new group:  AIR_DENSITY kg/m3_  with feature:  AIR_DENSITY kg/m3_sum
# Creating new group:  AIR_DENSITY kg/m3_m  with feature:  AIR_DENSITY kg/m3_mean
# Adding feature:  AIR_DENSITY kg/m3_max  to group:  AIR_DENSITY kg/m3_
# Adding feature:  AIR_DENSITY kg/m3_min  to group:  AIR_DENSITY kg/m3_
# Adding feature:  AIR_DENSITY kg/m3_var  to group:  AIR_DENSITY kg/m3_
# Creating new group:  0_0 (instant)_lambert_level 0-filtered_2-mi  with feature:  0_0 (instant)_lambert_level 0-filtered_2-min_sum
# Creating new group:  0_0 (instant)_lambert_level 0-filtered_2-min  with feature:  0_0 (instant)_lambert_level 0-filtered_2-min_mean
# Adding feature:  0_0 (instant)_lambert_level 0-filtered_2-min_max  to group:  0_0 (instant)_lambert_level 0-filtered_2-mi
# Adding feature:  0_0 (instant)_lambert_level 0-filtered_2-min_min  to group:  0_0 (instant)_lambert_level 0-filtered_2-mi
# Adding feature:  0_0 (instant)_lambert_level 0-filtered_2-min_var  to group:  0_0 (instant)_lambert_level 0-filtered_2-mi
# Creating new group:  GUST_FORCE N-filtered_32-max  with feature:  GUST_FORCE N-filtered_32-max_sum
# Creating new group:  GUST_FORCE N-filtered_32-max_  with feature:  GUST_FORCE N-filtered_32-max_mean
# Adding feature:  GUST_FORCE N-filtered_32-max_max  to group:  GUST_FORCE N-filtered_32-max
# Adding feature:  GUST_FORCE N-filtered_32-max_min  to group:  GUST_FORCE N-filtered_32-max
# Adding feature:  GUST_FORCE N-filtered_32-max_var  to group:  GUST_FORCE N-filtered_32-max
# Creating new group:  AIR_DENSITY kg/m3-filtered_2-min  with feature:  AIR_DENSITY kg/m3-filtered_2-min_sum
# Creating new group:  AIR_DENSITY kg/m3-filtered_2-min_  with feature:  AIR_DENSITY kg/m3-filtered_2-min_mean
# Adding feature:  AIR_DENSITY kg/m3-filtered_2-min_max  to group:  AIR_DENSITY kg/m3-filtered_2-min
# Adding feature:  AIR_DENSITY kg/m3-filtered_2-min_min  to group:  AIR_DENSITY kg/m3-filtered_2-min
# Adding feature:  AIR_DENSITY kg/m3-filtered_2-min_var  to group:  AIR_DENSITY kg/m3-filtered_2-min
# Creating new group:  10 metre U wind component_m s**-1 (instant)_lambert_level 10 m-filtered_  with feature:  10 metre U wind component_m s**-1 (instant)_lambert_level 10 m-filtered_2-max_sum
# Creating new group:  10 metre U wind component_m s**-1 (instant)_lambert_level 10 m-filtered_2  with feature:  10 metre U wind component_m s**-1 (instant)_lambert_level 10 m-filtered_2-max_mean
# Adding feature:  10 metre U wind component_m s**-1 (instant)_lambert_level 10 m-filtered_2-max_max  to group:  10 metre U wind component_m s**-1 (instant)_lambert_level 10 m-filtered_
# Adding feature:  10 metre U wind component_m s**-1 (instant)_lambert_level 10 m-filtered_2-max_min  to group:  10 metre U wind component_m s**-1 (instant)_lambert_level 10 m-filtered_
# Adding feature:  10 metre U wind component_m s**-1 (instant)_lambert_level 10 m-filtered_2-max_var  to group:  10 metre U wind component_m s**-1 (instant)_lambert_level 10 m-filtered_
# Creating new group:  10 metre V wind component_m s**-1 (instant)_lambert_level 10 m-filtered_4  with feature:  10 metre V wind component_m s**-1 (instant)_lambert_level 10 m-filtered_4-mean_sum
# Creating new group:  10 metre V wind component_m s**-1 (instant)_lambert_level 10 m-filtered_4-  with feature:  10 metre V wind component_m s**-1 (instant)_lambert_level 10 m-filtered_4-mean_mean
# Adding feature:  10 metre V wind component_m s**-1 (instant)_lambert_level 10 m-filtered_4-mean_max  to group:  10 metre V wind component_m s**-1 (instant)_lambert_level 10 m-filtered_4
# Adding feature:  10 metre V wind component_m s**-1 (instant)_lambert_level 10 m-filtered_4-mean_min  to group:  10 metre V wind component_m s**-1 (instant)_lambert_level 10 m-filtered_4
# Adding feature:  10 metre V wind component_m s**-1 (instant)_lambert_level 10 m-filtered_4-mean_var  to group:  10 metre V wind component_m s**-1 (instant)_lambert_level 10 m-filtered_4
# Creating new group:  Absolute vorticity_s**-1 (instant)_lambert_level 50000 Pa-filtered_8  with feature:  Absolute vorticity_s**-1 (instant)_lambert_level 50000 Pa-filtered_8-min_sum
# Creating new group:  Absolute vorticity_s**-1 (instant)_lambert_level 50000 Pa-filtered_8-  with feature:  Absolute vorticity_s**-1 (instant)_lambert_level 50000 Pa-filtered_8-min_mean
# Adding feature:  Absolute vorticity_s**-1 (instant)_lambert_level 50000 Pa-filtered_8-min_max  to group:  Absolute vorticity_s**-1 (instant)_lambert_level 50000 Pa-filtered_8
# Adding feature:  Absolute vorticity_s**-1 (instant)_lambert_level 50000 Pa-filtered_8-min_min  to group:  Absolute vorticity_s**-1 (instant)_lambert_level 50000 Pa-filtered_8
# Adding feature:  Absolute vorticity_s**-1 (instant)_lambert_level 50000 Pa-filtered_8-min_var  to group:  Absolute vorticity_s**-1 (instant)_lambert_level 50000 Pa-filtered_8
# Creating new group:  Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_1  with feature:  Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_16-max_sum
# Adding feature:  Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_16-max_mean  to group:  Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_1
# Adding feature:  Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_16-max_max  to group:  Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_1
# Adding feature:  Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_16-max_min  to group:  Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_1
# Adding feature:  Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_16-max_var  to group:  Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_1
# Creating new group:  Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_1  with feature:  Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_16-min_sum
# Creating new group:  Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_16  with feature:  Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_16-min_mean
# Adding feature:  Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_16-min_max  to group:  Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_1
# Adding feature:  Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_16-min_min  to group:  Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_1
# Adding feature:  Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_16-min_var  to group:  Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_1
# Creating new group:  GUST_FORCE N-filtered_16-max  with feature:  GUST_FORCE N-filtered_16-max_sum
# Creating new group:  GUST_FORCE N-filtered_16-max_  with feature:  GUST_FORCE N-filtered_16-max_mean
# Adding feature:  GUST_FORCE N-filtered_16-max_max  to group:  GUST_FORCE N-filtered_16-max
# Adding feature:  GUST_FORCE N-filtered_16-max_min  to group:  GUST_FORCE N-filtered_16-max
# Adding feature:  GUST_FORCE N-filtered_16-max_var  to group:  GUST_FORCE N-filtered_16-max
# Creating new group:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2  with feature:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max_sum
# Creating new group:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-  with feature:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max_mean
# Adding feature:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max_max  to group:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2
# Adding feature:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max_min  to group:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2
# Adding feature:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max_var  to group:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2
# Creating new group:  Hail_m (max)_lambert_level 0-filtered_24-mea  with feature:  Hail_m (max)_lambert_level 0-filtered_24-mean_sum
# Creating new group:  Hail_m (max)_lambert_level 0-filtered_24-mean  with feature:  Hail_m (max)_lambert_level 0-filtered_24-mean_mean
# Adding feature:  Hail_m (max)_lambert_level 0-filtered_24-mean_max  to group:  Hail_m (max)_lambert_level 0-filtered_24-mea
# Adding feature:  Hail_m (max)_lambert_level 0-filtered_24-mean_min  to group:  Hail_m (max)_lambert_level 0-filtered_24-mea
# Adding feature:  Hail_m (max)_lambert_level 0-filtered_24-mean_var  to group:  Hail_m (max)_lambert_level 0-filtered_24-mea
# Creating new group:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_32-  with feature:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_32-max_sum
# Creating new group:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_32-m  with feature:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_32-max_mean
# Adding feature:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_32-max_max  to group:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_32-
# Adding feature:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_32-max_min  to group:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_32-
# Adding feature:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_32-max_var  to group:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_32-
# Creating new group:  Snow depth_m (instant)_lambert_level 0-filtered_16-me  with feature:  Snow depth_m (instant)_lambert_level 0-filtered_16-mean_sum
# Creating new group:  Snow depth_m (instant)_lambert_level 0-filtered_16-mea  with feature:  Snow depth_m (instant)_lambert_level 0-filtered_16-mean_mean
# Adding feature:  Snow depth_m (instant)_lambert_level 0-filtered_16-mean_max  to group:  Snow depth_m (instant)_lambert_level 0-filtered_16-me
# Adding feature:  Snow depth_m (instant)_lambert_level 0-filtered_16-mean_min  to group:  Snow depth_m (instant)_lambert_level 0-filtered_16-me
# Adding feature:  Snow depth_m (instant)_lambert_level 0-filtered_16-mean_var  to group:  Snow depth_m (instant)_lambert_level 0-filtered_16-me
# Creating new group:  WIND_FORCE N-filtered_32-min  with feature:  WIND_FORCE N-filtered_32-min_sum
# Creating new group:  WIND_FORCE N-filtered_32-min_  with feature:  WIND_FORCE N-filtered_32-min_mean
# Adding feature:  WIND_FORCE N-filtered_32-min_max  to group:  WIND_FORCE N-filtered_32-min
# Adding feature:  WIND_FORCE N-filtered_32-min_min  to group:  WIND_FORCE N-filtered_32-min
# Adding feature:  WIND_FORCE N-filtered_32-min_var  to group:  WIND_FORCE N-filtered_32-min
# Creating new group:  221_221 (min)_lambert_levels 0-40000-filtered_32-me  with feature:  221_221 (min)_lambert_levels 0-40000-filtered_32-mean_sum
# Creating new group:  221_221 (min)_lambert_levels 0-40000-filtered_32-mea  with feature:  221_221 (min)_lambert_levels 0-40000-filtered_32-mean_mean
# Adding feature:  221_221 (min)_lambert_levels 0-40000-filtered_32-mean_max  to group:  221_221 (min)_lambert_levels 0-40000-filtered_32-me
# Adding feature:  221_221 (min)_lambert_levels 0-40000-filtered_32-mean_min  to group:  221_221 (min)_lambert_levels 0-40000-filtered_32-me
# Adding feature:  221_221 (min)_lambert_levels 0-40000-filtered_32-mean_var  to group:  221_221 (min)_lambert_levels 0-40000-filtered_32-me
# Creating new group:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_  with feature:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_2-max_sum
# Adding feature:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_2-max_mean  to group:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_2
# Adding feature:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_2-max_max  to group:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_
# Adding feature:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_2-max_min  to group:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_
# Adding feature:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_2-max_var  to group:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_
# Creating new group:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_32-  with feature:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_32-min_sum
# Creating new group:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_32-m  with feature:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_32-min_mean
# Adding feature:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_32-min_max  to group:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_32-
# Adding feature:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_32-min_min  to group:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_32-
# Adding feature:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_32-min_var  to group:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_32-
# Creating new group:  Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-  with feature:  Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max_sum
# Creating new group:  Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-m  with feature:  Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max_mean
# Adding feature:  Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max_max  to group:  Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-
# Adding feature:  Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max_min  to group:  Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-
# Adding feature:  Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max_var  to group:  Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-
# Creating new group:  Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_4-  with feature:  Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_4-min_sum
# Creating new group:  Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_4-m  with feature:  Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_4-min_mean
# Adding feature:  Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_4-min_max  to group:  Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_4-
# Adding feature:  Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_4-min_min  to group:  Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_4-
# Adding feature:  Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_4-min_var  to group:  Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_4-
# Creating new group:  4_4 (max)_lambert_level 0-filtered_16-ma  with feature:  4_4 (max)_lambert_level 0-filtered_16-max_sum
# Creating new group:  4_4 (max)_lambert_level 0-filtered_16-max  with feature:  4_4 (max)_lambert_level 0-filtered_16-max_mean
# Adding feature:  4_4 (max)_lambert_level 0-filtered_16-max_max  to group:  4_4 (max)_lambert_level 0-filtered_16-ma
# Adding feature:  4_4 (max)_lambert_level 0-filtered_16-max_min  to group:  4_4 (max)_lambert_level 0-filtered_16-ma
# Adding feature:  4_4 (max)_lambert_level 0-filtered_16-max_var  to group:  4_4 (max)_lambert_level 0-filtered_16-ma
# Creating new group:  Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_2  with feature:  Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_24-min_sum
# Adding feature:  Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_24-min_mean  to group:  Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_2
# Adding feature:  Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_24-min_max  to group:  Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_2
# Adding feature:  Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_24-min_min  to group:  Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_2
# Adding feature:  Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_24-min_var  to group:  Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_2
# Creating new group:  Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_3  with feature:  Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_32-min_sum
# Creating new group:  Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_32  with feature:  Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_32-min_mean
# Adding feature:  Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_32-min_max  to group:  Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_3
# Adding feature:  Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_32-min_min  to group:  Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_3
# Adding feature:  Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_32-min_var  to group:  Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_3
# Creating new group:  Total column integrated water vapour_kg m**-2 (instant)_lambert_level 0-filtered_  with feature:  Total column integrated water vapour_kg m**-2 (instant)_lambert_level 0-filtered_2-min_sum
# Adding feature:  Total column integrated water vapour_kg m**-2 (instant)_lambert_level 0-filtered_2-min_mean  to group:  Total column integrated water vapour_kg m**-2 (instant)_lambert_level 0-filtered_
# Adding feature:  Total column integrated water vapour_kg m**-2 (instant)_lambert_level 0-filtered_2-min_max  to group:  Total column integrated water vapour_kg m**-2 (instant)_lambert_level 0-filtered_
# Adding feature:  Total column integrated water vapour_kg m**-2 (instant)_lambert_level 0-filtered_2-min_min  to group:  Total column integrated water vapour_kg m**-2 (instant)_lambert_level 0-filtered_
# Adding feature:  Total column integrated water vapour_kg m**-2 (instant)_lambert_level 0-filtered_2-min_var  to group:  Total column integrated water vapour_kg m**-2 (instant)_lambert_level 0-filtered_
# Creating new group:  0_0 (instant)_lambert_level 0-filtered_24-ma  with feature:  0_0 (instant)_lambert_level 0-filtered_24-max_sum
# Creating new group:  0_0 (instant)_lambert_level 0-filtered_24-max  with feature:  0_0 (instant)_lambert_level 0-filtered_24-max_mean
# Adding feature:  0_0 (instant)_lambert_level 0-filtered_24-max_max  to group:  0_0 (instant)_lambert_level 0-filtered_24-ma
# Adding feature:  0_0 (instant)_lambert_level 0-filtered_24-max_min  to group:  0_0 (instant)_lambert_level 0-filtered_24-ma
# Adding feature:  0_0 (instant)_lambert_level 0-filtered_24-max_var  to group:  0_0 (instant)_lambert_level 0-filtered_24-ma
# Creating new group:  220_220 (max)_lambert_levels 0-40000-filtered_2-m  with feature:  220_220 (max)_lambert_levels 0-40000-filtered_2-min_sum
# Creating new group:  220_220 (max)_lambert_levels 0-40000-filtered_2-mi  with feature:  220_220 (max)_lambert_levels 0-40000-filtered_2-min_mean
# Adding feature:  220_220 (max)_lambert_levels 0-40000-filtered_2-min_max  to group:  220_220 (max)_lambert_levels 0-40000-filtered_2-m
# Adding feature:  220_220 (max)_lambert_levels 0-40000-filtered_2-min_min  to group:  220_220 (max)_lambert_levels 0-40000-filtered_2-m
# Adding feature:  220_220 (max)_lambert_levels 0-40000-filtered_2-min_var  to group:  220_220 (max)_lambert_levels 0-40000-filtered_2-m
# Adding feature:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filtered_16-mean_sum  to group:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filter
# Creating new group:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filtere  with feature:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filtered_16-mean_mean
# Adding feature:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filtered_16-mean_max  to group:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filter
# Adding feature:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filtered_16-mean_min  to group:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filter
# Adding feature:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filtered_16-mean_var  to group:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filter
# Creating new group:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_8  with feature:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_8-mean_sum
# Creating new group:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_8-  with feature:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_8-mean_mean
# Adding feature:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_8-mean_max  to group:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_8
# Adding feature:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_8-mean_min  to group:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_8
# Adding feature:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_8-mean_var  to group:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_8
# Creating new group:  220_220 (max)_lambert_levels 0-40000-filtered_4-m  with feature:  220_220 (max)_lambert_levels 0-40000-filtered_4-max_sum
# Creating new group:  220_220 (max)_lambert_levels 0-40000-filtered_4-ma  with feature:  220_220 (max)_lambert_levels 0-40000-filtered_4-max_mean
# Adding feature:  220_220 (max)_lambert_levels 0-40000-filtered_4-max_max  to group:  220_220 (max)_lambert_levels 0-40000-filtered_4-m
# Adding feature:  220_220 (max)_lambert_levels 0-40000-filtered_4-max_min  to group:  220_220 (max)_lambert_levels 0-40000-filtered_4-m
# Adding feature:  220_220 (max)_lambert_levels 0-40000-filtered_4-max_var  to group:  220_220 (max)_lambert_levels 0-40000-filtered_4-m
# Creating new group:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-m  with feature:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-mean_sum
# Adding feature:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-mean_mean  to group:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-m
# Adding feature:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-mean_max  to group:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-m
# Adding feature:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-mean_min  to group:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-m
# Adding feature:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-mean_var  to group:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-m
# Creating new group:  HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_16-ma  with feature:  HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_16-max_sum
# Adding feature:  HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_16-max_mean  to group:  HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_16-ma
# Adding feature:  HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_16-max_max  to group:  HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_16-ma
# Adding feature:  HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_16-max_min  to group:  HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_16-ma
# Adding feature:  HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_16-max_var  to group:  HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_16-ma
# Creating new group:  221_221 (min)_lambert_levels 0-40000-filtered_2-m  with feature:  221_221 (min)_lambert_levels 0-40000-filtered_2-max_sum
# Creating new group:  221_221 (min)_lambert_levels 0-40000-filtered_2-ma  with feature:  221_221 (min)_lambert_levels 0-40000-filtered_2-max_mean
# Adding feature:  221_221 (min)_lambert_levels 0-40000-filtered_2-max_max  to group:  221_221 (min)_lambert_levels 0-40000-filtered_2-m
# Adding feature:  221_221 (min)_lambert_levels 0-40000-filtered_2-max_min  to group:  221_221 (min)_lambert_levels 0-40000-filtered_2-m
# Adding feature:  221_221 (min)_lambert_levels 0-40000-filtered_2-max_var  to group:  221_221 (min)_lambert_levels 0-40000-filtered_2-m
# Creating new group:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filt  with feature:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filtered_8-min_sum
# Adding feature:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filtered_8-min_mean  to group:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filte
# Adding feature:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filtered_8-min_max  to group:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filt
# Adding feature:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filtered_8-min_min  to group:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filt
# Adding feature:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filtered_8-min_var  to group:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filt
# Creating new group:  Snow depth_m (instant)_lambert_level 0-filtered_2-me  with feature:  Snow depth_m (instant)_lambert_level 0-filtered_2-mean_sum
# Creating new group:  Snow depth_m (instant)_lambert_level 0-filtered_2-mea  with feature:  Snow depth_m (instant)_lambert_level 0-filtered_2-mean_mean
# Adding feature:  Snow depth_m (instant)_lambert_level 0-filtered_2-mean_max  to group:  Snow depth_m (instant)_lambert_level 0-filtered_2-me
# Adding feature:  Snow depth_m (instant)_lambert_level 0-filtered_2-mean_min  to group:  Snow depth_m (instant)_lambert_level 0-filtered_2-me
# Adding feature:  Snow depth_m (instant)_lambert_level 0-filtered_2-mean_var  to group:  Snow depth_m (instant)_lambert_level 0-filtered_2-me
# Creating new group:  Surface pressure_Pa (instant)_lambert_level 0-filtered_2-m  with feature:  Surface pressure_Pa (instant)_lambert_level 0-filtered_2-mean_sum
# Creating new group:  Surface pressure_Pa (instant)_lambert_level 0-filtered_2-me  with feature:  Surface pressure_Pa (instant)_lambert_level 0-filtered_2-mean_mean
# Adding feature:  Surface pressure_Pa (instant)_lambert_level 0-filtered_2-mean_max  to group:  Surface pressure_Pa (instant)_lambert_level 0-filtered_2-m
# Adding feature:  Surface pressure_Pa (instant)_lambert_level 0-filtered_2-mean_min  to group:  Surface pressure_Pa (instant)_lambert_level 0-filtered_2-m
# Adding feature:  Surface pressure_Pa (instant)_lambert_level 0-filtered_2-mean_var  to group:  Surface pressure_Pa (instant)_lambert_level 0-filtered_2-m
# Creating new group:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_3  with feature:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_32-max_sum
# Creating new group:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_32  with feature:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_32-max_mean
# Adding feature:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_32-max_max  to group:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_3
# Adding feature:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_32-max_min  to group:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_3
# ...
# Adding feature:  (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-5)^2  to group:  (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-m
# Creating new group:  (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-me  with feature:  (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-10)^1
# Adding feature:  (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-10)^2  to group:  (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-me
# Adding feature:  (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-15)^1  to group:  (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-me
# Adding feature:  (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-15)^2  to group:  (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-me
# Adding feature:  (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-20)^1  to group:  (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-me
# Adding feature:  (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-20)^2  to group:  (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-me
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max-0)^1  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max-0)^2  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max-5)^1  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max-5)^2  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max-10)^1  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-m
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max-10)^2  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-m
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max-15)^1  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-m
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max-15)^2  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-m
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max-20)^1  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-m
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max-20)^2  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-m
# Adding feature:  (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-0)^1  to group:  (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-m
# Adding feature:  (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-0)^2  to group:  (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-m
# Adding feature:  (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-5)^1  to group:  (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-m
# Adding feature:  (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-5)^2  to group:  (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-m
# Creating new group:  (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-me  with feature:  (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-10)^1
# Adding feature:  (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-10)^2  to group:  (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-me
# Adding feature:  (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-15)^1  to group:  (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-me
# Adding feature:  (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-15)^2  to group:  (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-me
# Adding feature:  (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-20)^1  to group:  (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-me
# Adding feature:  (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-20)^2  to group:  (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-me
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-0)^1  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-m
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-0)^2  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-m
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-5)^1  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-m
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-5)^2  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-m
# Creating new group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-me  with feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-10)^1
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-10)^2  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-me
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-15)^1  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-me
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-15)^2  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-me
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-20)^1  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-me
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-20)^2  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-me
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-0)^1  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-m
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-0)^2  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-m
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-5)^1  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-m
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-5)^2  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-m
# Creating new group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-me  with feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-10)^1
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-10)^2  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-me
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-15)^1  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-me
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-15)^2  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-me
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-20)^1  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-me
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-20)^2  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-me
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-0)^1  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-m
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-0)^2  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-m
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-5)^1  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-m
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-5)^2  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-m
# Creating new group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-me  with feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-10)^1
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-10)^2  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-me
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-15)^1  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-me
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-15)^2  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-me
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-20)^1  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-me
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-20)^2  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-me
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min-0)^1  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min-0)^2  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min-5)^1  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min-5)^2  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min-10)^1  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-m
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min-10)^2  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-m
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min-15)^1  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-m
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min-15)^2  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-m
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min-20)^1  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-m
# Adding feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min-20)^2  to group:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-m
# Creating new group:  la  with feature:  lat
# Creating new group:  lo  with feature:  lon
# Creating new group:  LU_11_3  with feature:  LU_11_30
# Creating new group:  LU_21_3  with feature:  LU_21_30
# Creating new group:  LU_22_3  with feature:  LU_22_30
# Creating new group:  LU_23_3  with feature:  LU_23_30
# Creating new group:  LU_24_3  with feature:  LU_24_30
# Creating new group:  LU_31_3  with feature:  LU_31_30
# Creating new group:  LU_41_3  with feature:  LU_41_30
# Creating new group:  LU_42_3  with feature:  LU_42_30
# Creating new group:  LU_43_3  with feature:  LU_43_30
# Creating new group:  LU_52_3  with feature:  LU_52_30
# Creating new group:  LU_71_3  with feature:  LU_71_30
# Creating new group:  LU_81_3  with feature:  LU_81_30
# Creating new group:  LU_82_3  with feature:  LU_82_30
# Creating new group:  LU_90_3  with feature:  LU_90_30
# Creating new group:  LU_95_3  with feature:  LU_95_30
# Creating new group:  LU_11_6  with feature:  LU_11_60
# Creating new group:  LU_21_6  with feature:  LU_21_60
# Creating new group:  LU_22_6  with feature:  LU_22_60
# Creating new group:  LU_23_6  with feature:  LU_23_60
# Creating new group:  LU_24_6  with feature:  LU_24_60
# Creating new group:  LU_31_6  with feature:  LU_31_60
# Creating new group:  LU_41_6  with feature:  LU_41_60
# Creating new group:  LU_42_6  with feature:  LU_42_60
# Creating new group:  LU_43_6  with feature:  LU_43_60
# Creating new group:  LU_52_6  with feature:  LU_52_60
# Creating new group:  LU_71_6  with feature:  LU_71_60
# Creating new group:  LU_81_6  with feature:  LU_81_60
# Creating new group:  LU_82_6  with feature:  LU_82_60
# Creating new group:  LU_90_6  with feature:  LU_90_60
# Creating new group:  LU_95_6  with feature:  LU_95_60
# Creating new group:  canopy_25th_  with feature:  canopy_25th_30
# Creating new group:  canopy_75th_  with feature:  canopy_75th_30
# Creating new group:  canopy_interval_0_0  with feature:  canopy_interval_0_0_30
# Creating new group:  canopy_interval_11_20  with feature:  canopy_interval_11_20_30
# Creating new group:  canopy_interval_1_10  with feature:  canopy_interval_1_10_30
# Creating new group:  canopy_interval_21_30  with feature:  canopy_interval_21_30_30
# Creating new group:  canopy_interval_31_40  with feature:  canopy_interval_31_40_30
# Creating new group:  canopy_interval_41_50  with feature:  canopy_interval_41_50_30
# Creating new group:  canopy_interval_51_60  with feature:  canopy_interval_51_60_30
# Creating new group:  canopy_interval_61_70  with feature:  canopy_interval_61_70_30
# Creating new group:  canopy_interval_71_80  with feature:  canopy_interval_71_80_30
# Creating new group:  canopy_interval_81_90  with feature:  canopy_interval_81_90_30
# Creating new group:  canopy_interval_91_100  with feature:  canopy_interval_91_100_30
# Creating new group:  canopy_mean_  with feature:  canopy_mean_30
# Creating new group:  canopy_median_  with feature:  canopy_median_30
# Creating new group:  canopy_var_  with feature:  canopy_var_30
# Adding feature:  canopy_25th_60  to group:  canopy_25th_
# Adding feature:  canopy_75th_60  to group:  canopy_75th_
# Adding feature:  canopy_interval_0_0_60  to group:  canopy_interval_0_0
# Adding feature:  canopy_interval_11_20_60  to group:  canopy_interval_11_20
# Adding feature:  canopy_interval_1_10_60  to group:  canopy_interval_1_10
# Adding feature:  canopy_interval_21_30_60  to group:  canopy_interval_21_30
# Adding feature:  canopy_interval_31_40_60  to group:  canopy_interval_31_40
# Adding feature:  canopy_interval_41_50_60  to group:  canopy_interval_41_50
# Adding feature:  canopy_interval_51_60_60  to group:  canopy_interval_51_60
# Adding feature:  canopy_interval_61_70_60  to group:  canopy_interval_61_70
# Adding feature:  canopy_interval_71_80_60  to group:  canopy_interval_71_80
# Adding feature:  canopy_interval_81_90_60  to group:  canopy_interval_81_90
# Adding feature:  canopy_interval_91_100_60  to group:  canopy_interval_91_100
# Adding feature:  canopy_mean_60  to group:  canopy_mean_
# Adding feature:  canopy_median_60  to group:  canopy_median_
# Adding feature:  canopy_var_60  to group:  canopy_var_
# Creating new group:  length_proxy_  with feature:  length_proxy_30
# Creating new group:  line_length_  with feature:  line_length_30
# Adding feature:  length_proxy_60  to group:  length_proxy_
# Adding feature:  line_length_60  to group:  line_length_
# Number of feature groups:  1058

# %%
# Print size of each group that has more than 1 feature
ct = 0

for key, value in feature_groups.items():
    if len(value) > 1:
        print(key, ' : ', len(value))
        ct += 1

print('Number of feature groups with more than 1 feature: ', ct)
# Out:
# 10 metre wind speed_m s**-1 (max)_lambert_level 10 m_  :  2
# 10 metre wind speed_m s**-1 (max)_lambert_level 10 m_c  :  2
# 10 metre wind speed_m s**-1 (max)_lambert_level 10   :  3
# 10 metre wind speed_m s**-1 (max)_lambert_level 10 m  :  2
# Wind speed (gust)_m s**-1 (max)_lambert_level 10 m  :  6
# 221_221 (min)_lambert_levels 0-40000-filtered_2-me  :  4
# HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-mi  :  4
# AIR_DENSITY kg/m3-filtered_2-mean  :  4
# Snow depth_m (instant)_lambert_level 0-filtered_8-m  :  8
# 4_4 (max)_lambert_level 0-filtered_2-mea  :  4
# HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_16-m  :  6
# Snow depth_m (instant)_lambert_level 0-filtered_8-me  :  4
# Total cloud cover_% (instant)_lambert_level 0-filtered_16-m  :  6
# 2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_2  :  8
# 2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_2-  :  6
# Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_8-m  :  7
# Total cloud cover_% (instant)_lambert_level 0-filtered_32-  :  8
# Total cloud cover_% (instant)_lambert_level 0-filtered_32-m  :  6
# 0_0 (instant)_lambert_level 0-filtered_16-ma  :  4
# Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_2  :  14
# Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_24  :  6
# HOURLY_SNOW_ACCUM_RATE m/h-filtered_16-ma  :  4
# HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/  :  5
# Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filte  :  42
# Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filter  :  21
# Water equivalent of accumulated snow depth_kg m**-2 (instant)_lambert_level 0-filtered_  :  42
# AIR_DENSITY kg/m3-filtered_32-max  :  4
# 220_220 (max)_lambert_levels 0-40000-filtered_16-m  :  8
# AIR_DENSITY kg/m3-filtered_8-max  :  4
# HOURLY_SNOW_ACCUM_RATE m/h-filtered_8-mi  :  4
# AIR_DENSITY kg/m3_  :  4
# 0_0 (instant)_lambert_level 0-filtered_2-mi  :  4
# GUST_FORCE N-filtered_32-max  :  4
# AIR_DENSITY kg/m3-filtered_2-min  :  4
# 10 metre U wind component_m s**-1 (instant)_lambert_level 10 m-filtered_  :  24
# 10 metre U wind component_m s**-1 (instant)_lambert_level 10 m-filtered_2  :  14
# 10 metre V wind component_m s**-1 (instant)_lambert_level 10 m-filtered_4  :  6
# Absolute vorticity_s**-1 (instant)_lambert_level 50000 Pa-filtered_8  :  8
# Absolute vorticity_s**-1 (instant)_lambert_level 50000 Pa-filtered_8-  :  6
# Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_1  :  14
# Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_1  :  8
# Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_16  :  7
# GUST_FORCE N-filtered_16-max  :  4
# 10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2  :  8
# 10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-  :  6
# Hail_m (max)_lambert_level 0-filtered_24-mea  :  4
# 2 metre temperature_K (instant)_lambert_level 2 m-filtered_32-  :  8
# 2 metre temperature_K (instant)_lambert_level 2 m-filtered_32-m  :  7
# Snow depth_m (instant)_lambert_level 0-filtered_16-me  :  4
# WIND_FORCE N-filtered_32-min  :  4
# 221_221 (min)_lambert_levels 0-40000-filtered_32-me  :  4
# Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_  :  24
# HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_32-  :  8
# HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_32-m  :  6
# Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-  :  8
# Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-m  :  7
# Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_4-  :  8
# Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_4-m  :  7
# 4_4 (max)_lambert_level 0-filtered_16-ma  :  4
# Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_2  :  21
# Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_3  :  8
# Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_32  :  7
# Total column integrated water vapour_kg m**-2 (instant)_lambert_level 0-filtered_  :  66
# 0_0 (instant)_lambert_level 0-filtered_24-ma  :  4
# 220_220 (max)_lambert_levels 0-40000-filtered_2-m  :  8
# Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filtere  :  3
# Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_8  :  6
# 220_220 (max)_lambert_levels 0-40000-filtered_4-m  :  8
# 2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-m  :  7
# HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_16-ma  :  5
# 221_221 (min)_lambert_levels 0-40000-filtered_2-m  :  8
# Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filt  :  24
# Snow depth_m (instant)_lambert_level 0-filtered_2-me  :  4
# Surface pressure_Pa (instant)_lambert_level 0-filtered_2-m  :  6
# Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_3  :  8
# Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_32  :  6
# Hail_m (max)_lambert_level 0 10-filtered_8-ma  :  5
# HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_2-ma  :  4
# GUST_FORCE N-filtered_24-mean  :  4
# Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_  :  24
# Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_8  :  7
# HOURLY_WET_SNOW_ACCUM_RATE m/h  :  4
# WIND_FORCE N-filtered_16-min  :  4
# 199_199 (max)_lambert_levels 5000-2000 m-filtered_24-m  :  14
# Convective available potential energy_J kg-1 (instant)_lambert_levels 25500  :  4
# 2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_16  :  8
# 2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_16-  :  6
# WIND_FORCE N-filtered_16-mean  :  4
# 74_74 (max)_lambert_level 0 200-filtered_4-mi  :  5
# 2 metre temperature_K (instant)_lambert_level 2 m-filtered_2-  :  8
# 2 metre temperature_K (instant)_lambert_level 2 m-filtered_2-m  :  6
# WIND_FORCE N_m  :  2
# AIR_DENSITY kg/m3-filtered_32-mean  :  4
# Surface pressure_Pa (instant)_lambert_level 0-filtered_24-m  :  6
# Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_4  :  8
# Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_4-  :  6
# 2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_32  :  8
# 2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_32-  :  6
# 10 metre U wind component_m s**-1 (instant)_lambert_level 10 m-filtered_3  :  8
# 10 metre U wind component_m s**-1 (instant)_lambert_level 10 m-filtered_32  :  6
# HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-ma  :  4
# 199_199 (max)_lambert_levels 5000-2000 m-filtered_4-m  :  8
# 10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-  :  6
# 221_221 (min)_lambert_levels 0-40000-filtered_8-m  :  8
# 220_220 (max)_lambert_levels 0-40000  :  5
# Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_32  :  8
# Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_32-  :  6
# 2 metre temperature_K (instant)_lambert_level 2 m-filtered_24-  :  8
# 2 metre temperature_K (instant)_lambert_level 2 m-filtered_24-m  :  7
# 220_220 (max)_lambert_levels 0-40000-filtered_24-m  :  8
# HOURLY_SNOW_ACCUM_RATE m/h-filtered_32-mea  :  4
# WIND_FORCE N-filtered_16-max  :  4
# Total precipitation_kg m-2 (accum)_lambert_level  :  4
# Hail_m (max)_lambert_level 0-filtered_8-mea  :  4
# 2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_24  :  8
# 2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_24-  :  6
# 4_4 (max)_lambert_level 0-filtered_24-mea  :  4
# Hail_m (max)_lambert_level 0-filtered_24-mi  :  4
# AIR_DENSITY kg/m3-filtered_24-max  :  4
# 221_221 (min)_lambert_levels 0-40000-filtered_32-m  :  8
# HOURLY_SNOW_ACCUM_RATE m/h-filtered_32-mi  :  4
# Hail_m (max)_lambert_level 0 10-filtered_8-me  :  4
# Total cloud cover_% (instant)_lambert_level 0-filtered_24-  :  8
# Total cloud cover_% (instant)_lambert_level 0-filtered_24-m  :  6
# Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_2-m  :  7
# Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_8  :  6
# AIR_DENSITY kg/m3-filtered_8-min  :  4
# GUST_FORCE N-filtered_2-mean  :  4
# 10 metre V wind component_m s**-1 (instant)_lambert_level 10 m-filtered_  :  24
# Hail_m (max)_lambert_level 0-filtered_2-ma  :  4
# HOURLY_SNOW_ACCUM_RATE m/h-filtered_24-mea  :  4
# 74_74 (max)_lambert_level 0 200-filtered_32-m  :  8
# Hail_m (max)_lambert_level 0-filtered_4-mi  :  4
# Hail_m (max)_lambert_level 0 10-filtered_24-me  :  4
# Hail_m (max)_lambert_level 0  :  4
# 220_220 (max)_lambert_levels 0-40000-filtered_8-m  :  8
# Water equivalent of accumulated snow depth_kg m**-2 (instant)_lambert_level 0-filtered  :  24
# 2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-  :  8
# Total column integrated water vapour_kg m**-2 (instant)_lambert_level 0-filtered_3  :  6
# 2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_32  :  8
# 2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_32-  :  6
# 2 metre temperature_K (instant)_lambert_level 2 m-filtered_8-m  :  6
# 0_0 (instant)_lambert_level 0-filtered_4-ma  :  4
# Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_16  :  6
# 10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-  :  6
# 2 metre temperature_K (instant)_lambert_level 2 m-filtered_4-  :  8
# 2 metre temperature_K (instant)_lambert_level 2 m-filtered_4-m  :  6
# Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-  :  8
# Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-m  :  7
# 2 metre temperature_K (instant)_lambert_level 2 m-filtered_8-  :  8
# AIR_DENSITY kg/m3-filtered_16-mean  :  4
# Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_  :  63
# Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert  :  5
# HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_4-m  :  6
# Hail_m (max)_lambert_level 0 10-filtered_32-m  :  8
# HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-mea  :  5
# GUST_FORCE N-filtered_8-max  :  4
# Snow depth_m (instant)_lambert_level 0-filtered_24-me  :  4
# Hail_m (max)_lambert_level 0-filtered_16-mea  :  4
# Surface pressure_Pa (instant)_lambert_level 0-filtered_16-m  :  6
# 4_4 (max)_lambert_level 0-filtered_32-mi  :  4
# AIR_DENSITY kg/m3-filtered_24-min  :  4
# Surface pressure_Pa (instant)_lambert_level 0-filtered_24-  :  8
# Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_24-  :  14
# Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_24  :  8
# Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_24-  :  6
# Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_32-  :  14
# 199_199 (max)_lambert_levels 5000-2000 m-filtered_16-m  :  14
# Snow depth_m (instant)_lambert_level 0-filtered_2-m  :  8
# 199_199 (max)_lambert_levels 5000-2000 m-filtered_8-m  :  8
# 221_221 (min)_lambert_levels 0-40000-filtered_16-m  :  8
# 74_74 (max)_lambert_level 0 200-filtered_16-m  :  8
# Snow depth_m (instant)_lambert_level   :  4
# AIR_DENSITY kg/m3-filtered_24-mean  :  4
# 2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_4  :  8
# 2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_4-  :  6
# 10 metre V wind component_m s**-1 (instant)_lambert_level 10 m-filtered_2  :  14
# 10 metre V wind component_m s**-1 (instant)_lambert_level 10 m-filtered_24  :  6
# Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered  :  24
# 0_0 (instant)_lambert_level 0-filtered_8-mea  :  4
# Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-m  :  7
# HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_16-  :  8
# Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_  :  42
# Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_2  :  7
# 4_4 (max)_lambert_level 0-filtered_32-mea  :  4
# 220_220 (max)_lambert_levels 0-40000-filtered_32-m  :  8
# 221_221 (min)_lambert_levels 0-40000-filtered_24-me  :  4
# 10 metre V wind component_m s**-1 (instant)_lambert_level 10 m-filtered_8  :  6
# 10 metre V wind component_m s**-1 (instant)_lambert_level 10 m-filtered_1  :  8
# 10 metre V wind component_m s**-1 (instant)_lambert_level 10 m-filtered_16  :  6
# Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_  :  24
# Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_2  :  14
# Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_1  :  6
# AIR_DENSITY kg/m3-filtered_8-mean  :  4
# 4_4 (max)_lambert_level 0-filtered_2-mi  :  4
# Total cloud cover_% (instant)_lambert_level   :  4
# WIND_FORCE N-filtered_4-mean  :  4
# Total column integrated water vapour_kg m**-2 (instant)_lambert_level 0-filtered_1  :  6
# Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_3  :  6
# 74_74 (max)_lambert_level 0 200-filtered_4-ma  :  5
# Total cloud cover_% (instant)_lambert_level 0-filtered_16-  :  8
# Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-  :  14
# Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_8-  :  8
# 2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_16  :  8
# 2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_16-  :  6
# 220_220 (max)_lambert_levels 0-40000-filtered_32-me  :  4
# Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_16-  :  14
# Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0  :  4
# 0_0 (instant)_lambert_level 0-filtered_2-mea  :  4
# Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_4  :  6
# HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_2-mi  :  4
# 4_4 (max)_lambert_level 0_  :  4
# Absolute vorticity_s**-1 (instant)_lambert_level 50000 Pa-filtered_32  :  8
# Absolute vorticity_s**-1 (instant)_lambert_level 50000 Pa-filtered_32-  :  6
# 220_220 (max)_lambert_levels 0-40000-filtered_16-me  :  4
# Snow depth_m (instant)_lambert_level 0-filtered_4-me  :  4
# 74_74 (max)_lambert_level 0 200-filtered_2-mi  :  5
# Surface pressure_Pa (instant)_lambert_level 0-filtered_8-  :  8
# Surface pressure_Pa (instant)_lambert_level 0-filtered_8-m  :  6
# HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_24-ma  :  5
# 2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_8  :  8
# 2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_8-  :  6
# HOURLY_SNOW_ACCUM_RATE m/h-filtered_4-mi  :  4
# 10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-  :  6
# 10 metre V wind component_m s**-1 (instant)_lambert_level 10 m-filtered_3  :  8
# 10 metre V wind component_m s**-1 (instant)_lambert_level 10 m-filtered_32  :  6
# 2 metre relative humidity_% (instant)_lambert_level 2  :  4
# Water equivalent of accumulated snow depth_kg m**-2 (instant)_lambert_level 0-filtered_1  :  6
# Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered  :  24
# 4_4 (max)_lambert_level 0-filtered_8-mea  :  4
# Surface pressure_Pa (instant)_lambert_level 0-filtered_16-  :  8
# HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_24-m  :  6
# Hail_m (max)_lambert_level 0 10-filtered_4-me  :  4
# HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_2-  :  8
# HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_2-m  :  6
# HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_32-me  :  4
# Water equivalent of accumulated snow depth_kg m**-2 (instant)_lambert_level 0-filtered_3  :  6
# Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-  :  14
# Snow depth_m (instant)_lambert_level 0-filtered_4-m  :  8
# GUST_FORCE N-filtered_16-mean  :  4
# 221_221 (min)_lambert_levels 0-40000-filtered_8-me  :  4
# Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_2-  :  8
# 10 metre U wind component_m s**-1 (instant)_lambert_level 10 m-filtered_24  :  6
# 10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8  :  8
# Hail_m (max)_lambert_level 0-filtered_32-ma  :  4
# Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_3  :  14
# 10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-  :  6
# 0_0 (instant)_lambert_level 0  :  4
# Total column integrated water vapour_kg m**-2 (instant)_lambert_level 0-filtered_2  :  7
# 4_4 (max)_lambert_level 0-filtered_8-ma  :  4
# Surface pressure_Pa (instant)_lambert_level 0-filtered_2-  :  8
# Snow depth_m (instant)_lambert_level 0-filtered_24-m  :  8
# 0_0 (instant)_lambert_level 0-filtered_8-mi  :  4
# 74_74 (max)_lambert_level 0 200-filtered_2-ma  :  5
# HOURLY_SNOW_ACCUM_RATE m/h_  :  5
# GUST_FORCE N-filtered_2-max  :  4
# Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_4  :  7
# 2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_8  :  8
# 2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_8-  :  6
# 74_74 (max)_lambert_level 0 200-filtered_24-me  :  4
# 221_221 (min)_lambert_levels 0-40000-filtered_4-me  :  4
# 74_74 (max)_lambert_level 0 200-filtered_24-m  :  8
# Absolute vorticity_s**-1 (instant)_lambert_level 50000 Pa-filtered_2  :  8
# Absolute vorticity_s**-1 (instant)_lambert_level 50000 Pa-filtered_2-  :  6
# 2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_4-  :  6
# 10 metre U wind component_m s**-1 (instant)_lambert_level 10 m-filtered_4  :  6
# Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-  :  8
# Total cloud cover_% (instant)_lambert_level 0-filtered_8-m  :  6
# HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_8-  :  8
# HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_8-m  :  6
# 10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16  :  8
# Total cloud cover_% (instant)_lambert_level 0-filtered_2-  :  8
# Total cloud cover_% (instant)_lambert_level 0-filtered_2-m  :  6
# WIND_FORCE N-filtered_8-mean  :  4
# HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_24-  :  8
# WIND_FORCE N-filtered_32-mean  :  4
# 10 metre U wind component_m s**-1 (instant)_lambert_level 10 m-filtered_8  :  6
# 10 metre U wind component_m s**-1 (instant)_lambert_level 10 m-filtered_16  :  6
# GUST_FORCE N-filtered_16-min  :  4
# 221_221 (min)_lambert_levels 0-40000-filtered_24-m  :  8
# Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_8-  :  6
# Absolute vorticity_s**-1 (instant)_lambert_level 50000 Pa-filtered_24-  :  6
# HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_16-me  :  4
# Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-  :  14
# Surface pressure_Pa (instant)_lambert_level 0-filtered_4-  :  8
# Surface pressure_Pa (instant)_lambert_level 0-filtered_4-m  :  6
# GUST_FORCE N_m  :  2
# Hail_m (max)_lambert_level 0 10-filtered_16-m  :  8
# Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_4  :  6
# Hail_m (max)_lambert_level 0-filtered_32-mi  :  4
# 10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4  :  8
# 10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-  :  6
# Hail_m (max)_lambert_level 0 10-filtered_4-ma  :  5
# Surface pressure_Pa (instant)_lambert_level 0-filtered_32-m  :  6
# HOURLY_SNOW_ACCUM_RATE m/h-filtered_4-ma  :  4
# HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_24-me  :  4
# 4_4 (max)_lambert_level 0-filtered_32-ma  :  4
# 74_74 (max)_lambert_level 0 200-filtered_8-ma  :  5
# GUST_FORCE N-filtered_4-max  :  4
# 10 metre V wind component_m s**-1 (instant)_lambert_level 1  :  4
# Hail_m (max)_lambert_level 0-filtered_16-ma  :  4
# HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_4-mea  :  5
# Hail_m (max)_lambert_level 0-filtered_2-mea  :  4
# Absolute vorticity_s**-1 (instant)_lambert_level 50000 Pa-filtered_16-  :  6
# 4_4 (max)_lambert_level 0-filtered_24-mi  :  4
# AIR_DENSITY kg/m3-filtered_16-max  :  4
# HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_4-mi  :  4
# 10 metre wind speed_m s**-1 (max)_lambert_level 10  :  4
# Total cloud cover_% (instant)_lambert_level 0-filtered_4-  :  8
# Total cloud cover_% (instant)_lambert_level 0-filtered_4-m  :  6
# WIND_FORCE N-filtered_2-mean  :  4
# WIND_FORCE N-filtered_24-max  :  4
# Hail_m (max)_lambert_level 0-filtered_16-mi  :  4
# Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_16-  :  6
# HOURLY_SNOW_ACCUM_RATE m/h-filtered_2-mi  :  4
# Hail_m (max)_lambert_level 0-filtered_32-mea  :  4
# 0_0 (instant)_lambert_level 0-filtered_4-mi  :  4
# Hail_m (max)_lambert_level 0 10  :  4
# HOURLY_SNOW_ACCUM_RATE m/h-filtered_24-ma  :  4
# WIND_FORCE N-filtered_24-min  :  4
# 199_199 (max)_lambert_levels 5000-2000 m-filtered_32-m  :  14
# 4_4 (max)_lambert_level 0-filtered_16-mea  :  4
# 74_74 (max)_lambert_level 0 200-filtered_2-me  :  4
# 0_0 (instant)_lambert_level 0-filtered_32-mi  :  4
# 2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_24  :  8
# 2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_24-  :  6
# Absolute vorticity_s**-1 (instant)_lambert_level 50000  :  4
# HOURLY_SNOW_ACCUM_RATE m/h-filtered_2-ma  :  4
# Hail_m (max)_lambert_level 0 10-filtered_24-m  :  8
# 2 metre dewpoint temperature_K (instant)_lambert_level   :  4
# Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_1  :  8
# Total column-integrated condensate_kg m**-2 (instant)_lambert_lev  :  4
# Wind speed (gust)_m s**-1 (max)_lambert_level 10  :  4
# 0_0 (instant)_lambert_level 0-filtered_8-ma  :  4
# 10 metre U wind component_m s**-1 (instant)_lambert_level 10 m-filtered_1  :  8
# Hail_m (max)_lambert_level 0 10-filtered_32-me  :  4
# Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_24  :  7
# HOURLY_SNOW_ACCUM_RATE m/h-filtered_2-mea  :  4
# AIR_DENSITY kg/m3-filtered_4-max  :  4
# WIND_FORCE N-filtered_24-mean  :  4
# 10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32  :  8
# Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_8  :  8
# 74_74 (max)_lambert_level 0 200-filtered_32-me  :  4
# 2 metre temperature_K (instant)_lambert_level 2  :  4
# Hail_m (max)_lambert_level 0-filtered_8-mi  :  4
# GUST_FORCE N-filtered_2-min  :  4
# HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_32-ma  :  5
# HOURLY_SNOW_ACCUM_RATE m/h-filtered_24-mi  :  4
# WIND_FORCE N-filtered_4-max  :  4
# Hail_m (max)_lambert_level 0 10-filtered_2-ma  :  5
# AIR_DENSITY kg/m3-filtered_4-min  :  4
# HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_4-  :  8
# 10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24  :  8
# 199_199 (max)_lambert_levels 5000-2000 m-filtered_4-me  :  5
# 74_74 (max)_lambert_level 0 200-filtered_16-me  :  4
# 4_4 (max)_lambert_level 0-filtered_4-mi  :  4
# WIND_FORCE N-filtered_8-min  :  4
# 0_0 (instant)_lambert_level 0-filtered_2-ma  :  4
# 2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_2-  :  6
# 221_221 (min)_lambert_levels 0-40000-filtered_16-me  :  4
# WIND_FORCE N-filtered_2-max  :  4
# 0_0 (instant)_lambert_level 0-filtered_16-mea  :  5
# Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma v  :  5
# Water equivalent of accumulated snow depth_kg m**-2 (instant)_lambert_level 0-filtered_2  :  7
# GUST_FORCE N-filtered_32-min  :  4
# GUST_FORCE N-filtered_24-min  :  4
# Hail_m (max)_lambert_level 0 10-filtered_8-mi  :  5
# 221_221 (min)_lambert_levels 0-40000-filtered_4-m  :  8
# Snow depth_m (instant)_lambert_level 0-filtered_16-m  :  8
# 4_4 (max)_lambert_level 0-filtered_16-mi  :  4
# HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_2-mea  :  5
# HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_24-mi  :  5
# 221_221 (min)_lambert_levels 0-40000  :  5
# 4_4 (max)_lambert_level 0-filtered_8-mi  :  4
# AIR_DENSITY kg/m3-filtered_2-max  :  4
# 4_4 (max)_lambert_level 0-filtered_4-ma  :  4
# GUST_FORCE N-filtered_4-min  :  4
# 199_199 (max)_lambert_levels 5000-2000 m-filtered_2-m  :  8
# 0_0 (instant)_lambert_level 0-filtered_4-mea  :  4
# HOURLY_SNOW_ACCUM_RATE m/h-filtered_8-mea  :  4
# Absolute vorticity_s**-1 (instant)_lambert_level 50000 Pa-filtered_16  :  8
# WIND_FORCE N-filtered_2-min  :  4
# Hail_m (max)_lambert_level 0-filtered_4-mea  :  4
# 199_199 (max)_lambert_levels 5000-2000   :  4
# Hail_m (max)_lambert_level 0 10-filtered_2-mi  :  5
# HOURLY_SNOW_ACCUM_RATE m/h-filtered_32-ma  :  4
# WIND_FORCE N-filtered_32-max  :  4
# Snow depth_m (instant)_lambert_level 0-filtered_32-m  :  8
# Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_16  :  8
# Hail_m (max)_lambert_level 0-filtered_2-mi  :  4
# Hail_m (max)_lambert_level 0 10-filtered_2-me  :  4
# Hail_m (max)_lambert_level 0 10-filtered_16-me  :  4
# Convective available potential energy_J kg-1 (instant)_lambert_lev  :  4
# WIND_FORCE N-filtered_8-max  :  4
# HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_32-mi  :  5
# HOURLY_SNOW_ACCUM_RATE m/h-filtered_16-mi  :  4
# Absolute vorticity_s**-1 (instant)_lambert_level 50000 Pa-filtered_4  :  8
# Absolute vorticity_s**-1 (instant)_lambert_level 50000 Pa-filtered_4-  :  6
# GUST_FORCE N-filtered_8-mean  :  4
# 0_0 (instant)_lambert_level 0-filtered_24-mi  :  4
# 199_199 (max)_lambert_levels 5000-2000 m-filtered_8-me  :  5
# Surface pressure_Pa (instant)_lambert_level   :  4
# Hail_m (max)_lambert_level 0-filtered_8-ma  :  4
# 74_74 (max)_lambert_level 0 200-filtered_4-me  :  4
# AIR_DENSITY kg/m3-filtered_32-min  :  4
# HOURLY_SNOW_ACCUM_RATE m/h-filtered_4-mea  :  4
# GUST_FORCE N-filtered_24-max  :  4
# 220_220 (max)_lambert_levels 0-40000-filtered_8-me  :  4
# 2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_2  :  8
# GUST_FORCE N-filtered_8-min  :  4
# 220_220 (max)_lambert_levels 0-40000-filtered_24-me  :  4
# Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_2  :  8
# Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_2-  :  6
# HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_16-mi  :  5
# WIND_FORCE N-filtered_4-min  :  4
# 4_4 (max)_lambert_level 0-filtered_2-ma  :  4
# HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_4-ma  :  4
# 220_220 (max)_lambert_levels 0-40000-filtered_2-me  :  4
# GUST_FORCE N-filtered_32-mean  :  4
# Snow depth_m (instant)_lambert_level 0-filtered_32-me  :  4
# Hail_m (max)_lambert_level 0-filtered_4-ma  :  4
# 74_74 (max)_lambert_level 0 200-filtered_8-me  :  4
# 0_0 (instant)_lambert_level 0-filtered_16-mi  :  4
# Surface pressure_Pa (instant)_lambert_level 0-filtered_32-  :  8
# 4_4 (max)_lambert_level 0-filtered_4-mea  :  4
# Total column integrated water vapour_kg m**-2 (instant)_lambert_lev  :  4
# Absolute vorticity_s**-1 (instant)_lambert_level 50000 Pa-filtered_24  :  8
# AIR_DENSITY kg/m3-filtered_4-mean  :  4
# HOURLY_SNOW_ACCUM_RATE m/h-filtered_16-mea  :  4
# Water equivalent of accumulated snow depth_kg m**-2 (instant)_lambert_le  :  4
# 0_0 (instant)_lambert_level 0-filtered_32-mea  :  5
# GUST_FORCE N-filtered_4-mean  :  4
# 0_0 (instant)_lambert_level 0-filtered_24-mea  :  5
# HOURLY_SNOW_ACCUM_RATE m/h-filtered_8-ma  :  4
# Convective inhibition_J kg-1 (instant)_lambert_level  :  4
# 0_0 (instant)_lambert_level 0-filtered_32-ma  :  4
# 74_74 (max)_lambert_level 0 200-filtered_8-mi  :  5
# 10 metre U wind component_m s**-1 (instant)_lambert_level 1  :  4
# 199_199 (max)_lambert_levels 5000-2000 m-filtered_2-me  :  5
# 4_4 (max)_lambert_level 0-filtered_24-ma  :  4
# 74_74 (max)_lambert_level 0 200  :  4
# Hail_m (max)_lambert_level 0-filtered_24-ma  :  4
# AIR_DENSITY kg/m3-filtered_16-min  :  4
# Total cloud cover_% (instant)_lambert_level 0-filtered_8-  :  8
# Hail_m (max)_lambert_level 0 10-filtered_4-mi  :  5
# 2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_4  :  8
# 220_220 (max)_lambert_levels 0-40000-filtered_4-me  :  4
# Surface pressure_Pa (instant)_lambert_level 0-filtered_2-min_3_hour_vari  :  2
# 2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_16-mean_3_hour_var  :  2
# 2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_2-max_3_hour_var  :  2
# 2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_32-mean_3_hour_var  :  2
# 2 metre temperature_K (instant)_lambert_level 2 m-filtered_24-max_3_hour_vari  :  2
# 2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_2-mean_3_hour_var  :  2
# 2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_16-min_3_hour_var  :  2
# 2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_2-min_3_hour_var  :  2
# Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_24-min_3_hour_va  :  2
# Surface pressure_Pa (instant)_lambert_level 0-filtered_16-min_3_hour_vari  :  2
# Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_2-min_3_hour_var  :  2
# Surface pressure_Pa (instant)_lambert_level 0-filtered_8-mean_3_hour_vari  :  2
# Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_16-max_3_hour_var  :  2
# 2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_16-max_3_hour_var  :  2
# Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_16-mean_3_hour_var  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_24-max_3_hour_v  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_level 0_3_hour_var  :  2
# 2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_24-mean_3_hour_var  :  2
# Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa_3_hour_vari  :  2
# Surface pressure_Pa (instant)_lambert_level 0-filtered_4-max_3_hour_vari  :  2
# 2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_32-min_3_hour_var  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_16-max_3_hour_va  :  2
# Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_2-mean_3_hour_va  :  2
# Surface pressure_Pa (instant)_lambert_level 0-filtered_8-min_3_hour_vari  :  2
# Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_32-min_3_hour_var  :  2
# 2 metre temperature_K (instant)_lambert_level 2 m-filtered_32-max_3_hour_vari  :  2
# 2 metre temperature_K (instant)_lambert_level 2 m-filtered_2-min_3_hour_vari  :  2
# 2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_8-max_3_hour_var  :  2
# Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_2-max_3_hour_var  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_16-mean_3_hour_va  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_4-min_3_hour_va  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_24-min_3_hour_va  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_8-min_3_hour_v  :  2
# 2 metre relative humidity_% (instant)_lambert_level 2 m_3_hour_varia  :  2
# 2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-max_3_hour_vari  :  2
# Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_8-mean_3_hour_va  :  2
# 2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-mean_3_hour_vari  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_16-max_3_hour_v  :  2
# Surface pressure_Pa (instant)_lambert_level 0-filtered_16-max_3_hour_vari  :  2
# Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_32-max_3_hour_va  :  2
# Surface pressure_Pa (instant)_lambert_level 0-filtered_2-mean_3_hour_vari  :  2
# Surface pressure_Pa (instant)_lambert_level 0_3_hour_variat  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_8-mean_3_hour_v  :  2
# 2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_8-mean_3_hour_var  :  2
# Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_4-min_3_hour_var  :  2
# 2 metre temperature_K (instant)_lambert_level 2 m-filtered_2-mean_3_hour_vari  :  2
# 2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_8-mean_3_hour_var  :  2
# 2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_24-min_3_hour_var  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_8-max_3_hour_va  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_16-min_3_hour_va  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_4-max_3_hour_va  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa_3_hour_va  :  2
# Surface pressure_Pa (instant)_lambert_level 0-filtered_8-max_3_hour_vari  :  2
# 2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_16-max_3_hour_var  :  2
# 2 metre dewpoint temperature_K (instant)_lambert_level 2 m_3_hour_varia  :  2
# 2 metre temperature_K (instant)_lambert_level 2 m-filtered_2-max_3_hour_vari  :  2
# Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_4-max_3_hour_vari  :  2
# Surface pressure_Pa (instant)_lambert_level 0-filtered_24-mean_3_hour_vari  :  2
# Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_4-min_3_hour_vari  :  2
# 2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_32-max_3_hour_var  :  2
# 2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_32-max_3_hour_var  :  2
# 2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_24-max_3_hour_var  :  2
# Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_24-max_3_hour_va  :  2
# Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_16-min_3_hour_va  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_2-mean_3_hour_va  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_2-max_3_hour_va  :  2
# 2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_24-max_3_hour_var  :  2
# Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_32-max_3_hour_var  :  2
# 2 metre temperature_K (instant)_lambert_level 2 m-filtered_24-min_3_hour_vari  :  2
# Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_24-mean_3_hour_var  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_32-mean_3_hour_v  :  2
# 2 metre temperature_K (instant)_lambert_level 2 m-filtered_4-max_3_hour_vari  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_32-max_3_hour_va  :  2
# Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_24-max_3_hour_var  :  2
# 2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_2-min_3_hour_var  :  2
# Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_8-max_3_hour_vari  :  2
# Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_2-max_3_hour_vari  :  2
# Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_4-mean_3_hour_var  :  2
# 2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_24-min_3_hour_var  :  2
# Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_8-min_3_hour_vari  :  2
# Surface pressure_Pa (instant)_lambert_level 0-filtered_2-max_3_hour_vari  :  2
# 2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_4-max_3_hour_var  :  2
# 2 metre temperature_K (instant)_lambert_level 2 m_3_hour_variat  :  2
# Surface pressure_Pa (instant)_lambert_level 0-filtered_4-mean_3_hour_vari  :  2
# 2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_16-min_3_hour_var  :  2
# Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_8-min_3_hour_var  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_24-mean_3_hour_va  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_8-max_3_hour_v  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_4-mean_3_hour_va  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_8-min_3_hour_va  :  2
# 2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_8-max_3_hour_var  :  2
# Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_24-mean_3_hour_va  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_2-min_3_hour_va  :  2
# 2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_4-mean_3_hour_var  :  2
# 2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_32-mean_3_hour_var  :  2
# Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_32-min_3_hour_va  :  2
# 2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-min_3_hour_vari  :  2
# 2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_32-min_3_hour_var  :  2
# Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_2-mean_3_hour_var  :  2
# 2 metre temperature_K (instant)_lambert_level 2 m-filtered_8-mean_3_hour_vari  :  2
# Surface pressure_Pa (instant)_lambert_level 0-filtered_32-max_3_hour_vari  :  2
# Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_16-min_3_hour_var  :  2
# Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_16-mean_3_hour_va  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_8-mean_3_hour_va  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_24-min_3_hour_v  :  2
# 2 metre temperature_K (instant)_lambert_level 2 m-filtered_4-min_3_hour_vari  :  2
# 2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_2-mean_3_hour_var  :  2
# 2 metre temperature_K (instant)_lambert_level 2 m-filtered_8-max_3_hour_vari  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_4-max_3_hour_v  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_32-max_3_hour_v  :  2
# 2 metre temperature_K (instant)_lambert_level 2 m-filtered_32-mean_3_hour_vari  :  2
# 2 metre temperature_K (instant)_lambert_level 2 m-filtered_4-mean_3_hour_vari  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_32-min_3_hour_v  :  2
# Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_32-mean_3_hour_va  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_2-mean_3_hour_v  :  2
# 2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_2-max_3_hour_var  :  2
# Surface pressure_Pa (instant)_lambert_level 0-filtered_16-mean_3_hour_vari  :  2
# 2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_24-mean_3_hour_var  :  2
# Convective inhibition_J kg-1 (instant)_lambert_level 0_3_hour_varia  :  2
# Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_32-mean_3_hour_var  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_24-max_3_hour_va  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_16-min_3_hour_v  :  2
# Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_4-mean_3_hour_va  :  2
# Surface pressure_Pa (instant)_lambert_level 0-filtered_24-min_3_hour_vari  :  2
# Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_8-max_3_hour_var  :  2
# Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_16-max_3_hour_va  :  2
# Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_8-mean_3_hour_var  :  2
# Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_24-min_3_hour_var  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_32-min_3_hour_va  :  2
# 2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_8-min_3_hour_var  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_32-mean_3_hour_va  :  2
# Surface pressure_Pa (instant)_lambert_level 0-filtered_4-min_3_hour_vari  :  2
# 2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_8-min_3_hour_var  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_24-mean_3_hour_v  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_4-mean_3_hour_v  :  2
# 2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_4-min_3_hour_var  :  2
# Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_4-max_3_hour_var  :  2
# 2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_16-mean_3_hour_var  :  2
# Surface pressure_Pa (instant)_lambert_level 0-filtered_24-max_3_hour_vari  :  2
# Surface pressure_Pa (instant)_lambert_level 0-filtered_32-min_3_hour_vari  :  2
# Surface pressure_Pa (instant)_lambert_level 0-filtered_32-mean_3_hour_vari  :  2
# 2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_4-mean_3_hour_var  :  2
# 2 metre temperature_K (instant)_lambert_level 2 m-filtered_24-mean_3_hour_vari  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_2-min_3_hour_v  :  2
# 2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_4-max_3_hour_var  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_2-max_3_hour_v  :  2
# Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_2-min_3_hour_vari  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_4-min_3_hour_v  :  2
# Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_16-mean_3_hour_v  :  2
# 2 metre temperature_K (instant)_lambert_level 2 m-filtered_8-min_3_hour_vari  :  2
# 2 metre temperature_K (instant)_lambert_level 2 m-filtered_32-min_3_hour_vari  :  2
# 2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_4-min_3_hour_var  :  2
# (Wind speed (gust)_m s**-1 (max)_lambert_level 10   :  4
# (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m  :  6
# (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-  :  8
# (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-m  :  16
# (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-m  :  16
# (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-me  :  6
# (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-  :  8
# (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-m  :  16
# (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-  :  8
# (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-m  :  16
# (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-  :  8
# (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-m  :  16
# (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-m  :  16
# (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-me  :  6
# (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-  :  8
# (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-m  :  16
# (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-m  :  16
# (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-me  :  6
# (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-  :  8
# (10 metre wind speed_m s**-1 (max)_lambert_level 10   :  4
# (10 metre wind speed_m s**-1 (max)_lambert_level 10 m  :  6
# (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-  :  8
# (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-m  :  16
# (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-me  :  6
# (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-  :  8
# (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-m  :  16
# (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-  :  8
# (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-m  :  16
# (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-me  :  6
# (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-me  :  6
# (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-  :  8
# (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-me  :  6
# (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-  :  8
# (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-m  :  16
# (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-  :  8
# (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-me  :  6
# (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-me  :  6
# (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-me  :  6
# (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-me  :  6
# (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-me  :  6
# canopy_25th_  :  2
# canopy_75th_  :  2
# canopy_interval_0_0  :  2
# canopy_interval_11_20  :  2
# canopy_interval_1_10  :  2
# canopy_interval_21_30  :  2
# canopy_interval_31_40  :  2
# canopy_interval_41_50  :  2
# canopy_interval_51_60  :  2
# canopy_interval_61_70  :  2
# canopy_interval_71_80  :  2
# canopy_interval_81_90  :  2
# canopy_interval_91_100  :  2
# canopy_mean_  :  2
# canopy_median_  :  2
# canopy_var_  :  2
# length_proxy_  :  2
# line_length_  :  2
# Number of feature groups with more than 1 feature:  657

# %%
# Load your dataset
data = pd.read_parquet(path='../outage_data.parquet', engine='pyarrow')

# apply ordinal encoding to 'poly_ewkt', 'point_ewkt', 'event_type' columns
non_numerical_columns = ['poly_ewkt', 'event_type']

for column in non_numerical_columns:
    data[column] = data[column].astype('category')
    data[column] = data[column].cat.codes

# Convert datetime columns to separate columns for year, month, day, hour, minute, second
datetime_features = list(data.select_dtypes(include = "datetime64[ns, UTC]").columns)
for i in datetime_features:
    data[i+"_year"] = data[i].dt.year
    data[i+"_month"] = data[i].dt.month
    data[i+"_day"] = data[i].dt.day
    data[i+"_hour"] = data[i].dt.hour

data.drop(columns = ['point_ewkt'], inplace = True)

# %%
# for every group of features select the one with best correlation with 'outage_count'

import math

selected_features = []
labels = data['outage_count'].copy()

for key, value in feature_groups.items():
    if len(value) > 1:
        highest_corr = - math.inf
        print("Finding the best feature for group: ", key)
        for feat in value:
            #print("Calculating correlation for feature: ", feat)
            corr = labels.corr(data[feat])
            #print(feat, ': ', corr)
            if corr > highest_corr:
                highest_corr = corr
                selected_feature = feat

        print('Selected feature: ', selected_feature, ' with correlation: ', highest_corr)
        selected_features.append(selected_feature)
    else:
        print('Selected feature: ', value[0])
        selected_features.append(value[0])
    
display(selected_features)
# Out:
# Selected feature:  0
# Selected feature:  breaker_counts
# Selected feature:  fuse_counts
# Selected feature:  switch_counts
# Selected feature:  transformer_counts
# Selected feature:  recloser_counts
# Selected feature:  pole_counts
# Selected feature:  poly_ewkt
# Selected feature:  point_ewkt
# Selected feature:  grid_id
# Selected feature:  outage_count
# Selected feature:  SimStartDate
# Selected feature:  outage_start_time
# Selected feature:  outage_end_time
# Selected feature:  weather_start_time
# Selected feature:  weather_end_time
# Selected feature:  event_type
# Selected feature:  x
# Selected feature:  y
# Finding the best feature for group:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m_
# Selected feature:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m_cogt_5  with correlation:  0.012201150002195063
# Finding the best feature for group:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m_c
# Selected feature:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m_cogt_18  with correlation:  -0.01077672517867401
# Finding the best feature for group:  10 metre wind speed_m s**-1 (max)_lambert_level 10
# Selected feature:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m_gt_5  with correlation:  0.01581643959690126
# Finding the best feature for group:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m
# Selected feature:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m_gt_18  with correlation:  -0.010666187923656862
# Finding the best feature for group:  Wind speed (gust)_m s**-1 (max)_lambert_level 10 m
# Selected feature:  Wind speed (gust)_m s**-1 (max)_lambert_level 10 m_gt_17  with correlation:  0.11082845661261395
# Finding the best feature for group:  221_221 (min)_lambert_levels 0-40000-filtered_2-me
# Selected feature:  221_221 (min)_lambert_levels 0-40000-filtered_2-mean_var  with correlation:  0.07586879828734265
# Selected feature:  221_221 (min)_lambert_levels 0-40000-filtered_2-mean_mean
# Finding the best feature for group:  HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-mi
# Selected feature:  HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-min_sum  with correlation:  0.013033613751111742
# Selected feature:  HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-min_mean
# Finding the best feature for group:  AIR_DENSITY kg/m3-filtered_2-mean
# Selected feature:  AIR_DENSITY kg/m3-filtered_2-mean_var  with correlation:  0.05846121329842999
# Selected feature:  AIR_DENSITY kg/m3-filtered_2-mean_mean
# Finding the best feature for group:  Snow depth_m (instant)_lambert_level 0-filtered_8-m
# Selected feature:  Snow depth_m (instant)_lambert_level 0-filtered_8-min_min  with correlation:  0.01665878515229188
# Selected feature:  Snow depth_m (instant)_lambert_level 0-filtered_8-max_mean
# Finding the best feature for group:  4_4 (max)_lambert_level 0-filtered_2-mea
# Selected feature:  4_4 (max)_lambert_level 0-filtered_2-mean_sum  with correlation:  0.1024864955331518
# Selected feature:  4_4 (max)_lambert_level 0-filtered_2-mean_mean
# Finding the best feature for group:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_16-m
# Selected feature:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_16-max_mean  with correlation:  0.024132155127247663
# Selected feature:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_16-mean_mean
# Finding the best feature for group:  Snow depth_m (instant)_lambert_level 0-filtered_8-me
# Selected feature:  Snow depth_m (instant)_lambert_level 0-filtered_8-mean_max  with correlation:  0.003997887374221971
# Selected feature:  Snow depth_m (instant)_lambert_level 0-filtered_8-mean_mean
# Finding the best feature for group:  Total cloud cover_% (instant)_lambert_level 0-filtered_16-m
# Selected feature:  Total cloud cover_% (instant)_lambert_level 0-filtered_16-max_mean  with correlation:  0.04007662838714078
# Selected feature:  Total cloud cover_% (instant)_lambert_level 0-filtered_16-mean_mean
# Finding the best feature for group:  2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_2
# Selected feature:  2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_2-max_var  with correlation:  0.05496577516977076
# Finding the best feature for group:  2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_2-
# Selected feature:  2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_2-mean_var  with correlation:  0.05412924119243907
# Finding the best feature for group:  Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_8-m
# Selected feature:  Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_8-mean_sum  with correlation:  0.07454445040838677
# Finding the best feature for group:  Total cloud cover_% (instant)_lambert_level 0-filtered_32-
# Selected feature:  Total cloud cover_% (instant)_lambert_level 0-filtered_32-max_min  with correlation:  0.04740480100441708
# Finding the best feature for group:  Total cloud cover_% (instant)_lambert_level 0-filtered_32-m
# Selected feature:  Total cloud cover_% (instant)_lambert_level 0-filtered_32-max_mean  with correlation:  0.042535897150834535
# Finding the best feature for group:  0_0 (instant)_lambert_level 0-filtered_16-ma
# Selected feature:  0_0 (instant)_lambert_level 0-filtered_16-max_sum  with correlation:  0.06483219229079329
# Selected feature:  0_0 (instant)_lambert_level 0-filtered_16-max_mean
# Finding the best feature for group:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_2
# Selected feature:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_24-max_max  with correlation:  0.02203630478999911
# Finding the best feature for group:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_24
# Selected feature:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_24-max_mean  with correlation:  0.011780777194823247
# Finding the best feature for group:  HOURLY_SNOW_ACCUM_RATE m/h-filtered_16-ma
# Selected feature:  HOURLY_SNOW_ACCUM_RATE m/h-filtered_16-max_max  with correlation:  0.0433689472483351
# Selected feature:  HOURLY_SNOW_ACCUM_RATE m/h-filtered_16-max_mean
# Finding the best feature for group:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/
# Selected feature:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h_max  with correlation:  0.0386258587083686
# Finding the best feature for group:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filte
# Selected feature:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filtered_24-max_var  with correlation:  0.04926851845477247
# Finding the best feature for group:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filter
# Selected feature:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filtered_16-mean_var  with correlation:  0.023681813248797437
# Finding the best feature for group:  Water equivalent of accumulated snow depth_kg m**-2 (instant)_lambert_level 0-filtered_
# Selected feature:  Water equivalent of accumulated snow depth_kg m**-2 (instant)_lambert_level 0-filtered_32-max_max  with correlation:  0.07972819892723484
# Selected feature:  Water equivalent of accumulated snow depth_kg m**-2 (instant)_lambert_level 0-filtered_8-mean_mean
# Finding the best feature for group:  AIR_DENSITY kg/m3-filtered_32-max
# Selected feature:  AIR_DENSITY kg/m3-filtered_32-max_var  with correlation:  0.02285090873874907
# Selected feature:  AIR_DENSITY kg/m3-filtered_32-max_mean
# Finding the best feature for group:  220_220 (max)_lambert_levels 0-40000-filtered_16-m
# Selected feature:  220_220 (max)_lambert_levels 0-40000-filtered_16-max_min  with correlation:  0.09031060475334449
# Selected feature:  220_220 (max)_lambert_levels 0-40000-filtered_16-max_mean
# Finding the best feature for group:  AIR_DENSITY kg/m3-filtered_8-max
# Selected feature:  AIR_DENSITY kg/m3-filtered_8-max_var  with correlation:  0.03657694967365748
# Selected feature:  AIR_DENSITY kg/m3-filtered_8-max_mean
# Finding the best feature for group:  HOURLY_SNOW_ACCUM_RATE m/h-filtered_8-mi
# Selected feature:  HOURLY_SNOW_ACCUM_RATE m/h-filtered_8-min_max  with correlation:  0.016792059910464792
# Selected feature:  HOURLY_SNOW_ACCUM_RATE m/h-filtered_8-min_mean
# Finding the best feature for group:  AIR_DENSITY kg/m3_
# Selected feature:  AIR_DENSITY kg/m3_var  with correlation:  0.060044288848027226
# Selected feature:  AIR_DENSITY kg/m3_mean
# Finding the best feature for group:  0_0 (instant)_lambert_level 0-filtered_2-mi
# Selected feature:  0_0 (instant)_lambert_level 0-filtered_2-min_sum  with correlation:  0.04214531473985174
# Selected feature:  0_0 (instant)_lambert_level 0-filtered_2-min_mean
# Finding the best feature for group:  GUST_FORCE N-filtered_32-max
# Selected feature:  GUST_FORCE N-filtered_32-max_sum  with correlation:  0.16643204574863116
# Selected feature:  GUST_FORCE N-filtered_32-max_mean
# Finding the best feature for group:  AIR_DENSITY kg/m3-filtered_2-min
# Selected feature:  AIR_DENSITY kg/m3-filtered_2-min_var  with correlation:  0.055440929558391513
# Selected feature:  AIR_DENSITY kg/m3-filtered_2-min_mean
# Finding the best feature for group:  10 metre U wind component_m s**-1 (instant)_lambert_level 10 m-filtered_
# Selected feature:  10 metre U wind component_m s**-1 (instant)_lambert_level 10 m-filtered_8-min_var  with correlation:  0.0411258746743427
# Finding the best feature for group:  10 metre U wind component_m s**-1 (instant)_lambert_level 10 m-filtered_2
# Selected feature:  10 metre U wind component_m s**-1 (instant)_lambert_level 10 m-filtered_24-min_var  with correlation:  0.07861971247001306
# Finding the best feature for group:  10 metre V wind component_m s**-1 (instant)_lambert_level 10 m-filtered_4
# Selected feature:  10 metre V wind component_m s**-1 (instant)_lambert_level 10 m-filtered_4-mean_var  with correlation:  -0.01212085087130814
# Selected feature:  10 metre V wind component_m s**-1 (instant)_lambert_level 10 m-filtered_4-mean_mean
# Finding the best feature for group:  Absolute vorticity_s**-1 (instant)_lambert_level 50000 Pa-filtered_8
# Selected feature:  Absolute vorticity_s**-1 (instant)_lambert_level 50000 Pa-filtered_8-max_sum  with correlation:  0.07274770902307005
# Finding the best feature for group:  Absolute vorticity_s**-1 (instant)_lambert_level 50000 Pa-filtered_8-
# Selected feature:  Absolute vorticity_s**-1 (instant)_lambert_level 50000 Pa-filtered_8-max_mean  with correlation:  0.0727477090230701
# Finding the best feature for group:  Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_1
# Selected feature:  Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_16-max_var  with correlation:  0.01327619637125883
# Finding the best feature for group:  Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_1
# Selected feature:  Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_16-max_sum  with correlation:  0.08456517541087098
# Finding the best feature for group:  Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_16
# Selected feature:  Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_16-max_mean  with correlation:  0.08456517541087094
# Finding the best feature for group:  GUST_FORCE N-filtered_16-max
# Selected feature:  GUST_FORCE N-filtered_16-max_sum  with correlation:  0.1499066536953515
# Selected feature:  GUST_FORCE N-filtered_16-max_mean
# Finding the best feature for group:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2
# Selected feature:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min_sum  with correlation:  0.0412603271571825
# Finding the best feature for group:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-
# Selected feature:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min_mean  with correlation:  0.04126032715718253
# Finding the best feature for group:  Hail_m (max)_lambert_level 0-filtered_24-mea
# Selected feature:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min_mean  with correlation:  -inf
# Selected feature:  Hail_m (max)_lambert_level 0-filtered_24-mean_mean
# Finding the best feature for group:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_32-
# Selected feature:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_32-max_var  with correlation:  0.03112691721212635
# Finding the best feature for group:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_32-m
# Selected feature:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_32-mean_var  with correlation:  0.03205614877554488
# Finding the best feature for group:  Snow depth_m (instant)_lambert_level 0-filtered_16-me
# Selected feature:  Snow depth_m (instant)_lambert_level 0-filtered_16-mean_max  with correlation:  0.0013879329598328067
# Selected feature:  Snow depth_m (instant)_lambert_level 0-filtered_16-mean_mean
# Finding the best feature for group:  WIND_FORCE N-filtered_32-min
# Selected feature:  WIND_FORCE N-filtered_32-min_sum  with correlation:  0.11616501512529595
# Selected feature:  WIND_FORCE N-filtered_32-min_mean
# Finding the best feature for group:  221_221 (min)_lambert_levels 0-40000-filtered_32-me
# Selected feature:  221_221 (min)_lambert_levels 0-40000-filtered_32-mean_var  with correlation:  0.07061815829814323
# Selected feature:  221_221 (min)_lambert_levels 0-40000-filtered_32-mean_mean
# Finding the best feature for group:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_
# Selected feature:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_2-min_min  with correlation:  0.006001092790112212
# Finding the best feature for group:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_32-
# Selected feature:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_32-max_max  with correlation:  0.13641526822820824
# Finding the best feature for group:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_32-m
# Selected feature:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_32-max_mean  with correlation:  0.07781664564214073
# Finding the best feature for group:  Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-
# Selected feature:  Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max_sum  with correlation:  0.11688772126400444
# Finding the best feature for group:  Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-m
# Selected feature:  Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max_mean  with correlation:  0.1168877212640045
# Finding the best feature for group:  Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_4-
# Selected feature:  Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_4-max_sum  with correlation:  0.07393460838893327
# Finding the best feature for group:  Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_4-m
# Selected feature:  Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_4-mean_sum  with correlation:  0.07615576180701077
# Finding the best feature for group:  4_4 (max)_lambert_level 0-filtered_16-ma
# Selected feature:  4_4 (max)_lambert_level 0-filtered_16-max_sum  with correlation:  0.09644107132118071
# Selected feature:  4_4 (max)_lambert_level 0-filtered_16-max_mean
# Finding the best feature for group:  Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_2
# Selected feature:  Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_24-max_var  with correlation:  0.013121538128696363
# Finding the best feature for group:  Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_3
# Selected feature:  Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_32-max_sum  with correlation:  0.07864689289771153
# Finding the best feature for group:  Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_32
# Selected feature:  Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_32-mean_sum  with correlation:  0.07981249630426121
# Finding the best feature for group:  Total column integrated water vapour_kg m**-2 (instant)_lambert_level 0-filtered_
# Selected feature:  Total column integrated water vapour_kg m**-2 (instant)_lambert_level 0-filtered_24-max_max  with correlation:  0.025431767270667486
# Finding the best feature for group:  0_0 (instant)_lambert_level 0-filtered_24-ma
# Selected feature:  0_0 (instant)_lambert_level 0-filtered_24-max_sum  with correlation:  0.06395212504330605
# Selected feature:  0_0 (instant)_lambert_level 0-filtered_24-max_mean
# Finding the best feature for group:  220_220 (max)_lambert_levels 0-40000-filtered_2-m
# Selected feature:  220_220 (max)_lambert_levels 0-40000-filtered_2-max_sum  with correlation:  0.09170442071203821
# Selected feature:  220_220 (max)_lambert_levels 0-40000-filtered_2-min_mean
# Finding the best feature for group:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filtere
# Selected feature:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filtered_24-mean_mean  with correlation:  0.01556025176906301
# Finding the best feature for group:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_8
# Selected feature:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_8-mean_min  with correlation:  0.006222345827073468
# Selected feature:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_8-mean_mean
# Finding the best feature for group:  220_220 (max)_lambert_levels 0-40000-filtered_4-m
# Selected feature:  220_220 (max)_lambert_levels 0-40000-filtered_4-max_sum  with correlation:  0.09158400074719535
# Selected feature:  220_220 (max)_lambert_levels 0-40000-filtered_4-max_mean
# Finding the best feature for group:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-m
# Selected feature:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-mean_var  with correlation:  0.041293675343239813
# Finding the best feature for group:  HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_16-ma
# Selected feature:  HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_16-max_max  with correlation:  0.06339194611895829
# Finding the best feature for group:  221_221 (min)_lambert_levels 0-40000-filtered_2-m
# Selected feature:  221_221 (min)_lambert_levels 0-40000-filtered_2-min_var  with correlation:  0.07710251856578214
# Selected feature:  221_221 (min)_lambert_levels 0-40000-filtered_2-max_mean
# Finding the best feature for group:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filt
# Selected feature:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filtered_8-max_max  with correlation:  0.03766824140721883
# Finding the best feature for group:  Snow depth_m (instant)_lambert_level 0-filtered_2-me
# Selected feature:  Snow depth_m (instant)_lambert_level 0-filtered_2-mean_max  with correlation:  0.00964331356476309
# Selected feature:  Snow depth_m (instant)_lambert_level 0-filtered_2-mean_mean
# Finding the best feature for group:  Surface pressure_Pa (instant)_lambert_level 0-filtered_2-m
# Selected feature:  Surface pressure_Pa (instant)_lambert_level 0-filtered_2-mean_var  with correlation:  0.09122149990946547
# Selected feature:  Surface pressure_Pa (instant)_lambert_level 0-filtered_2-mean_mean
# Finding the best feature for group:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_3
# Selected feature:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_32-max_max  with correlation:  0.023079555738967004
# Finding the best feature for group:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_32
# Selected feature:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_32-max_mean  with correlation:  0.012799792534692505
# Finding the best feature for group:  Hail_m (max)_lambert_level 0 10-filtered_8-ma
# Selected feature:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_32-max_mean  with correlation:  -inf
# Finding the best feature for group:  HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_2-ma
# Selected feature:  HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_2-max_max  with correlation:  0.04361970990491683
# Selected feature:  HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_2-max_mean
# Finding the best feature for group:  GUST_FORCE N-filtered_24-mean
# Selected feature:  GUST_FORCE N-filtered_24-mean_sum  with correlation:  0.13116356858431846
# Selected feature:  GUST_FORCE N-filtered_24-mean_mean
# Finding the best feature for group:  Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_
# Selected feature:  Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_4-min_max  with correlation:  0.014482370686973384
# Finding the best feature for group:  Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_8
# Selected feature:  Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_8-mean_var  with correlation:  0.011882629643061509
# Finding the best feature for group:  HOURLY_WET_SNOW_ACCUM_RATE m/h
# Selected feature:  HOURLY_WET_SNOW_ACCUM_RATE m/h_max  with correlation:  0.04371231201591448
# Selected feature:  HOURLY_WET_SNOW_ACCUM_RATE m/h_mean
# Finding the best feature for group:  WIND_FORCE N-filtered_16-min
# Selected feature:  WIND_FORCE N-filtered_16-min_sum  with correlation:  0.1040472056233898
# Selected feature:  WIND_FORCE N-filtered_16-min_mean
# Finding the best feature for group:  199_199 (max)_lambert_levels 5000-2000 m-filtered_24-m
# Selected feature:  199_199 (max)_lambert_levels 5000-2000 m-filtered_24-max_sum  with correlation:  0.04853260316588434
# Finding the best feature for group:  Convective available potential energy_J kg-1 (instant)_lambert_levels 25500
# Selected feature:  Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa_max  with correlation:  0.010449084768076293
# Selected feature:  Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa_mean
# Finding the best feature for group:  2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_16
# Selected feature:  2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_16-min_var  with correlation:  0.02351437216042709
# Finding the best feature for group:  2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_16-
# Selected feature:  2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_16-mean_var  with correlation:  0.05146840055003138
# Finding the best feature for group:  WIND_FORCE N-filtered_16-mean
# Selected feature:  WIND_FORCE N-filtered_16-mean_sum  with correlation:  0.06280824305886387
# Selected feature:  WIND_FORCE N-filtered_16-mean_mean
# Finding the best feature for group:  74_74 (max)_lambert_level 0 200-filtered_4-mi
# Selected feature:  74_74 (max)_lambert_level 0 200-filtered_4-min_mean  with correlation:  0.059459565185167894
# Finding the best feature for group:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_2-
# Selected feature:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_2-min_var  with correlation:  0.05888077646370564
# Finding the best feature for group:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_2-m
# Selected feature:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_2-mean_var  with correlation:  0.06216705576044883
# Selected feature:  WIND_FORCE N_sum
# Selected feature:  WIND_FORCE N_mean
# Finding the best feature for group:  WIND_FORCE N_m
# Selected feature:  WIND_FORCE N_min  with correlation:  -0.006578237975613131
# Selected feature:  WIND_FORCE N_var
# Finding the best feature for group:  AIR_DENSITY kg/m3-filtered_32-mean
# Selected feature:  AIR_DENSITY kg/m3-filtered_32-mean_var  with correlation:  0.04347823536307249
# Selected feature:  AIR_DENSITY kg/m3-filtered_32-mean_mean
# Finding the best feature for group:  Surface pressure_Pa (instant)_lambert_level 0-filtered_24-m
# Selected feature:  Surface pressure_Pa (instant)_lambert_level 0-filtered_24-mean_var  with correlation:  0.09174301252278326
# Selected feature:  Surface pressure_Pa (instant)_lambert_level 0-filtered_24-mean_mean
# Finding the best feature for group:  Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_4
# Selected feature:  Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_4-max_max  with correlation:  0.02526930755338811
# Finding the best feature for group:  Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_4-
# Selected feature:  Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_4-mean_max  with correlation:  0.019942496188541072
# Finding the best feature for group:  2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_32
# Selected feature:  2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_32-min_var  with correlation:  0.004032531048064118
# Finding the best feature for group:  2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_32-
# Selected feature:  2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_32-mean_var  with correlation:  0.030387444920024407
# Finding the best feature for group:  10 metre U wind component_m s**-1 (instant)_lambert_level 10 m-filtered_3
# Selected feature:  10 metre U wind component_m s**-1 (instant)_lambert_level 10 m-filtered_32-min_var  with correlation:  0.0772038011225613
# Finding the best feature for group:  10 metre U wind component_m s**-1 (instant)_lambert_level 10 m-filtered_32
# Selected feature:  10 metre U wind component_m s**-1 (instant)_lambert_level 10 m-filtered_32-mean_var  with correlation:  0.04103883684750741
# Finding the best feature for group:  HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-ma
# Selected feature:  HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-max_max  with correlation:  0.05249585142113856
# Selected feature:  HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-max_mean
# Finding the best feature for group:  199_199 (max)_lambert_levels 5000-2000 m-filtered_4-m
# Selected feature:  199_199 (max)_lambert_levels 5000-2000 m-filtered_4-max_max  with correlation:  0.04095306001821926
# Selected feature:  199_199 (max)_lambert_levels 5000-2000 m-filtered_4-min_mean
# Finding the best feature for group:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-
# Selected feature:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-max_mean  with correlation:  0.11911454566940433
# Selected feature:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean_mean
# Finding the best feature for group:  221_221 (min)_lambert_levels 0-40000-filtered_8-m
# Selected feature:  221_221 (min)_lambert_levels 0-40000-filtered_8-min_var  with correlation:  0.07715754075075991
# Selected feature:  221_221 (min)_lambert_levels 0-40000-filtered_8-max_mean
# Finding the best feature for group:  220_220 (max)_lambert_levels 0-40000
# Selected feature:  220_220 (max)_lambert_levels 0-40000_mean  with correlation:  0.08334169523303174
# Finding the best feature for group:  Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_32
# Selected feature:  Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_32-max_max  with correlation:  0.03507303435520341
# Finding the best feature for group:  Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_32-
# Selected feature:  Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_32-mean_max  with correlation:  0.01629196046456623
# Finding the best feature for group:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_24-
# Selected feature:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_24-max_var  with correlation:  0.031343304019783955
# Finding the best feature for group:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_24-m
# Selected feature:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_24-mean_var  with correlation:  0.03402027744966196
# Finding the best feature for group:  220_220 (max)_lambert_levels 0-40000-filtered_24-m
# Selected feature:  220_220 (max)_lambert_levels 0-40000-filtered_24-max_min  with correlation:  0.0918880449132489
# Selected feature:  220_220 (max)_lambert_levels 0-40000-filtered_24-max_mean
# Finding the best feature for group:  HOURLY_SNOW_ACCUM_RATE m/h-filtered_32-mea
# Selected feature:  HOURLY_SNOW_ACCUM_RATE m/h-filtered_32-mean_max  with correlation:  0.04058621847945204
# Selected feature:  HOURLY_SNOW_ACCUM_RATE m/h-filtered_32-mean_mean
# Finding the best feature for group:  WIND_FORCE N-filtered_16-max
# Selected feature:  WIND_FORCE N-filtered_16-max_sum  with correlation:  0.10880751654688983
# Selected feature:  WIND_FORCE N-filtered_16-max_mean
# Finding the best feature for group:  Total precipitation_kg m-2 (accum)_lambert_level
# Selected feature:  Total precipitation_kg m-2 (accum)_lambert_level 0_sum  with correlation:  0.07688416092553184
# Selected feature:  Total precipitation_kg m-2 (accum)_lambert_level 0_mean
# Finding the best feature for group:  Hail_m (max)_lambert_level 0-filtered_8-mea
# Selected feature:  Total precipitation_kg m-2 (accum)_lambert_level 0_sum  with correlation:  -inf
# Selected feature:  Hail_m (max)_lambert_level 0-filtered_8-mean_mean
# Finding the best feature for group:  2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_24
# Selected feature:  2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_24-max_var  with correlation:  0.023633055928859698
# Finding the best feature for group:  2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_24-
# Selected feature:  2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_24-mean_var  with correlation:  0.031855013231825303
# Finding the best feature for group:  4_4 (max)_lambert_level 0-filtered_24-mea
# Selected feature:  4_4 (max)_lambert_level 0-filtered_24-mean_sum  with correlation:  0.10006284600903076
# Selected feature:  4_4 (max)_lambert_level 0-filtered_24-mean_mean
# Finding the best feature for group:  Hail_m (max)_lambert_level 0-filtered_24-mi
# Selected feature:  4_4 (max)_lambert_level 0-filtered_24-mean_sum  with correlation:  -inf
# Selected feature:  Hail_m (max)_lambert_level 0-filtered_24-min_mean
# Finding the best feature for group:  AIR_DENSITY kg/m3-filtered_24-max
# Selected feature:  AIR_DENSITY kg/m3-filtered_24-max_var  with correlation:  0.023202790730483532
# Selected feature:  AIR_DENSITY kg/m3-filtered_24-max_mean
# Finding the best feature for group:  221_221 (min)_lambert_levels 0-40000-filtered_32-m
# Selected feature:  221_221 (min)_lambert_levels 0-40000-filtered_32-min_var  with correlation:  0.06959491394101727
# Selected feature:  221_221 (min)_lambert_levels 0-40000-filtered_32-max_mean
# Finding the best feature for group:  HOURLY_SNOW_ACCUM_RATE m/h-filtered_32-mi
# Selected feature:  221_221 (min)_lambert_levels 0-40000-filtered_32-min_var  with correlation:  -inf
# Selected feature:  HOURLY_SNOW_ACCUM_RATE m/h-filtered_32-min_mean
# Finding the best feature for group:  Hail_m (max)_lambert_level 0 10-filtered_8-me
# Selected feature:  221_221 (min)_lambert_levels 0-40000-filtered_32-min_var  with correlation:  -inf
# Selected feature:  Hail_m (max)_lambert_level 0 10-filtered_8-mean_mean
# Finding the best feature for group:  Total cloud cover_% (instant)_lambert_level 0-filtered_24-
# Selected feature:  Total cloud cover_% (instant)_lambert_level 0-filtered_24-max_sum  with correlation:  0.04142902807709231
# Finding the best feature for group:  Total cloud cover_% (instant)_lambert_level 0-filtered_24-m
# Selected feature:  Total cloud cover_% (instant)_lambert_level 0-filtered_24-max_mean  with correlation:  0.04142902807709239
# Finding the best feature for group:  Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_2-m
# Selected feature:  Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_2-mean_sum  with correlation:  0.07666672320365842
# Finding the best feature for group:  Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_8
# Selected feature:  Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_8-max_mean  with correlation:  0.08007360287570674
# Selected feature:  Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_8-mean_mean
# Finding the best feature for group:  AIR_DENSITY kg/m3-filtered_8-min
# Selected feature:  AIR_DENSITY kg/m3-filtered_8-min_var  with correlation:  0.050943335060288746
# Selected feature:  AIR_DENSITY kg/m3-filtered_8-min_mean
# Finding the best feature for group:  GUST_FORCE N-filtered_2-mean
# Selected feature:  GUST_FORCE N-filtered_2-mean_sum  with correlation:  0.10900185868899524
# Selected feature:  GUST_FORCE N-filtered_2-mean_mean
# Finding the best feature for group:  10 metre V wind component_m s**-1 (instant)_lambert_level 10 m-filtered_
# Selected feature:  10 metre V wind component_m s**-1 (instant)_lambert_level 10 m-filtered_8-min_var  with correlation:  0.018698358502032775
# Finding the best feature for group:  Hail_m (max)_lambert_level 0-filtered_2-ma
# Selected feature:  10 metre V wind component_m s**-1 (instant)_lambert_level 10 m-filtered_8-min_var  with correlation:  -inf
# Selected feature:  Hail_m (max)_lambert_level 0-filtered_2-max_mean
# Selected feature:  2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_32-mean_mean
# Finding the best feature for group:  HOURLY_SNOW_ACCUM_RATE m/h-filtered_24-mea
# Selected feature:  HOURLY_SNOW_ACCUM_RATE m/h-filtered_24-mean_max  with correlation:  0.025490691936368753
# Selected feature:  HOURLY_SNOW_ACCUM_RATE m/h-filtered_24-mean_mean
# Finding the best feature for group:  74_74 (max)_lambert_level 0 200-filtered_32-m
# Selected feature:  74_74 (max)_lambert_level 0 200-filtered_32-max_var  with correlation:  0.07324055992702531
# Selected feature:  74_74 (max)_lambert_level 0 200-filtered_32-min_mean
# Finding the best feature for group:  Hail_m (max)_lambert_level 0-filtered_4-mi
# Selected feature:  74_74 (max)_lambert_level 0 200-filtered_32-max_var  with correlation:  -inf
# Selected feature:  Hail_m (max)_lambert_level 0-filtered_4-min_mean
# Finding the best feature for group:  Hail_m (max)_lambert_level 0 10-filtered_24-me
# Selected feature:  74_74 (max)_lambert_level 0 200-filtered_32-max_var  with correlation:  -inf
# Selected feature:  Hail_m (max)_lambert_level 0 10-filtered_24-mean_mean
# Finding the best feature for group:  Hail_m (max)_lambert_level 0
# Selected feature:  74_74 (max)_lambert_level 0 200-filtered_32-max_var  with correlation:  -inf
# Selected feature:  Hail_m (max)_lambert_level 0_mean
# Finding the best feature for group:  220_220 (max)_lambert_levels 0-40000-filtered_8-m
# Selected feature:  220_220 (max)_lambert_levels 0-40000-filtered_8-max_sum  with correlation:  0.08894913780831726
# Selected feature:  220_220 (max)_lambert_levels 0-40000-filtered_8-min_mean
# Finding the best feature for group:  Water equivalent of accumulated snow depth_kg m**-2 (instant)_lambert_level 0-filtered
# Selected feature:  Water equivalent of accumulated snow depth_kg m**-2 (instant)_lambert_level 0-filtered_8-min_max  with correlation:  0.01579877353657188
# Finding the best feature for group:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-
# Selected feature:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-max_var  with correlation:  0.035200079980087944
# Finding the best feature for group:  Total column integrated water vapour_kg m**-2 (instant)_lambert_level 0-filtered_3
# Selected feature:  Total column integrated water vapour_kg m**-2 (instant)_lambert_level 0-filtered_32-mean_var  with correlation:  0.018741911224719708
# Finding the best feature for group:  2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_32
# Selected feature:  2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_32-max_var  with correlation:  0.022609620839604258
# Finding the best feature for group:  2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_32-
# Selected feature:  2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_32-mean_var  with correlation:  0.02791201037740464
# Finding the best feature for group:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_8-m
# Selected feature:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_8-mean_var  with correlation:  0.053657454865932555
# Selected feature:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_8-mean_mean
# Finding the best feature for group:  0_0 (instant)_lambert_level 0-filtered_4-ma
# Selected feature:  0_0 (instant)_lambert_level 0-filtered_4-max_sum  with correlation:  0.05657037606097078
# Selected feature:  0_0 (instant)_lambert_level 0-filtered_4-max_mean
# Finding the best feature for group:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_16
# Selected feature:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_16-max_mean  with correlation:  0.009071000327680559
# Selected feature:  Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_16-mean_mean
# Finding the best feature for group:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-
# Selected feature:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max_mean  with correlation:  0.12167938308663258
# Selected feature:  10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean_mean
# Finding the best feature for group:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_4-
# Selected feature:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_4-min_var  with correlation:  0.051037408532924634
# Finding the best feature for group:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_4-m
# Selected feature:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_4-mean_var  with correlation:  0.059376476591710144
# Finding the best feature for group:  Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-
# Selected feature:  Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max_min  with correlation:  0.10609024364838844
# Finding the best feature for group:  Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-m
# Selected feature:  Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max_mean  with correlation:  0.1056921405808553
# Finding the best feature for group:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_8-
# Selected feature:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_8-max_var  with correlation:  0.04285597366201445
# Finding the best feature for group:  AIR_DENSITY kg/m3-filtered_16-mean
# Selected feature:  AIR_DENSITY kg/m3-filtered_16-mean_var  with correlation:  0.04765444885888525
# Selected feature:  AIR_DENSITY kg/m3-filtered_16-mean_mean
# Finding the best feature for group:  Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_
# Selected feature:  Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_32-max_max  with correlation:  0.01702589600084808
# Finding the best feature for group:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert
# Selected feature:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0_max  with correlation:  0.024177611974950414
# Finding the best feature for group:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_4-m
# Selected feature:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_4-mean_max  with correlation:  0.03495339310902954
# Selected feature:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_4-mean_mean
# Finding the best feature for group:  Hail_m (max)_lambert_level 0 10-filtered_32-m
# Selected feature:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_4-mean_max  with correlation:  -inf
# Selected feature:  Hail_m (max)_lambert_level 0 10-filtered_32-max_mean
# Finding the best feature for group:  HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-mea
# Selected feature:  HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-mean_max  with correlation:  0.0354616144950895
# Finding the best feature for group:  GUST_FORCE N-filtered_8-max
# Selected feature:  GUST_FORCE N-filtered_8-max_sum  with correlation:  0.12636996308870732
# Selected feature:  GUST_FORCE N-filtered_8-max_mean
# Finding the best feature for group:  Snow depth_m (instant)_lambert_level 0-filtered_24-me
# Selected feature:  Snow depth_m (instant)_lambert_level 0-filtered_24-mean_max  with correlation:  0.004784021709600366
# Selected feature:  Snow depth_m (instant)_lambert_level 0-filtered_24-mean_mean
# Finding the best feature for group:  Hail_m (max)_lambert_level 0-filtered_16-mea
# Selected feature:  Snow depth_m (instant)_lambert_level 0-filtered_24-mean_max  with correlation:  -inf
# Selected feature:  Hail_m (max)_lambert_level 0-filtered_16-mean_mean
# Finding the best feature for group:  Surface pressure_Pa (instant)_lambert_level 0-filtered_16-m
# Selected feature:  Surface pressure_Pa (instant)_lambert_level 0-filtered_16-mean_var  with correlation:  0.09160390047269162
# Selected feature:  Surface pressure_Pa (instant)_lambert_level 0-filtered_16-mean_mean
# Finding the best feature for group:  4_4 (max)_lambert_level 0-filtered_32-mi
# Selected feature:  4_4 (max)_lambert_level 0-filtered_32-min_sum  with correlation:  0.08493884651421947
# Selected feature:  4_4 (max)_lambert_level 0-filtered_32-min_mean
# Finding the best feature for group:  AIR_DENSITY kg/m3-filtered_24-min
# Selected feature:  AIR_DENSITY kg/m3-filtered_24-min_var  with correlation:  0.04845197698959815
# Selected feature:  AIR_DENSITY kg/m3-filtered_24-min_mean
# Finding the best feature for group:  Surface pressure_Pa (instant)_lambert_level 0-filtered_24-
# Selected feature:  Surface pressure_Pa (instant)_lambert_level 0-filtered_24-max_var  with correlation:  0.09263047340974542
# Finding the best feature for group:  Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_24-
# Selected feature:  Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_24-mean_sum  with correlation:  0.0723710402048334
# Selected feature:  Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_24-mean_mean
# Finding the best feature for group:  Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_24
# Selected feature:  Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_24-max_max  with correlation:  0.037873312970596915
# Finding the best feature for group:  Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_24-
# Selected feature:  Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_24-mean_max  with correlation:  0.01441518017841318
# Finding the best feature for group:  Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_32-
# Selected feature:  Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_32-mean_sum  with correlation:  0.07390762076229647
# Finding the best feature for group:  199_199 (max)_lambert_levels 5000-2000 m-filtered_16-m
# Selected feature:  199_199 (max)_lambert_levels 5000-2000 m-filtered_16-max_max  with correlation:  0.05063987585033072
# Finding the best feature for group:  Snow depth_m (instant)_lambert_level 0-filtered_2-m
# Selected feature:  Snow depth_m (instant)_lambert_level 0-filtered_2-min_max  with correlation:  0.014347426882420702
# Selected feature:  Snow depth_m (instant)_lambert_level 0-filtered_2-min_mean
# Finding the best feature for group:  199_199 (max)_lambert_levels 5000-2000 m-filtered_8-m
# Selected feature:  199_199 (max)_lambert_levels 5000-2000 m-filtered_8-max_max  with correlation:  0.046866494133312925
# Selected feature:  199_199 (max)_lambert_levels 5000-2000 m-filtered_8-max_mean
# Finding the best feature for group:  221_221 (min)_lambert_levels 0-40000-filtered_16-m
# Selected feature:  221_221 (min)_lambert_levels 0-40000-filtered_16-min_var  with correlation:  0.07912736663650576
# Selected feature:  221_221 (min)_lambert_levels 0-40000-filtered_16-min_mean
# Finding the best feature for group:  74_74 (max)_lambert_level 0 200-filtered_16-m
# Selected feature:  74_74 (max)_lambert_level 0 200-filtered_16-max_var  with correlation:  0.07876507653947891
# Selected feature:  74_74 (max)_lambert_level 0 200-filtered_16-max_mean
# Finding the best feature for group:  Snow depth_m (instant)_lambert_level
# Selected feature:  Snow depth_m (instant)_lambert_level 0_max  with correlation:  0.012191508542241812
# Selected feature:  Snow depth_m (instant)_lambert_level 0_mean
# Finding the best feature for group:  AIR_DENSITY kg/m3-filtered_24-mean
# Selected feature:  AIR_DENSITY kg/m3-filtered_24-mean_var  with correlation:  0.04419425597343142
# Selected feature:  AIR_DENSITY kg/m3-filtered_24-mean_mean
# Finding the best feature for group:  2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_4
# Selected feature:  2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_4-max_var  with correlation:  0.05198072078139384
# Finding the best feature for group:  2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_4-
# Selected feature:  2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_4-mean_var  with correlation:  0.05112968712305494
# Finding the best feature for group:  10 metre V wind component_m s**-1 (instant)_lambert_level 10 m-filtered_2
# Selected feature:  10 metre V wind component_m s**-1 (instant)_lambert_level 10 m-filtered_24-max_var  with correlation:  0.05484221680161469
# Finding the best feature for group:  10 metre V wind component_m s**-1 (instant)_lambert_level 10 m-filtered_24
# Selected feature:  10 metre V wind component_m s**-1 (instant)_lambert_level 10 m-filtered_24-mean_var  with correlation:  0.031112922983047086
# Finding the best feature for group:  Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered
# Selected feature:  Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_8-min_max  with correlation:  0.013799949802123849
# Finding the best feature for group:  0_0 (instant)_lambert_level 0-filtered_8-mea
# Selected feature:  0_0 (instant)_lambert_level 0-filtered_8-mean_sum  with correlation:  0.05120481383184289
# Selected feature:  0_0 (instant)_lambert_level 0-filtered_8-mean_mean
# Finding the best feature for group:  Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-m
# Selected feature:  Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean_min  with correlation:  0.1026713853138025
# Finding the best feature for group:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_16-
# Selected feature:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_16-max_max  with correlation:  0.05795339689936081
# Finding the best feature for group:  Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_
# Selected feature:  Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_24-max_sum  with correlation:  0.14064384485479844
# Finding the best feature for group:  Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_2
# Selected feature:  Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_24-max_mean  with correlation:  0.14064384485479847
# Finding the best feature for group:  4_4 (max)_lambert_level 0-filtered_32-mea
# Selected feature:  4_4 (max)_lambert_level 0-filtered_32-mean_sum  with correlation:  0.09939718814147536
# Selected feature:  4_4 (max)_lambert_level 0-filtered_32-mean_mean
# Finding the best feature for group:  220_220 (max)_lambert_levels 0-40000-filtered_32-m
# ...
#  'Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa_3_hour_variation_max',
#  'Surface pressure_Pa (instant)_lambert_level 0-filtered_4-max_3_hour_variation_max',
#  '2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_32-min_3_hour_variation_min',
#  'Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_16-max_3_hour_variation_max',
#  'Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_2-mean_3_hour_variation_max',
#  'Surface pressure_Pa (instant)_lambert_level 0-filtered_8-min_3_hour_variation_max',
#  'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_32-min_3_hour_variation_min',
#  '2 metre temperature_K (instant)_lambert_level 2 m-filtered_32-max_3_hour_variation_max',
#  '2 metre temperature_K (instant)_lambert_level 2 m-filtered_2-min_3_hour_variation_max',
#  '2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_8-max_3_hour_variation_max',
#  'Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_2-max_3_hour_variation_max',
#  'Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_16-mean_3_hour_variation_max',
#  'Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_4-min_3_hour_variation_max',
#  'Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_24-min_3_hour_variation_max',
#  'Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_8-min_3_hour_variation_max',
#  '2 metre relative humidity_% (instant)_lambert_level 2 m_3_hour_variation_max',
#  '2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-max_3_hour_variation_max',
#  'Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_8-mean_3_hour_variation_max',
#  '2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-mean_3_hour_variation_max',
#  'Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_16-max_3_hour_variation_max',
#  'Surface pressure_Pa (instant)_lambert_level 0-filtered_16-max_3_hour_variation_max',
#  'Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_32-max_3_hour_variation_max',
#  'Surface pressure_Pa (instant)_lambert_level 0-filtered_2-mean_3_hour_variation_max',
#  'Surface pressure_Pa (instant)_lambert_level 0_3_hour_variation_max',
#  'Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_8-mean_3_hour_variation_max',
#  '2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_8-mean_3_hour_variation_max',
#  'Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_4-min_3_hour_variation_max',
#  '2 metre temperature_K (instant)_lambert_level 2 m-filtered_2-mean_3_hour_variation_max',
#  '2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_8-mean_3_hour_variation_max',
#  '2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_24-min_3_hour_variation_min',
#  'Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_8-max_3_hour_variation_max',
#  'Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_16-min_3_hour_variation_max',
#  'Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_4-max_3_hour_variation_max',
#  'Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa_3_hour_variation_max',
#  'Surface pressure_Pa (instant)_lambert_level 0-filtered_8-max_3_hour_variation_max',
#  '2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_16-max_3_hour_variation_min',
#  '2 metre dewpoint temperature_K (instant)_lambert_level 2 m_3_hour_variation_max',
#  '2 metre temperature_K (instant)_lambert_level 2 m-filtered_2-max_3_hour_variation_max',
#  'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_4-max_3_hour_variation_max',
#  'Surface pressure_Pa (instant)_lambert_level 0-filtered_24-mean_3_hour_variation_max',
#  'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_4-min_3_hour_variation_max',
#  '2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_32-max_3_hour_variation_max',
#  '2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_32-max_3_hour_variation_min',
#  '2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_24-max_3_hour_variation_max',
#  'Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_24-max_3_hour_variation_max',
#  'Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_16-min_3_hour_variation_min',
#  'Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_2-mean_3_hour_variation_max',
#  'Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_2-max_3_hour_variation_max',
#  '2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_24-max_3_hour_variation_min',
#  'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_32-max_3_hour_variation_max',
#  '2 metre temperature_K (instant)_lambert_level 2 m-filtered_24-min_3_hour_variation_min',
#  'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_24-mean_3_hour_variation_max',
#  'Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_32-mean_3_hour_variation_max',
#  '2 metre temperature_K (instant)_lambert_level 2 m-filtered_4-max_3_hour_variation_max',
#  'Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_32-max_3_hour_variation_max',
#  'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_24-max_3_hour_variation_max',
#  '2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_2-min_3_hour_variation_max',
#  'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_8-max_3_hour_variation_max',
#  'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_2-max_3_hour_variation_max',
#  'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_4-mean_3_hour_variation_max',
#  '2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_24-min_3_hour_variation_min',
#  'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_8-min_3_hour_variation_min',
#  'Surface pressure_Pa (instant)_lambert_level 0-filtered_2-max_3_hour_variation_max',
#  '2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_4-max_3_hour_variation_max',
#  '2 metre temperature_K (instant)_lambert_level 2 m_3_hour_variation_max',
#  'Surface pressure_Pa (instant)_lambert_level 0-filtered_4-mean_3_hour_variation_max',
#  '2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_16-min_3_hour_variation_min',
#  'Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_8-min_3_hour_variation_min',
#  'Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_24-mean_3_hour_variation_max',
#  'Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_8-max_3_hour_variation_max',
#  'Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_4-mean_3_hour_variation_max',
#  'Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_8-min_3_hour_variation_max',
#  '2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_8-max_3_hour_variation_max',
#  'Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_24-mean_3_hour_variation_min',
#  'Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_2-min_3_hour_variation_max',
#  '2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_4-mean_3_hour_variation_max',
#  '2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_32-mean_3_hour_variation_min',
#  'Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_32-min_3_hour_variation_min',
#  '2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-min_3_hour_variation_min',
#  '2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_32-min_3_hour_variation_min',
#  'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_2-mean_3_hour_variation_max',
#  '2 metre temperature_K (instant)_lambert_level 2 m-filtered_8-mean_3_hour_variation_max',
#  'Surface pressure_Pa (instant)_lambert_level 0-filtered_32-max_3_hour_variation_max',
#  'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_16-min_3_hour_variation_min',
#  'Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_16-mean_3_hour_variation_min',
#  'Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_8-mean_3_hour_variation_max',
#  'Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_24-min_3_hour_variation_max',
#  '2 metre temperature_K (instant)_lambert_level 2 m-filtered_4-min_3_hour_variation_max',
#  '2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_2-mean_3_hour_variation_max',
#  '2 metre temperature_K (instant)_lambert_level 2 m-filtered_8-max_3_hour_variation_max',
#  'Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_4-max_3_hour_variation_max',
#  'Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_32-max_3_hour_variation_max',
#  '2 metre temperature_K (instant)_lambert_level 2 m-filtered_32-mean_3_hour_variation_max',
#  '2 metre temperature_K (instant)_lambert_level 2 m-filtered_4-mean_3_hour_variation_max',
#  'Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_32-min_3_hour_variation_max',
#  'Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_32-mean_3_hour_variation_min',
#  'Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_2-mean_3_hour_variation_max',
#  '2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_2-max_3_hour_variation_max',
#  'Surface pressure_Pa (instant)_lambert_level 0-filtered_16-mean_3_hour_variation_max',
#  '2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_24-mean_3_hour_variation_min',
#  'Convective inhibition_J kg-1 (instant)_lambert_level 0_3_hour_variation_max',
#  'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_32-mean_3_hour_variation_max',
#  'Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_24-max_3_hour_variation_max',
#  'Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_16-min_3_hour_variation_max',
#  'Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_4-mean_3_hour_variation_max',
#  'Surface pressure_Pa (instant)_lambert_level 0-filtered_24-min_3_hour_variation_max',
#  'Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_8-max_3_hour_variation_max',
#  'Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_16-max_3_hour_variation_max',
#  'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_8-mean_3_hour_variation_max',
#  'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_24-min_3_hour_variation_min',
#  'Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_32-min_3_hour_variation_max',
#  '2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_8-min_3_hour_variation_min',
#  'Convective available potential energy_J kg-1 (instant)_lambert_level 0-filtered_32-mean_3_hour_variation_max',
#  'Surface pressure_Pa (instant)_lambert_level 0-filtered_4-min_3_hour_variation_max',
#  '2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_8-min_3_hour_variation_max',
#  'Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_24-mean_3_hour_variation_max',
#  'Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_4-mean_3_hour_variation_max',
#  '2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_4-min_3_hour_variation_max',
#  'Convective inhibition_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_4-max_3_hour_variation_max',
#  '2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_16-mean_3_hour_variation_max',
#  'Surface pressure_Pa (instant)_lambert_level 0-filtered_24-max_3_hour_variation_max',
#  'Surface pressure_Pa (instant)_lambert_level 0-filtered_32-min_3_hour_variation_max',
#  'Surface pressure_Pa (instant)_lambert_level 0-filtered_32-mean_3_hour_variation_max',
#  '2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_4-mean_3_hour_variation_max',
#  '2 metre temperature_K (instant)_lambert_level 2 m-filtered_24-mean_3_hour_variation_max',
#  'Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_2-min_3_hour_variation_max',
#  '2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_4-max_3_hour_variation_max',
#  'Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_2-max_3_hour_variation_max',
#  'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_2-min_3_hour_variation_max',
#  'Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_4-min_3_hour_variation_max',
#  'Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_16-mean_3_hour_variation_max',
#  '2 metre temperature_K (instant)_lambert_level 2 m-filtered_8-min_3_hour_variation_max',
#  '2 metre temperature_K (instant)_lambert_level 2 m-filtered_32-min_3_hour_variation_min',
#  '2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_4-min_3_hour_variation_min',
#  '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-5)^2',
#  '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-10)^2',
#  '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max-5)^2',
#  '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max-10)^2',
#  '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max-15)^2',
#  '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-20)^2',
#  '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max-5)^2',
#  '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max-10)^2',
#  '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-max-5)^2',
#  '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-max-15)^2',
#  '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-min-5)^2',
#  '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max-15)^1',
#  '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min-10)^1',
#  '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-10)^1',
#  '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-max-5)^2',
#  '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-max-15)^2',
#  '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-max-15)^1',
#  '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-10)^1',
#  '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-min-5)^2',
#  '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-0)^1',
#  '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-20)^2',
#  '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-min-5)^1',
#  '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-max-15)^1',
#  '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-10)^2',
#  '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-max-5)^2',
#  '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-max-15)^2',
#  '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-max-5)^2',
#  '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-max-10)^2',
#  '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-15)^2',
#  '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-10)^2',
#  '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min-0)^1',
#  '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-15)^2',
#  ...]
