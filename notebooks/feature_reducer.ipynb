# %%
import pandas as pd

# %%
# read list of values from features.csv
features = pd.read_csv('../features.csv', header=None)
feature_list = features.values.tolist()
unique_features = features[0].unique().tolist()
print('Number of features: ', len(feature_list))
print('Number of unique features: ', len(unique_features))
# Out:
# Number of features:  4110
# Number of unique features:  4110

# %%
def get_str_prfx(s, pct):
    if len(s) > 1:
        index = int(len(s)*pct)
        return s[:index]
    else:
        return s

# %%
# Load your dataset
data = pd.read_parquet(path='../outage_data.parquet', engine='pyarrow')

# apply ordinal encoding to 'poly_ewkt', 'point_ewkt', 'event_type' columns
non_numerical_columns = ['poly_ewkt', 'event_type']

for column in non_numerical_columns:
    data[column] = data[column].astype('category')
    data[column] = data[column].cat.codes

# Convert datetime columns to separate columns for year, month, day, hour, minute, second
datetime_features = list(data.select_dtypes(include = "datetime64[ns, UTC]").columns)
for i in datetime_features:
    data[i+"_year"] = data[i].dt.year
    data[i+"_month"] = data[i].dt.month
    data[i+"_day"] = data[i].dt.day
    data[i+"_hour"] = data[i].dt.hour

data.drop(columns = ['point_ewkt'], inplace = True)

# %%
target = data['outage_count']

# %%
from difflib import SequenceMatcher
from itertools import combinations

# %%
def group_features(features, similarity_threshold=80):
    groups = []
    used_indices = set()

    for i, feature1 in enumerate(features):
        if i in used_indices:
            continue

        # This will be a new group
        current_group = [feature1]
        used_indices.add(i)

        for j, feature2 in enumerate(features):
            if j in used_indices or i == j:
                continue

            # Calculate similarity
            similarity = SequenceMatcher(None, feature1, feature2).ratio() * 100
            if similarity > similarity_threshold:
                current_group.append(feature2)
                used_indices.add(j)
        
        groups.append(current_group)

    return groups

# %%
groups = group_features(unique_features)
groups
# Out:
# [['0'],
#  ['breaker_counts'],
#  ['fuse_counts'],
#  ['switch_counts'],
#  ['transformer_counts'],
#  ['recloser_counts'],
#  ['pole_counts'],
#  ['poly_ewkt'],
#  ['point_ewkt'],
#  ['grid_id'],
#  ['outage_count'],
#  ['SimStartDate'],
#  ['outage_start_time'],
#  ['outage_end_time'],
#  ['weather_start_time'],
#  ['weather_end_time'],
#  ['event_type'],
#  ['x'],
#  ['y'],
#  ['10 metre wind speed_m s**-1 (max)_lambert_level 10 m_cogt_5',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m_cogt_9',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m_cogt_13',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m_cogt_18',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m_gt_5',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m_gt_9',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m_gt_13',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m_gt_18',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m_gt_35',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max_var',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean_var',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean_var',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean_var',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min_var',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean_var',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean_var',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min_var',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-min_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-min_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-min_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-min_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-min_var',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-min_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-min_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-min_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-min_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-min_var',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-max_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-max_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-max_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-max_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-max_var',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-max_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-max_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-max_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-max_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-max_var',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m_var',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-min_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-min_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-min_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-min_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-min_var',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-min_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-min_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-min_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-min_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-min_var',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-max_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-max_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-max_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-max_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-max_var',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean_var',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max_var',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-max_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-max_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-max_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-max_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-max_var',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-15)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-15)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max-15)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max-15)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-15)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-15)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-max-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-max-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-max-15)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-max-15)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-min-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-min-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-min-15)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-min-15)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-15)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-15)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-max-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-max-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-max-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-max-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-max-15)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-max-15)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min-15)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min-15)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-min-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-min-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-min-15)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-min-15)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-min-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-min-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-min-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-min-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-min-15)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-min-15)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-max-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-max-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-max-15)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-max-15)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-min-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-min-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-min-15)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-min-15)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-max-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-max-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-max-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-max-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-max-15)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-max-15)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max-15)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max-15)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-15)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-15)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min-15)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min-15)^2'],
#  ['Wind speed (gust)_m s**-1 (max)_lambert_level 10 m_gt_13',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m_gt_17',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m_gt_22',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m_gt_27',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m_gt_44',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max_var',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-min_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-min_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-min_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-min_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-min_var',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max_var',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean_var',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-min_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-min_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-min_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-min_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-min_var',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-min_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-min_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-min_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-min_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-min_var',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-min_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-min_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-min_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-min_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-min_var',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-max_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-max_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-max_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-max_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-max_var',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-mean_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-mean_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-mean_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-mean_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-mean_var',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-mean_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-mean_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-mean_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-mean_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-mean_var',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-max_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-max_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-max_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-max_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-max_var',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-max_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-max_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-max_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-max_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-max_var',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-mean_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-mean_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-mean_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-mean_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-mean_var',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-mean_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-mean_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-mean_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-mean_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-mean_var',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m_var',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-mean_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-mean_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-mean_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-mean_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-mean_var',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-min_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-min_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-min_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-min_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-min_var',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-min_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-min_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-min_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-min_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-min_var',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-max_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-max_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-max_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-max_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-max_var',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-20)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-20)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max-20)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max-20)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-max-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-max-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-max-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-max-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-max-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-max-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-max-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-max-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-max-20)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-max-20)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-min-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-min-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-min-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-min-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-min-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-min-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-min-20)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-20)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-max-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-max-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-max-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-max-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-max-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-max-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-max-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-max-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-max-20)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-max-20)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-min-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-min-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-min-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-min-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-min-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-min-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-min-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-min-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-min-20)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-min-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-min-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-min-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-min-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-min-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-min-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-min-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-min-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-min-20)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-min-20)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-min-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-min-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-min-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-min-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-min-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-min-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-min-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-min-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-min-20)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-min-20)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-max-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-max-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-max-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-max-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-max-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-max-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-max-20)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-20)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-20)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-20)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-max-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-max-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-max-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-max-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-max-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-max-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-max-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-max-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-max-20)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-min-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-min-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-min-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-min-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-min-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-min-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-min-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-min-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-min-20)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-min-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-min-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-min-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-min-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-min-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-min-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-min-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-min-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-min-20)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-20)^1'],
#  ['221_221 (min)_lambert_levels 0-40000-filtered_2-mean_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_2-mean_mean',
#   '221_221 (min)_lambert_levels 0-40000-filtered_2-mean_max',
#   '221_221 (min)_lambert_levels 0-40000-filtered_2-mean_min',
#   '221_221 (min)_lambert_levels 0-40000-filtered_2-mean_var',
#   '4_4 (max)_lambert_level 0-filtered_2-mean_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_16-max_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_16-max_mean',
#   '220_220 (max)_lambert_levels 0-40000-filtered_16-max_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_16-max_min',
#   '220_220 (max)_lambert_levels 0-40000-filtered_16-max_var',
#   '221_221 (min)_lambert_levels 0-40000-filtered_32-mean_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_32-mean_mean',
#   '221_221 (min)_lambert_levels 0-40000-filtered_32-mean_max',
#   '221_221 (min)_lambert_levels 0-40000-filtered_32-mean_min',
#   '221_221 (min)_lambert_levels 0-40000-filtered_32-mean_var',
#   '220_220 (max)_lambert_levels 0-40000-filtered_2-min_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_2-min_mean',
#   '220_220 (max)_lambert_levels 0-40000-filtered_2-min_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_2-min_min',
#   '220_220 (max)_lambert_levels 0-40000-filtered_2-min_var',
#   '220_220 (max)_lambert_levels 0-40000-filtered_4-max_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_4-max_mean',
#   '220_220 (max)_lambert_levels 0-40000-filtered_4-max_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_4-max_min',
#   '220_220 (max)_lambert_levels 0-40000-filtered_4-max_var',
#   '221_221 (min)_lambert_levels 0-40000-filtered_2-max_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_2-max_mean',
#   '221_221 (min)_lambert_levels 0-40000-filtered_2-max_max',
#   '221_221 (min)_lambert_levels 0-40000-filtered_2-max_min',
#   '221_221 (min)_lambert_levels 0-40000-filtered_2-max_var',
#   '221_221 (min)_lambert_levels 0-40000-filtered_8-max_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_8-max_mean',
#   '221_221 (min)_lambert_levels 0-40000-filtered_8-max_max',
#   '221_221 (min)_lambert_levels 0-40000-filtered_8-max_min',
#   '221_221 (min)_lambert_levels 0-40000-filtered_8-max_var',
#   '220_220 (max)_lambert_levels 0-40000-filtered_24-max_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_24-max_mean',
#   '220_220 (max)_lambert_levels 0-40000-filtered_24-max_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_24-max_min',
#   '220_220 (max)_lambert_levels 0-40000-filtered_24-max_var',
#   '4_4 (max)_lambert_level 0-filtered_24-mean_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_32-max_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_32-max_mean',
#   '221_221 (min)_lambert_levels 0-40000-filtered_32-max_max',
#   '221_221 (min)_lambert_levels 0-40000-filtered_32-max_min',
#   '221_221 (min)_lambert_levels 0-40000-filtered_32-max_var',
#   '220_220 (max)_lambert_levels 0-40000-filtered_8-min_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_8-min_mean',
#   '220_220 (max)_lambert_levels 0-40000-filtered_8-min_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_8-min_min',
#   '220_220 (max)_lambert_levels 0-40000-filtered_8-min_var',
#   '221_221 (min)_lambert_levels 0-40000-filtered_16-min_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_16-min_mean',
#   '221_221 (min)_lambert_levels 0-40000-filtered_16-min_max',
#   '221_221 (min)_lambert_levels 0-40000-filtered_16-min_min',
#   '221_221 (min)_lambert_levels 0-40000-filtered_16-min_var',
#   '4_4 (max)_lambert_level 0-filtered_32-mean_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_32-min_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_32-min_mean',
#   '220_220 (max)_lambert_levels 0-40000-filtered_32-min_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_32-min_min',
#   '220_220 (max)_lambert_levels 0-40000-filtered_32-min_var',
#   '221_221 (min)_lambert_levels 0-40000-filtered_24-mean_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_24-mean_mean',
#   '221_221 (min)_lambert_levels 0-40000-filtered_24-mean_max',
#   '221_221 (min)_lambert_levels 0-40000-filtered_24-mean_min',
#   '221_221 (min)_lambert_levels 0-40000-filtered_24-mean_var',
#   '221_221 (min)_lambert_levels 0-40000-filtered_8-min_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_8-min_mean',
#   '221_221 (min)_lambert_levels 0-40000-filtered_8-min_max',
#   '221_221 (min)_lambert_levels 0-40000-filtered_8-min_min',
#   '221_221 (min)_lambert_levels 0-40000-filtered_8-min_var',
#   '220_220 (max)_lambert_levels 0-40000-filtered_32-mean_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_32-mean_mean',
#   '220_220 (max)_lambert_levels 0-40000-filtered_32-mean_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_32-mean_min',
#   '220_220 (max)_lambert_levels 0-40000-filtered_32-mean_var',
#   '220_220 (max)_lambert_levels 0-40000-filtered_16-mean_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_16-mean_mean',
#   '220_220 (max)_lambert_levels 0-40000-filtered_16-mean_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_16-mean_min',
#   '220_220 (max)_lambert_levels 0-40000-filtered_16-mean_var',
#   '220_220 (max)_lambert_levels 0-40000-filtered_2-max_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_2-max_mean',
#   '220_220 (max)_lambert_levels 0-40000-filtered_2-max_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_2-max_min',
#   '220_220 (max)_lambert_levels 0-40000-filtered_2-max_var',
#   '221_221 (min)_lambert_levels 0-40000-filtered_8-mean_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_8-mean_mean',
#   '221_221 (min)_lambert_levels 0-40000-filtered_8-mean_max',
#   '221_221 (min)_lambert_levels 0-40000-filtered_8-mean_min',
#   '221_221 (min)_lambert_levels 0-40000-filtered_8-mean_var',
#   '221_221 (min)_lambert_levels 0-40000-filtered_4-mean_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_4-mean_mean',
#   '221_221 (min)_lambert_levels 0-40000-filtered_4-mean_max',
#   '221_221 (min)_lambert_levels 0-40000-filtered_4-mean_min',
#   '221_221 (min)_lambert_levels 0-40000-filtered_4-mean_var',
#   '221_221 (min)_lambert_levels 0-40000-filtered_24-max_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_24-max_mean',
#   '221_221 (min)_lambert_levels 0-40000-filtered_24-max_max',
#   '221_221 (min)_lambert_levels 0-40000-filtered_24-max_min',
#   '221_221 (min)_lambert_levels 0-40000-filtered_24-max_var',
#   '220_220 (max)_lambert_levels 0-40000-filtered_4-min_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_4-min_mean',
#   '220_220 (max)_lambert_levels 0-40000-filtered_4-min_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_4-min_min',
#   '220_220 (max)_lambert_levels 0-40000-filtered_4-min_var',
#   '221_221 (min)_lambert_levels 0-40000-filtered_16-max_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_16-max_mean',
#   '221_221 (min)_lambert_levels 0-40000-filtered_16-max_max',
#   '221_221 (min)_lambert_levels 0-40000-filtered_16-max_min',
#   '221_221 (min)_lambert_levels 0-40000-filtered_16-max_var',
#   '74_74 (max)_lambert_level 0 200-filtered_2-mean_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_16-mean_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_16-mean_mean',
#   '221_221 (min)_lambert_levels 0-40000-filtered_16-mean_max',
#   '221_221 (min)_lambert_levels 0-40000-filtered_16-mean_min',
#   '221_221 (min)_lambert_levels 0-40000-filtered_16-mean_var',
#   '221_221 (min)_lambert_levels 0-40000-filtered_4-min_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_4-min_mean',
#   '221_221 (min)_lambert_levels 0-40000-filtered_4-min_max',
#   '221_221 (min)_lambert_levels 0-40000-filtered_4-min_min',
#   '221_221 (min)_lambert_levels 0-40000-filtered_4-min_var',
#   '221_221 (min)_lambert_levels 0-40000_sum',
#   '221_221 (min)_lambert_levels 0-40000_mean',
#   '221_221 (min)_lambert_levels 0-40000_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_32-max_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_32-max_mean',
#   '220_220 (max)_lambert_levels 0-40000-filtered_32-max_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_32-max_min',
#   '220_220 (max)_lambert_levels 0-40000-filtered_32-max_var',
#   '199_199 (max)_lambert_levels 5000-2000 m-filtered_24-mean_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_8-max_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_8-max_mean',
#   '220_220 (max)_lambert_levels 0-40000-filtered_8-max_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_8-max_min',
#   '220_220 (max)_lambert_levels 0-40000-filtered_8-max_var',
#   '220_220 (max)_lambert_levels 0-40000-filtered_16-min_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_16-min_mean',
#   '220_220 (max)_lambert_levels 0-40000-filtered_16-min_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_16-min_min',
#   '220_220 (max)_lambert_levels 0-40000-filtered_16-min_var',
#   '221_221 (min)_lambert_levels 0-40000-filtered_4-max_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_4-max_mean',
#   '221_221 (min)_lambert_levels 0-40000-filtered_4-max_max',
#   '221_221 (min)_lambert_levels 0-40000-filtered_4-max_min',
#   '221_221 (min)_lambert_levels 0-40000-filtered_4-max_var',
#   '220_220 (max)_lambert_levels 0-40000-filtered_8-mean_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_8-mean_mean',
#   '220_220 (max)_lambert_levels 0-40000-filtered_8-mean_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_8-mean_min',
#   '220_220 (max)_lambert_levels 0-40000-filtered_8-mean_var',
#   '199_199 (max)_lambert_levels 5000-2000 m-filtered_32-mean_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_32-min_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_32-min_mean',
#   '221_221 (min)_lambert_levels 0-40000-filtered_32-min_max',
#   '221_221 (min)_lambert_levels 0-40000-filtered_32-min_min',
#   '221_221 (min)_lambert_levels 0-40000-filtered_32-min_var',
#   '220_220 (max)_lambert_levels 0-40000-filtered_24-mean_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_24-mean_mean',
#   '220_220 (max)_lambert_levels 0-40000-filtered_24-mean_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_24-mean_min',
#   '220_220 (max)_lambert_levels 0-40000-filtered_24-mean_var',
#   '220_220 (max)_lambert_levels 0-40000-filtered_2-mean_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_2-mean_mean',
#   '220_220 (max)_lambert_levels 0-40000-filtered_2-mean_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_2-mean_min',
#   '220_220 (max)_lambert_levels 0-40000-filtered_2-mean_var',
#   '220_220 (max)_lambert_levels 0-40000-filtered_24-min_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_24-min_mean',
#   '220_220 (max)_lambert_levels 0-40000-filtered_24-min_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_24-min_min',
#   '220_220 (max)_lambert_levels 0-40000-filtered_24-min_var',
#   '221_221 (min)_lambert_levels 0-40000-filtered_24-min_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_24-min_mean',
#   '221_221 (min)_lambert_levels 0-40000-filtered_24-min_max',
#   '221_221 (min)_lambert_levels 0-40000-filtered_24-min_min',
#   '221_221 (min)_lambert_levels 0-40000-filtered_24-min_var',
#   '221_221 (min)_lambert_levels 0-40000-filtered_2-min_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_2-min_mean',
#   '221_221 (min)_lambert_levels 0-40000-filtered_2-min_max',
#   '221_221 (min)_lambert_levels 0-40000-filtered_2-min_min',
#   '221_221 (min)_lambert_levels 0-40000-filtered_2-min_var',
#   '199_199 (max)_lambert_levels 5000-2000 m-filtered_2-mean_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_4-mean_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_4-mean_mean',
#   '220_220 (max)_lambert_levels 0-40000-filtered_4-mean_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_4-mean_min',
#   '220_220 (max)_lambert_levels 0-40000-filtered_4-mean_var'],
#  ['HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-min_sum',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-min_mean',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-min_max',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-min_min',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-min_var',
#   'HOURLY_SNOW_ACCUM_RATE m/h-filtered_16-max_sum',
#   'HOURLY_SNOW_ACCUM_RATE m/h-filtered_16-max_mean',
#   'HOURLY_SNOW_ACCUM_RATE m/h-filtered_16-max_max',
#   'HOURLY_SNOW_ACCUM_RATE m/h-filtered_16-max_min',
#   'HOURLY_SNOW_ACCUM_RATE m/h-filtered_16-max_var',
#   'HOURLY_SNOW_ACCUM_RATE m/h-filtered_8-min_sum',
#   'HOURLY_SNOW_ACCUM_RATE m/h-filtered_8-min_mean',
#   'HOURLY_SNOW_ACCUM_RATE m/h-filtered_8-min_max',
#   'HOURLY_SNOW_ACCUM_RATE m/h-filtered_8-min_min',
#   'HOURLY_SNOW_ACCUM_RATE m/h-filtered_8-min_var',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_16-max_sum',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_16-max_mean',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_16-max_max',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_16-max_min',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_16-max_var',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_2-max_sum',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_2-max_mean',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_2-max_max',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_2-max_min',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_2-max_var',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h_sum',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h_min',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-max_sum',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-max_mean',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-max_max',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-max_min',
# ...
#   'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_16-max_3_hour_variation_max',
#   'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_16-mean_3_hour_variation_min',
#   'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_16-mean_3_hour_variation_max',
#   'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_4-max_3_hour_variation_min',
#   'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_32-max_3_hour_variation_min',
#   'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_24-mean_3_hour_variation_min',
#   'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_24-max_3_hour_variation_min',
#   'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_8-max_3_hour_variation_min',
#   'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_2-max_3_hour_variation_min',
#   'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_4-mean_3_hour_variation_min',
#   'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_2-mean_3_hour_variation_min',
#   'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_32-mean_3_hour_variation_min',
#   'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_8-mean_3_hour_variation_min',
#   'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_8-mean_3_hour_variation_max'],
#  ['2 metre temperature_K (instant)_lambert_level 2 m-filtered_2-min_3_hour_variation_max',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-mean_3_hour_variation_min',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-mean_3_hour_variation_max',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_2-mean_3_hour_variation_max',
#   '2 metre dewpoint temperature_K (instant)_lambert_level 2 m_3_hour_variation_min',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_24-min_3_hour_variation_min',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_24-min_3_hour_variation_max',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-min_3_hour_variation_min',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-min_3_hour_variation_max',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_8-mean_3_hour_variation_min',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_8-mean_3_hour_variation_max',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_4-min_3_hour_variation_min',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_4-min_3_hour_variation_max',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_32-mean_3_hour_variation_max',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_4-mean_3_hour_variation_min',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_4-mean_3_hour_variation_max',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_24-mean_3_hour_variation_max',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_8-min_3_hour_variation_min',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_8-min_3_hour_variation_max',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_32-min_3_hour_variation_min',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_32-min_3_hour_variation_max'],
#  ['2 metre relative humidity_% (instant)_lambert_level 2 m_3_hour_variation_min'],
#  ['Surface pressure_Pa (instant)_lambert_level 0_3_hour_variation_min',
#   'Surface pressure_Pa (instant)_lambert_level 0_3_hour_variation_max'],
#  ['Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa_3_hour_variation_min'],
#  ['(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-20)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-20)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-min-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-min-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-min-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-15)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-max-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-max-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-max-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-max-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-max-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-max-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-min-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-min-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-min-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-min-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-min-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-min-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-max-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-max-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-max-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-max-20)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-20)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-min-20)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-20)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-20)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-max-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-max-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-max-20)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min-20)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-max-20)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-min-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-min-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-min-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-min-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-min-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-min-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-min-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-min-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-min-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-min-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-min-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-max-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-max-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-max-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-max-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-max-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-max-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-min-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-min-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-min-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-min-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-min-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-min-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-max-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-max-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-max-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-max-20)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-min-20)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-20)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max-20)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-15)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-15)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min-20)^2'],
#  ['(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-15)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-15)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-15)^1'],
#  ['lat'],
#  ['lon'],
#  ['LU_11_30',
#   'LU_21_30',
#   'LU_31_30',
#   'LU_41_30',
#   'LU_71_30',
#   'LU_81_30',
#   'LU_11_60'],
#  ['LU_22_30',
#   'LU_23_30',
#   'LU_24_30',
#   'LU_42_30',
#   'LU_52_30',
#   'LU_82_30',
#   'LU_22_60'],
#  ['LU_43_30', 'LU_43_60'],
#  ['LU_90_30', 'LU_95_30', 'LU_90_60'],
#  ['LU_21_60',
#   'LU_23_60',
#   'LU_24_60',
#   'LU_31_60',
#   'LU_41_60',
#   'LU_42_60',
#   'LU_52_60',
#   'LU_71_60',
#   'LU_81_60',
#   'LU_82_60'],
#  ['LU_95_60'],
#  ['canopy_25th_30', 'canopy_75th_30', 'canopy_25th_60', 'canopy_75th_60'],
#  ['canopy_interval_0_0_30',
#   'canopy_interval_11_20_30',
#   'canopy_interval_1_10_30',
#   'canopy_interval_21_30_30',
#   'canopy_interval_31_40_30',
#   'canopy_interval_41_50_30',
#   'canopy_interval_51_60_30',
#   'canopy_interval_61_70_30',
#   'canopy_interval_71_80_30',
#   'canopy_interval_81_90_30',
#   'canopy_interval_91_100_30',
#   'canopy_interval_0_0_60',
#   'canopy_interval_11_20_60',
#   'canopy_interval_1_10_60',
#   'canopy_interval_21_30_60',
#   'canopy_interval_31_40_60',
#   'canopy_interval_41_50_60',
#   'canopy_interval_51_60_60',
#   'canopy_interval_61_70_60',
#   'canopy_interval_71_80_60',
#   'canopy_interval_81_90_60',
#   'canopy_interval_91_100_60'],
#  ['canopy_mean_30',
#   'canopy_median_30',
#   'canopy_var_30',
#   'canopy_mean_60',
#   'canopy_median_60'],
#  ['canopy_var_60'],
#  ['length_proxy_30', 'length_proxy_60'],
#  ['line_length_30', 'line_length_60']]

# %%
len(groups)
# Out:
# 82

# %%
for i in range(len(groups)):
    print("Group {}: {}".format(i, groups[i]))
# Out:
# Group 0: ['0']
# Group 1: ['breaker_counts']
# Group 2: ['fuse_counts']
# Group 3: ['switch_counts']
# Group 4: ['transformer_counts']
# Group 5: ['recloser_counts']
# Group 6: ['pole_counts']
# Group 7: ['poly_ewkt']
# Group 8: ['point_ewkt']
# Group 9: ['grid_id']
# Group 10: ['outage_count']
# Group 11: ['SimStartDate']
# Group 12: ['outage_start_time']
# Group 13: ['outage_end_time']
# Group 14: ['weather_start_time']
# Group 15: ['weather_end_time']
# Group 16: ['event_type']
# Group 17: ['x']
# Group 18: ['y']
# Group 19: ['10 metre wind speed_m s**-1 (max)_lambert_level 10 m_cogt_5', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m_cogt_9', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m_cogt_13', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m_cogt_18', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m_gt_5', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m_gt_9', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m_gt_13', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m_gt_18', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m_gt_35', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max_sum', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max_mean', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max_max', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max_min', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max_var', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean_sum', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean_mean', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean_max', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean_min', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean_var', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean_sum', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean_mean', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean_max', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean_min', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean_var', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean_sum', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean_mean', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean_max', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean_min', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean_var', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min_sum', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min_mean', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min_max', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min_min', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min_var', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean_sum', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean_mean', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean_max', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean_min', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean_var', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean_sum', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean_mean', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean_max', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean_min', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean_var', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min_sum', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min_mean', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min_max', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min_min', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min_var', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-min_sum', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-min_mean', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-min_max', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-min_min', '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-min_var',  ...
# Group 20: ['Wind speed (gust)_m s**-1 (max)_lambert_level 10 m_gt_13', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m_gt_17', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m_gt_22', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m_gt_27', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m_gt_44', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max_sum', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max_mean', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max_max', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max_min', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max_var', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-min_sum', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-min_mean', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-min_max', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-min_min', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-min_var', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max_sum', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max_mean', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max_max', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max_min', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max_var', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean_sum', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean_mean', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean_max', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean_min', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean_var', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-min_sum', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-min_mean', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-min_max', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-min_min', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-min_var', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-min_sum', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-min_mean', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-min_max', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-min_min', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-min_var', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-min_sum', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-min_mean', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-min_max', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-min_min', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-min_var', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-max_sum', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-max_mean', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-max_max', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-max_min', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-max_var', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-mean_sum', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-mean_mean', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-mean_max', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-mean_min', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-mean_var', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-mean_sum', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-mean_mean', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-mean_max', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-mean_min', 'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16- ...
# Group 21: ['221_221 (min)_lambert_levels 0-40000-filtered_2-mean_sum', '221_221 (min)_lambert_levels 0-40000-filtered_2-mean_mean', '221_221 (min)_lambert_levels 0-40000-filtered_2-mean_max', '221_221 (min)_lambert_levels 0-40000-filtered_2-mean_min', '221_221 (min)_lambert_levels 0-40000-filtered_2-mean_var', '4_4 (max)_lambert_level 0-filtered_2-mean_sum', '220_220 (max)_lambert_levels 0-40000-filtered_16-max_sum', '220_220 (max)_lambert_levels 0-40000-filtered_16-max_mean', '220_220 (max)_lambert_levels 0-40000-filtered_16-max_max', '220_220 (max)_lambert_levels 0-40000-filtered_16-max_min', '220_220 (max)_lambert_levels 0-40000-filtered_16-max_var', '221_221 (min)_lambert_levels 0-40000-filtered_32-mean_sum', '221_221 (min)_lambert_levels 0-40000-filtered_32-mean_mean', '221_221 (min)_lambert_levels 0-40000-filtered_32-mean_max', '221_221 (min)_lambert_levels 0-40000-filtered_32-mean_min', '221_221 (min)_lambert_levels 0-40000-filtered_32-mean_var', '220_220 (max)_lambert_levels 0-40000-filtered_2-min_sum', '220_220 (max)_lambert_levels 0-40000-filtered_2-min_mean', '220_220 (max)_lambert_levels 0-40000-filtered_2-min_max', '220_220 (max)_lambert_levels 0-40000-filtered_2-min_min', '220_220 (max)_lambert_levels 0-40000-filtered_2-min_var', '220_220 (max)_lambert_levels 0-40000-filtered_4-max_sum', '220_220 (max)_lambert_levels 0-40000-filtered_4-max_mean', '220_220 (max)_lambert_levels 0-40000-filtered_4-max_max', '220_220 (max)_lambert_levels 0-40000-filtered_4-max_min', '220_220 (max)_lambert_levels 0-40000-filtered_4-max_var', '221_221 (min)_lambert_levels 0-40000-filtered_2-max_sum', '221_221 (min)_lambert_levels 0-40000-filtered_2-max_mean', '221_221 (min)_lambert_levels 0-40000-filtered_2-max_max', '221_221 (min)_lambert_levels 0-40000-filtered_2-max_min', '221_221 (min)_lambert_levels 0-40000-filtered_2-max_var', '221_221 (min)_lambert_levels 0-40000-filtered_8-max_sum', '221_221 (min)_lambert_levels 0-40000-filtered_8-max_mean', '221_221 (min)_lambert_levels 0-40000-filtered_8-max_max', '221_221 (min)_lambert_levels 0-40000-filtered_8-max_min', '221_221 (min)_lambert_levels 0-40000-filtered_8-max_var', '220_220 (max)_lambert_levels 0-40000-filtered_24-max_sum', '220_220 (max)_lambert_levels 0-40000-filtered_24-max_mean', '220_220 (max)_lambert_levels 0-40000-filtered_24-max_max', '220_220 (max)_lambert_levels 0-40000-filtered_24-max_min', '220_220 (max)_lambert_levels 0-40000-filtered_24-max_var', '4_4 (max)_lambert_level 0-filtered_24-mean_sum', '221_221 (min)_lambert_levels 0-40000-filtered_32-max_sum', '221_221 (min)_lambert_levels 0-40000-filtered_32-max_mean', '221_221 (min)_lambert_levels 0-40000-filtered_32-max_max', '221_221 (min)_lambert_levels 0-40000-filtered_32-max_min', '221_221 (min)_lambert_levels 0-40000-filtered_32-max_var', '220_220 (max)_lambert_levels 0-40000-filtered_8-min_sum', '220_220 (max)_lambert_levels 0-40000-filtered_8-min_mean', '220_220 (max)_lambert_levels 0-40000-filtered_8-min_max', '220_220 (max)_lambert_levels 0-40000-filtered_8-min_min', '220_220 (max)_lambert_levels 0-40000-filtered_8-min_var', '221_221 (min)_lambert_levels 0-40000-filtered_16-min_sum', '221_221 (min)_lambert_levels 0-40000-filtered_16-min_mean', '221_221 (min)_lambert_levels 0-40000-filtered_16-min_max', '221_221 (min)_lambert_levels 0-40000-filtered_16-min_min', '221_221 (min)_lambert_levels 0-40000-filtered_16-min_var', '4_4 (max)_lambert_level 0-filtered_32-mean_sum', '220_220 (max)_lambert_levels 0-40000-filtered_32-min_sum', '220_220 (max)_lambert_levels 0-40000-filtered_32-min_mean', '220_220 (max)_lambert_levels 0-40000-filtered_32-min_max', '220_220 (max)_lambert_levels 0-40000-filtered_32-min_min', '220_220 (max)_lambert_levels 0-40000-filtered_32-min_var', '221_221 (min)_lambert_levels 0-40000-filtered_24-mean_sum', '221_221 (min)_lambert_levels 0-40000-filtered_24-mean_mean', '221_221 (min)_lambert_levels 0-40000-filtered_24-mean_max', '221_221 (min)_lambert_levels 0-40000-filtered_24-mean_min', '22 ...
# Group 22: ['HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-min_sum', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-min_mean', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-min_max', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-min_min', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-min_var', 'HOURLY_SNOW_ACCUM_RATE m/h-filtered_16-max_sum', 'HOURLY_SNOW_ACCUM_RATE m/h-filtered_16-max_mean', 'HOURLY_SNOW_ACCUM_RATE m/h-filtered_16-max_max', 'HOURLY_SNOW_ACCUM_RATE m/h-filtered_16-max_min', 'HOURLY_SNOW_ACCUM_RATE m/h-filtered_16-max_var', 'HOURLY_SNOW_ACCUM_RATE m/h-filtered_8-min_sum', 'HOURLY_SNOW_ACCUM_RATE m/h-filtered_8-min_mean', 'HOURLY_SNOW_ACCUM_RATE m/h-filtered_8-min_max', 'HOURLY_SNOW_ACCUM_RATE m/h-filtered_8-min_min', 'HOURLY_SNOW_ACCUM_RATE m/h-filtered_8-min_var', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_16-max_sum', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_16-max_mean', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_16-max_max', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_16-max_min', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_16-max_var', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_2-max_sum', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_2-max_mean', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_2-max_max', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_2-max_min', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_2-max_var', 'HOURLY_WET_SNOW_ACCUM_RATE m/h_sum', 'HOURLY_WET_SNOW_ACCUM_RATE m/h_min', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-max_sum', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-max_mean', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-max_max', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-max_min', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-max_var', 'HOURLY_SNOW_ACCUM_RATE m/h-filtered_32-mean_sum', 'HOURLY_SNOW_ACCUM_RATE m/h-filtered_32-mean_mean', 'HOURLY_SNOW_ACCUM_RATE m/h-filtered_32-mean_max', 'HOURLY_SNOW_ACCUM_RATE m/h-filtered_32-mean_min', 'HOURLY_SNOW_ACCUM_RATE m/h-filtered_32-mean_var', 'HOURLY_SNOW_ACCUM_RATE m/h-filtered_32-min_sum', 'HOURLY_SNOW_ACCUM_RATE m/h-filtered_32-min_mean', 'HOURLY_SNOW_ACCUM_RATE m/h-filtered_32-min_max', 'HOURLY_SNOW_ACCUM_RATE m/h-filtered_32-min_min', 'HOURLY_SNOW_ACCUM_RATE m/h-filtered_32-min_var', 'HOURLY_SNOW_ACCUM_RATE m/h-filtered_24-mean_sum', 'HOURLY_SNOW_ACCUM_RATE m/h-filtered_24-mean_mean', 'HOURLY_SNOW_ACCUM_RATE m/h-filtered_24-mean_max', 'HOURLY_SNOW_ACCUM_RATE m/h-filtered_24-mean_min', 'HOURLY_SNOW_ACCUM_RATE m/h-filtered_24-mean_var', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-mean_sum', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-mean_mean', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-mean_max', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-mean_min', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-mean_var', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_2-min_sum', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_2-min_mean', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_2-min_max', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_2-min_min', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_2-min_var', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_24-max_sum', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_24-max_mean', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_24-max_max', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_24-max_min', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_24-max_var', 'HOURLY_SNOW_ACCUM_RATE m/h-filtered_4-min_sum', 'HOURLY_SNOW_ACCUM_RATE m/h-filtered_4-min_mean', 'HOURLY_SNOW_ACCUM_RATE m/h-filtered_4-min_max', 'HOURLY_SNOW_ACCUM_RATE m/h-filtered_4-min_min', 'HOURLY_SNOW_ACCUM_RATE m/h-filtered_4-min_var', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_32-mean_sum', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_32-mean_mean', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_32-mean_max', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_32-mean_min', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_32-mean_var', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_16-mean_sum', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_16-mean_mean', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_16-mean_max', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_16-mean_min', 'HOURLY_WET_SNOW_ACCUM_RATE m/h-f ...
# Group 23: ['AIR_DENSITY kg/m3-filtered_2-mean_sum', 'AIR_DENSITY kg/m3-filtered_2-mean_mean', 'AIR_DENSITY kg/m3-filtered_2-mean_max', 'AIR_DENSITY kg/m3-filtered_2-mean_min', 'AIR_DENSITY kg/m3-filtered_2-mean_var', 'AIR_DENSITY kg/m3-filtered_32-max_sum', 'AIR_DENSITY kg/m3-filtered_32-max_mean', 'AIR_DENSITY kg/m3-filtered_32-max_max', 'AIR_DENSITY kg/m3-filtered_32-max_min', 'AIR_DENSITY kg/m3-filtered_32-max_var', 'AIR_DENSITY kg/m3-filtered_8-max_sum', 'AIR_DENSITY kg/m3-filtered_8-max_mean', 'AIR_DENSITY kg/m3-filtered_8-max_max', 'AIR_DENSITY kg/m3-filtered_8-max_min', 'AIR_DENSITY kg/m3-filtered_8-max_var', 'AIR_DENSITY kg/m3-filtered_2-min_sum', 'AIR_DENSITY kg/m3-filtered_2-min_mean', 'AIR_DENSITY kg/m3-filtered_2-min_max', 'AIR_DENSITY kg/m3-filtered_2-min_min', 'AIR_DENSITY kg/m3-filtered_2-min_var', 'AIR_DENSITY kg/m3-filtered_32-mean_sum', 'AIR_DENSITY kg/m3-filtered_32-mean_mean', 'AIR_DENSITY kg/m3-filtered_32-mean_max', 'AIR_DENSITY kg/m3-filtered_32-mean_min', 'AIR_DENSITY kg/m3-filtered_32-mean_var', 'AIR_DENSITY kg/m3-filtered_24-max_sum', 'AIR_DENSITY kg/m3-filtered_24-max_mean', 'AIR_DENSITY kg/m3-filtered_24-max_max', 'AIR_DENSITY kg/m3-filtered_24-max_min', 'AIR_DENSITY kg/m3-filtered_24-max_var', 'AIR_DENSITY kg/m3-filtered_8-min_sum', 'AIR_DENSITY kg/m3-filtered_8-min_mean', 'AIR_DENSITY kg/m3-filtered_8-min_max', 'AIR_DENSITY kg/m3-filtered_8-min_min', 'AIR_DENSITY kg/m3-filtered_8-min_var', 'AIR_DENSITY kg/m3-filtered_16-mean_sum', 'AIR_DENSITY kg/m3-filtered_16-mean_mean', 'AIR_DENSITY kg/m3-filtered_16-mean_max', 'AIR_DENSITY kg/m3-filtered_16-mean_min', 'AIR_DENSITY kg/m3-filtered_16-mean_var', 'AIR_DENSITY kg/m3-filtered_24-min_sum', 'AIR_DENSITY kg/m3-filtered_24-min_mean', 'AIR_DENSITY kg/m3-filtered_24-min_max', 'AIR_DENSITY kg/m3-filtered_24-min_min', 'AIR_DENSITY kg/m3-filtered_24-min_var', 'AIR_DENSITY kg/m3-filtered_24-mean_sum', 'AIR_DENSITY kg/m3-filtered_24-mean_mean', 'AIR_DENSITY kg/m3-filtered_24-mean_max', 'AIR_DENSITY kg/m3-filtered_24-mean_min', 'AIR_DENSITY kg/m3-filtered_24-mean_var', 'AIR_DENSITY kg/m3-filtered_8-mean_sum', 'AIR_DENSITY kg/m3-filtered_8-mean_mean', 'AIR_DENSITY kg/m3-filtered_8-mean_max', 'AIR_DENSITY kg/m3-filtered_8-mean_min', 'AIR_DENSITY kg/m3-filtered_8-mean_var', 'AIR_DENSITY kg/m3-filtered_16-max_sum', 'AIR_DENSITY kg/m3-filtered_16-max_mean', 'AIR_DENSITY kg/m3-filtered_16-max_max', 'AIR_DENSITY kg/m3-filtered_16-max_min', 'AIR_DENSITY kg/m3-filtered_16-max_var', 'AIR_DENSITY kg/m3-filtered_4-max_sum', 'AIR_DENSITY kg/m3-filtered_4-max_mean', 'AIR_DENSITY kg/m3-filtered_4-max_max', 'AIR_DENSITY kg/m3-filtered_4-max_min', 'AIR_DENSITY kg/m3-filtered_4-max_var', 'AIR_DENSITY kg/m3-filtered_4-min_sum', 'AIR_DENSITY kg/m3-filtered_4-min_mean', 'AIR_DENSITY kg/m3-filtered_4-min_max', 'AIR_DENSITY kg/m3-filtered_4-min_min', 'AIR_DENSITY kg/m3-filtered_4-min_var', 'AIR_DENSITY kg/m3-filtered_2-max_sum', 'AIR_DENSITY kg/m3-filtered_2-max_mean', 'AIR_DENSITY kg/m3-filtered_2-max_max', 'AIR_DENSITY kg/m3-filtered_2-max_min', 'AIR_DENSITY kg/m3-filtered_2-max_var', 'AIR_DENSITY kg/m3-filtered_32-min_sum', 'AIR_DENSITY kg/m3-filtered_32-min_mean', 'AIR_DENSITY kg/m3-filtered_32-min_max', 'AIR_DENSITY kg/m3-filtered_32-min_min', 'AIR_DENSITY kg/m3-filtered_32-min_var', 'AIR_DENSITY kg/m3-filtered_4-mean_sum', 'AIR_DENSITY kg/m3-filtered_4-mean_mean', 'AIR_DENSITY kg/m3-filtered_4-mean_max', 'AIR_DENSITY kg/m3-filtered_4-mean_min', 'AIR_DENSITY kg/m3-filtered_4-mean_var', 'AIR_DENSITY kg/m3-filtered_16-min_sum', 'AIR_DENSITY kg/m3-filtered_16-min_mean', 'AIR_DENSITY kg/m3-filtered_16-min_max', 'AIR_DENSITY kg/m3-filtered_16-min_min', 'AIR_DENSITY kg/m3-filtered_16-min_var']
# Group 24: ['Snow depth_m (instant)_lambert_level 0-filtered_8-max_sum', 'Snow depth_m (instant)_lambert_level 0-filtered_8-max_mean', 'Snow depth_m (instant)_lambert_level 0-filtered_8-max_max', 'Snow depth_m (instant)_lambert_level 0-filtered_8-max_min', 'Snow depth_m (instant)_lambert_level 0-filtered_8-max_var', 'Snow depth_m (instant)_lambert_level 0-filtered_8-mean_sum', 'Snow depth_m (instant)_lambert_level 0-filtered_8-mean_mean', 'Snow depth_m (instant)_lambert_level 0-filtered_8-mean_max', 'Snow depth_m (instant)_lambert_level 0-filtered_8-mean_min', 'Snow depth_m (instant)_lambert_level 0-filtered_8-mean_var', '0_0 (instant)_lambert_level 0-filtered_16-max_sum', '0_0 (instant)_lambert_level 0-filtered_16-max_mean', '0_0 (instant)_lambert_level 0-filtered_16-max_max', '0_0 (instant)_lambert_level 0-filtered_16-max_min', '0_0 (instant)_lambert_level 0-filtered_2-min_sum', 'Snow depth_m (instant)_lambert_level 0-filtered_16-mean_sum', 'Snow depth_m (instant)_lambert_level 0-filtered_16-mean_mean', 'Snow depth_m (instant)_lambert_level 0-filtered_16-mean_max', 'Snow depth_m (instant)_lambert_level 0-filtered_16-mean_min', 'Snow depth_m (instant)_lambert_level 0-filtered_16-mean_var', '0_0 (instant)_lambert_level 0-filtered_24-max_sum', '0_0 (instant)_lambert_level 0-filtered_24-max_mean', '0_0 (instant)_lambert_level 0-filtered_24-max_max', '0_0 (instant)_lambert_level 0-filtered_24-max_min', 'Snow depth_m (instant)_lambert_level 0-filtered_2-mean_sum', 'Snow depth_m (instant)_lambert_level 0-filtered_2-mean_mean', 'Snow depth_m (instant)_lambert_level 0-filtered_2-mean_max', 'Snow depth_m (instant)_lambert_level 0-filtered_2-mean_min', 'Snow depth_m (instant)_lambert_level 0-filtered_2-mean_var', 'Total cloud cover_% (instant)_lambert_level 0-filtered_24-max_sum', '0_0 (instant)_lambert_level 0-filtered_4-max_sum', '0_0 (instant)_lambert_level 0-filtered_4-max_mean', '0_0 (instant)_lambert_level 0-filtered_4-max_max', '0_0 (instant)_lambert_level 0-filtered_4-max_min', 'Snow depth_m (instant)_lambert_level 0-filtered_24-mean_sum', 'Snow depth_m (instant)_lambert_level 0-filtered_24-mean_mean', 'Snow depth_m (instant)_lambert_level 0-filtered_24-mean_max', 'Snow depth_m (instant)_lambert_level 0-filtered_24-mean_min', 'Snow depth_m (instant)_lambert_level 0-filtered_24-mean_var', 'Snow depth_m (instant)_lambert_level 0-filtered_2-min_sum', 'Snow depth_m (instant)_lambert_level 0-filtered_2-min_mean', 'Snow depth_m (instant)_lambert_level 0-filtered_2-min_max', 'Snow depth_m (instant)_lambert_level 0-filtered_2-min_min', 'Snow depth_m (instant)_lambert_level 0-filtered_2-min_var', 'Snow depth_m (instant)_lambert_level 0_sum', 'Snow depth_m (instant)_lambert_level 0_max', '0_0 (instant)_lambert_level 0-filtered_8-mean_sum', '0_0 (instant)_lambert_level 0-filtered_8-mean_mean', '0_0 (instant)_lambert_level 0-filtered_8-mean_min', '0_0 (instant)_lambert_level 0-filtered_2-mean_sum', 'Snow depth_m (instant)_lambert_level 0-filtered_4-mean_sum', 'Snow depth_m (instant)_lambert_level 0-filtered_4-mean_mean', 'Snow depth_m (instant)_lambert_level 0-filtered_4-mean_max', 'Snow depth_m (instant)_lambert_level 0-filtered_4-mean_min', 'Snow depth_m (instant)_lambert_level 0-filtered_4-mean_var', 'Snow depth_m (instant)_lambert_level 0-filtered_4-max_sum', 'Snow depth_m (instant)_lambert_level 0-filtered_4-max_mean', 'Snow depth_m (instant)_lambert_level 0-filtered_4-max_max', 'Snow depth_m (instant)_lambert_level 0-filtered_4-max_min', 'Snow depth_m (instant)_lambert_level 0-filtered_4-max_var', 'Snow depth_m (instant)_lambert_level 0-filtered_24-min_sum', 'Snow depth_m (instant)_lambert_level 0-filtered_24-min_mean', 'Snow depth_m (instant)_lambert_level 0-filtered_24-min_max', 'Snow depth_m (instant)_lambert_level 0-filtered_24-min_min', 'Snow depth_m (instant)_lambert_level 0-filtered_24-min_var', '0_0 (instant)_lambert_level 0-filtered_8-min_sum', 'Total cloud cover_% (instant)_lambert_level 0-filtered_32-max_sum', 'Total cloud  ...
# Group 25: ['4_4 (max)_lambert_level 0-filtered_2-mean_mean', '4_4 (max)_lambert_level 0-filtered_2-mean_max', '4_4 (max)_lambert_level 0-filtered_2-mean_min', '4_4 (max)_lambert_level 0-filtered_2-mean_var', '0_0 (instant)_lambert_level 0-filtered_2-min_mean', '0_0 (instant)_lambert_level 0-filtered_2-min_max', '0_0 (instant)_lambert_level 0-filtered_2-min_min', 'Hail_m (max)_lambert_level 0-filtered_24-mean_sum', 'Hail_m (max)_lambert_level 0-filtered_24-mean_mean', 'Hail_m (max)_lambert_level 0-filtered_24-mean_max', 'Hail_m (max)_lambert_level 0-filtered_24-mean_min', 'Hail_m (max)_lambert_level 0-filtered_24-mean_var', '4_4 (max)_lambert_level 0-filtered_16-max_sum', '4_4 (max)_lambert_level 0-filtered_16-max_mean', '4_4 (max)_lambert_level 0-filtered_16-max_max', '4_4 (max)_lambert_level 0-filtered_16-max_min', '4_4 (max)_lambert_level 0-filtered_16-max_var', 'Hail_m (max)_lambert_level 0 10-filtered_8-max_mean', 'Hail_m (max)_lambert_level 0 10-filtered_8-max_max', 'Hail_m (max)_lambert_level 0 10-filtered_8-max_min', '74_74 (max)_lambert_level 0 200-filtered_4-min_sum', '74_74 (max)_lambert_level 0 200-filtered_4-min_mean', '74_74 (max)_lambert_level 0 200-filtered_4-min_max', '74_74 (max)_lambert_level 0 200-filtered_4-min_min', '74_74 (max)_lambert_level 0 200-filtered_4-min_var', 'Hail_m (max)_lambert_level 0-filtered_8-mean_sum', 'Hail_m (max)_lambert_level 0-filtered_8-mean_mean', 'Hail_m (max)_lambert_level 0-filtered_8-mean_max', 'Hail_m (max)_lambert_level 0-filtered_8-mean_min', 'Hail_m (max)_lambert_level 0-filtered_8-mean_var', '4_4 (max)_lambert_level 0-filtered_24-mean_mean', '4_4 (max)_lambert_level 0-filtered_24-mean_max', '4_4 (max)_lambert_level 0-filtered_24-mean_min', '4_4 (max)_lambert_level 0-filtered_24-mean_var', 'Hail_m (max)_lambert_level 0-filtered_24-min_sum', 'Hail_m (max)_lambert_level 0-filtered_24-min_mean', 'Hail_m (max)_lambert_level 0-filtered_24-min_max', 'Hail_m (max)_lambert_level 0-filtered_24-min_min', 'Hail_m (max)_lambert_level 0-filtered_24-min_var', 'Hail_m (max)_lambert_level 0 10-filtered_8-mean_sum', 'Hail_m (max)_lambert_level 0 10-filtered_8-mean_mean', 'Hail_m (max)_lambert_level 0 10-filtered_8-mean_max', 'Hail_m (max)_lambert_level 0 10-filtered_8-mean_min', 'Hail_m (max)_lambert_level 0 10-filtered_8-mean_var', 'Hail_m (max)_lambert_level 0-filtered_2-max_sum', 'Hail_m (max)_lambert_level 0-filtered_2-max_mean', 'Hail_m (max)_lambert_level 0-filtered_2-max_max', 'Hail_m (max)_lambert_level 0-filtered_2-max_min', 'Hail_m (max)_lambert_level 0-filtered_2-max_var', '74_74 (max)_lambert_level 0 200-filtered_32-min_sum', '74_74 (max)_lambert_level 0 200-filtered_32-min_mean', '74_74 (max)_lambert_level 0 200-filtered_32-min_max', '74_74 (max)_lambert_level 0 200-filtered_32-min_min', '74_74 (max)_lambert_level 0 200-filtered_32-min_var', 'Hail_m (max)_lambert_level 0-filtered_4-min_sum', 'Hail_m (max)_lambert_level 0-filtered_4-min_mean', 'Hail_m (max)_lambert_level 0-filtered_4-min_max', 'Hail_m (max)_lambert_level 0-filtered_4-min_min', 'Hail_m (max)_lambert_level 0-filtered_4-min_var', 'Hail_m (max)_lambert_level 0 10-filtered_24-mean_sum', 'Hail_m (max)_lambert_level 0 10-filtered_24-mean_mean', 'Hail_m (max)_lambert_level 0 10-filtered_24-mean_max', 'Hail_m (max)_lambert_level 0 10-filtered_24-mean_min', 'Hail_m (max)_lambert_level 0 10-filtered_24-mean_var', 'Hail_m (max)_lambert_level 0 10-filtered_32-max_sum', 'Hail_m (max)_lambert_level 0 10-filtered_32-max_mean', 'Hail_m (max)_lambert_level 0 10-filtered_32-max_max', 'Hail_m (max)_lambert_level 0 10-filtered_32-max_min', 'Hail_m (max)_lambert_level 0 10-filtered_32-max_var', 'Hail_m (max)_lambert_level 0-filtered_16-mean_sum', 'Hail_m (max)_lambert_level 0-filtered_16-mean_mean', 'Hail_m (max)_lambert_level 0-filtered_16-mean_max', 'Hail_m (max)_lambert_level 0-filtered_16-mean_min', 'Hail_m (max)_lambert_level 0-filtered_16-mean_var', '4_4 (max)_lambert_level 0-filtered_32-min_sum', '4_4 (max)_lambert_level 0-fil ...
# Group 26: ['HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_16-mean_sum', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_16-mean_mean', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_16-mean_max', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_16-mean_min', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_16-mean_var', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h_sum', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h_mean', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h_max', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h_min', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h_var', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_32-min_sum', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_32-min_mean', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_32-min_max', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_32-min_min', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_32-min_var', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_4-mean_sum', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_4-mean_mean', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_4-mean_max', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_4-mean_min', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_4-mean_var', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_16-min_sum', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_16-min_mean', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_16-min_max', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_16-min_min', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_16-min_var', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_32-mean_sum', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_32-mean_mean', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_32-mean_max', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_32-mean_min', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_32-mean_var', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_24-mean_sum', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_24-mean_mean', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_24-mean_max', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_24-mean_min', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_24-mean_var', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_2-min_sum', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_2-min_mean', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_2-min_max', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_2-min_min', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_2-min_var', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_8-max_sum', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_8-max_mean', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_8-max_max', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_8-max_min', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_8-max_var', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_8-min_sum', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_8-min_mean', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_8-min_max', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_8-min_min', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_8-min_var', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_24-min_sum', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_24-min_mean', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_24-min_max', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_24-min_min', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_24-min_var', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_2-mean_sum', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_2-mean_mean', 'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_2-mean_max ...
# Group 27: ['Total cloud cover_% (instant)_lambert_level 0-filtered_16-mean_sum', 'Total cloud cover_% (instant)_lambert_level 0-filtered_16-mean_mean', 'Total cloud cover_% (instant)_lambert_level 0-filtered_16-mean_max', 'Total cloud cover_% (instant)_lambert_level 0-filtered_16-mean_min', 'Total cloud cover_% (instant)_lambert_level 0-filtered_16-mean_var', 'Total cloud cover_% (instant)_lambert_level 0-filtered_32-min_sum', 'Total cloud cover_% (instant)_lambert_level 0-filtered_32-min_mean', 'Total cloud cover_% (instant)_lambert_level 0-filtered_32-min_max', 'Total cloud cover_% (instant)_lambert_level 0-filtered_32-min_min', 'Total cloud cover_% (instant)_lambert_level 0-filtered_32-min_var', 'Total cloud cover_% (instant)_lambert_level 0-filtered_24-max_mean', 'Total cloud cover_% (instant)_lambert_level 0-filtered_24-max_max', 'Total cloud cover_% (instant)_lambert_level 0-filtered_24-max_min', 'Total cloud cover_% (instant)_lambert_level 0-filtered_24-max_var', 'Total cloud cover_% (instant)_lambert_level 0_sum', 'Total cloud cover_% (instant)_lambert_level 0_mean', 'Total cloud cover_% (instant)_lambert_level 0_max', 'Total cloud cover_% (instant)_lambert_level 0_min', 'Total cloud cover_% (instant)_lambert_level 0-filtered_16-min_sum', 'Total cloud cover_% (instant)_lambert_level 0-filtered_16-min_mean', 'Total cloud cover_% (instant)_lambert_level 0-filtered_16-min_max', 'Total cloud cover_% (instant)_lambert_level 0-filtered_16-min_min', 'Total cloud cover_% (instant)_lambert_level 0-filtered_16-min_var', 'Total cloud cover_% (instant)_lambert_level 0-filtered_32-max_mean', 'Total cloud cover_% (instant)_lambert_level 0-filtered_32-max_max', 'Total cloud cover_% (instant)_lambert_level 0-filtered_32-max_min', 'Total cloud cover_% (instant)_lambert_level 0-filtered_32-max_var', 'Total cloud cover_% (instant)_lambert_level 0-filtered_8-mean_mean', 'Total cloud cover_% (instant)_lambert_level 0-filtered_8-mean_max', 'Total cloud cover_% (instant)_lambert_level 0-filtered_8-mean_min', 'Total cloud cover_% (instant)_lambert_level 0-filtered_8-mean_var', 'Total cloud cover_% (instant)_lambert_level 0-filtered_2-min_sum', 'Total cloud cover_% (instant)_lambert_level 0-filtered_2-min_mean', 'Total cloud cover_% (instant)_lambert_level 0-filtered_2-min_max', 'Total cloud cover_% (instant)_lambert_level 0-filtered_2-min_min', 'Total cloud cover_% (instant)_lambert_level 0-filtered_2-min_var', 'Total cloud cover_% (instant)_lambert_level 0-filtered_24-min_sum', 'Total cloud cover_% (instant)_lambert_level 0-filtered_24-min_mean', 'Total cloud cover_% (instant)_lambert_level 0-filtered_24-min_max', 'Total cloud cover_% (instant)_lambert_level 0-filtered_24-min_min', 'Total cloud cover_% (instant)_lambert_level 0-filtered_24-min_var', 'Total cloud cover_% (instant)_lambert_level 0-filtered_4-max_mean', 'Total cloud cover_% (instant)_lambert_level 0-filtered_4-max_max', 'Total cloud cover_% (instant)_lambert_level 0-filtered_4-max_min', 'Total cloud cover_% (instant)_lambert_level 0-filtered_4-max_var', 'Total cloud cover_% (instant)_lambert_level 0-filtered_32-mean_sum', 'Total cloud cover_% (instant)_lambert_level 0-filtered_32-mean_mean', 'Total cloud cover_% (instant)_lambert_level 0-filtered_32-mean_max', 'Total cloud cover_% (instant)_lambert_level 0-filtered_32-mean_min', 'Total cloud cover_% (instant)_lambert_level 0-filtered_32-mean_var', 'Total cloud cover_% (instant)_lambert_level 0-filtered_4-mean_sum', 'Total cloud cover_% (instant)_lambert_level 0-filtered_4-mean_mean', 'Total cloud cover_% (instant)_lambert_level 0-filtered_4-mean_max', 'Total cloud cover_% (instant)_lambert_level 0-filtered_4-mean_min', 'Total cloud cover_% (instant)_lambert_level 0-filtered_4-mean_var', 'Total cloud cover_% (instant)_lambert_level 0-filtered_2-mean_sum', 'Total cloud cover_% (instant)_lambert_level 0-filtered_2-mean_mean', 'Total cloud cover_% (instant)_lambert_level 0-filtered_2-mean_max', 'Total cloud cover_% (instant)_lamber ...
# Group 28: ['2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_2-max_sum', '2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_2-max_mean', '2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_2-max_max', '2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_2-max_min', '2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_2-max_var', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_32-max_sum', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_32-max_mean', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_32-max_max', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_32-max_min', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_32-max_var', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-mean_sum', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-mean_mean', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-mean_max', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-mean_min', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-mean_var', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_2-max_sum', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_2-max_mean', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_2-max_max', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_2-max_min', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_2-max_var', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_24-min_sum', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_24-min_mean', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_24-min_max', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_24-min_min', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_24-min_var', '2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_24-min_sum', '2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_24-min_mean', '2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_24-min_max', '2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_24-min_min', '2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_24-min_var', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-min_sum', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-min_mean', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-min_max', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-min_min', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-min_var', '2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_32-min_sum', '2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_32-min_mean', '2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_32-min_max', '2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_32-min_min', '2 metre dewpoint temperature_K (instant)_lambert_level 2 m-filtered_32-min_var', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_8-mean_sum', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_8-mean_mean', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_8-mean_max', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_8-mean_min', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_8-mean_var', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_4-min_sum', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_4-min_mean', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_4-min_max', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_4-min_min', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_4-min_var', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_8-max_sum', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_8-max_mean', '2 metre temperature_K (instant)_lambert_level 2 m-filtered ...
# Group 29: ['Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_8-mean_sum', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_8-mean_mean', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_8-mean_max', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_8-mean_min', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_8-mean_var', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_4-min_sum', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_4-min_mean', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_4-min_max', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_4-min_min', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_4-min_var', 'Total precipitation_kg m-2 (accum)_lambert_level 0_sum', 'Total precipitation_kg m-2 (accum)_lambert_level 0_mean', 'Total precipitation_kg m-2 (accum)_lambert_level 0_max', 'Total precipitation_kg m-2 (accum)_lambert_level 0_min', 'Total precipitation_kg m-2 (accum)_lambert_level 0_var', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_4-mean_sum', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_4-mean_mean', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_4-mean_max', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_4-mean_min', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_4-mean_var', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_2-mean_sum', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_2-mean_mean', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_2-mean_max', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_2-mean_min', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_2-mean_var', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_24-mean_sum', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_24-mean_mean', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_24-mean_max', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_24-mean_min', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_24-mean_var', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_32-min_sum', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_32-min_mean', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_32-min_max', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_32-min_min', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_32-min_var', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_32-max_sum', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_32-max_mean', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_32-max_max', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_32-max_min', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_32-max_var', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_8-min_sum', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_8-min_mean', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_8-min_max', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_8-min_min', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_8-min_var', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_16-max_sum', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_16-max_mean', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_16-max_max', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_16-max_min', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_16-max_var', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_16-mean_sum', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_16-mean_mean', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_16-mean_max', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_16-mean_min', 'Total precipitation_kg m-2 (accum)_lambert_level 0-filtered_16 ...
# Group 30: ['0_0 (instant)_lambert_level 0-filtered_16-max_var', '0_0 (instant)_lambert_level 0-filtered_2-min_var', '0_0 (instant)_lambert_level 0-filtered_24-max_var', '0_0 (instant)_lambert_level 0-filtered_4-max_var', '0_0 (instant)_lambert_level 0-filtered_8-mean_var', 'Surface pressure_Pa (instant)_lambert_level 0-filtered_16-max_var', '0_0 (instant)_lambert_level 0_max', '0_0 (instant)_lambert_level 0_var', '0_0 (instant)_lambert_level 0-filtered_8-min_max', '0_0 (instant)_lambert_level 0-filtered_8-min_min', '0_0 (instant)_lambert_level 0-filtered_8-min_var', 'Hail_m (max)_lambert_level 0 10-filtered_16-max_var', '0_0 (instant)_lambert_level 0-filtered_4-min_max', '0_0 (instant)_lambert_level 0-filtered_4-min_min', '0_0 (instant)_lambert_level 0-filtered_4-min_var', '0_0 (instant)_lambert_level 0-filtered_32-min_max', '0_0 (instant)_lambert_level 0-filtered_32-min_min', '0_0 (instant)_lambert_level 0-filtered_32-min_var', '0_0 (instant)_lambert_level 0-filtered_2-max_var', '0_0 (instant)_lambert_level 0-filtered_16-mean_var', '0_0 (instant)_lambert_level 0-filtered_4-mean_var', '0_0 (instant)_lambert_level 0-filtered_24-min_max', '0_0 (instant)_lambert_level 0-filtered_24-min_min', '0_0 (instant)_lambert_level 0-filtered_24-min_var', '0_0 (instant)_lambert_level 0-filtered_16-min_max', '0_0 (instant)_lambert_level 0-filtered_16-min_min', '0_0 (instant)_lambert_level 0-filtered_16-min_var', '0_0 (instant)_lambert_level 0-filtered_32-max_var']
# ...
# Group 49: ['Hail_m (max)_lambert_level 0_sum', 'Hail_m (max)_lambert_level 0_mean', 'Hail_m (max)_lambert_level 0_max', 'Hail_m (max)_lambert_level 0_min', 'Hail_m (max)_lambert_level 0_var', '4_4 (max)_lambert_level 0_sum', '4_4 (max)_lambert_level 0_mean', '4_4 (max)_lambert_level 0_max', '4_4 (max)_lambert_level 0_min', 'Hail_m (max)_lambert_level 0 10_mean', 'Hail_m (max)_lambert_level 0 10_min', 'Hail_m (max)_lambert_level 0 10_var', '74_74 (max)_lambert_level 0 200_sum']
# Group 50: ['Snow depth_m (instant)_lambert_level 0_mean', 'Snow depth_m (instant)_lambert_level 0_min', 'Snow depth_m (instant)_lambert_level 0_var', '0_0 (instant)_lambert_level 0_mean']
# Group 51: ['Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_24-max_sum', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_24-max_mean', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_24-max_max', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_24-max_min', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_24-max_var', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_8-mean_sum', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_8-mean_mean', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_8-mean_max', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_8-mean_min', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_8-mean_var', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_16-min_sum', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_16-min_mean', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_16-min_max', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_16-min_min', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_16-min_var', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_32-mean_sum', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_32-mean_mean', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_32-mean_max', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_32-mean_min', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_32-mean_var', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_8-max_sum', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_8-max_mean', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_8-max_max', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_8-max_min', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_8-max_var', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_2-mean_sum', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_2-mean_mean', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_2-mean_max', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_2-mean_min', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_2-mean_var', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_8-min_sum', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_8-min_mean', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_8-min_max', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_8-min_min', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_8-min_var', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_24-min_sum', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_24-min_mean', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_24-min_max', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_24-min_min', 'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered ...
# Group 52: ['Total cloud cover_% (instant)_lambert_level 0_var']
# Group 53: ['4_4 (max)_lambert_level 0_var', '74_74 (max)_lambert_level 0 200_mean', '74_74 (max)_lambert_level 0 200_max', '74_74 (max)_lambert_level 0 200_min', '74_74 (max)_lambert_level 0 200_var']
# Group 54: ['GUST_FORCE N-filtered_16-mean_max', 'GUST_FORCE N-filtered_16-mean_var', 'GUST_FORCE N-filtered_16-min_var', 'GUST_FORCE N-filtered_4-min_var', 'GUST_FORCE N-filtered_8-min_var']
# Group 55: ['0_0 (instant)_lambert_level 0_sum', '0_0 (instant)_lambert_level 0_min']
# Group 56: ['GUST_FORCE N_sum', 'GUST_FORCE N_mean', 'GUST_FORCE N_max', 'GUST_FORCE N_min', 'GUST_FORCE N_var']
# Group 57: ['2 metre temperature_K (instant)_lambert_level 2 m_mean', '2 metre temperature_K (instant)_lambert_level 2 m_min', '2 metre temperature_K (instant)_lambert_level 2 m_var', '2 metre temperature_K (instant)_lambert_level 2 m_3_hour_variation_min', '2 metre temperature_K (instant)_lambert_level 2 m_3_hour_variation_max']
# Group 58: ['199_199 (max)_lambert_levels 5000-2000 m_mean', '199_199 (max)_lambert_levels 5000-2000 m_min', '199_199 (max)_lambert_levels 5000-2000 m_var']
# Group 59: ['Total column integrated water vapour_kg m**-2 (instant)_lambert_level 0_sum', 'Total column integrated water vapour_kg m**-2 (instant)_lambert_level 0_mean', 'Total column integrated water vapour_kg m**-2 (instant)_lambert_level 0_max', 'Total column integrated water vapour_kg m**-2 (instant)_lambert_level 0_min', 'Total column integrated water vapour_kg m**-2 (instant)_lambert_level 0_var']
# Group 60: ['Convective inhibition_J kg-1 (instant)_lambert_level 0_mean', 'Convective inhibition_J kg-1 (instant)_lambert_level 0_max', 'Convective inhibition_J kg-1 (instant)_lambert_level 0_var', 'Convective inhibition_J kg-1 (instant)_lambert_level 0_3_hour_variation_min', 'Convective inhibition_J kg-1 (instant)_lambert_level 0_3_hour_variation_max']
# Group 61: ['Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_16-max_3_hour_variation_min', 'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_16-max_3_hour_variation_max', 'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_16-mean_3_hour_variation_min', 'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_16-mean_3_hour_variation_max', 'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_4-max_3_hour_variation_min', 'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_32-max_3_hour_variation_min', 'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_24-mean_3_hour_variation_min', 'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_24-max_3_hour_variation_min', 'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_8-max_3_hour_variation_min', 'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_2-max_3_hour_variation_min', 'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_4-mean_3_hour_variation_min', 'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_2-mean_3_hour_variation_min', 'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_32-mean_3_hour_variation_min', 'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_8-mean_3_hour_variation_min', 'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_8-mean_3_hour_variation_max']
# Group 62: ['2 metre temperature_K (instant)_lambert_level 2 m-filtered_2-min_3_hour_variation_max', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-mean_3_hour_variation_min', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-mean_3_hour_variation_max', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_2-mean_3_hour_variation_max', '2 metre dewpoint temperature_K (instant)_lambert_level 2 m_3_hour_variation_min', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_24-min_3_hour_variation_min', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_24-min_3_hour_variation_max', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-min_3_hour_variation_min', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-min_3_hour_variation_max', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_8-mean_3_hour_variation_min', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_8-mean_3_hour_variation_max', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_4-min_3_hour_variation_min', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_4-min_3_hour_variation_max', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_32-mean_3_hour_variation_max', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_4-mean_3_hour_variation_min', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_4-mean_3_hour_variation_max', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_24-mean_3_hour_variation_max', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_8-min_3_hour_variation_min', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_8-min_3_hour_variation_max', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_32-min_3_hour_variation_min', '2 metre temperature_K (instant)_lambert_level 2 m-filtered_32-min_3_hour_variation_max']
# Group 63: ['2 metre relative humidity_% (instant)_lambert_level 2 m_3_hour_variation_min']
# Group 64: ['Surface pressure_Pa (instant)_lambert_level 0_3_hour_variation_min', 'Surface pressure_Pa (instant)_lambert_level 0_3_hour_variation_max']
# Group 65: ['Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa_3_hour_variation_min']
# Group 66: ['(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max-20)^2', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-0)^1', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-0)^2', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-10)^1', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-10)^2', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-20)^1', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-20)^2', '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max-20)^2', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max-0)^1', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max-0)^2', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max-10)^1', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max-10)^2', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max-20)^1', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max-20)^2', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-0)^1', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-0)^2', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-10)^1', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-10)^2', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-20)^1', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-20)^2', '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-min-0)^2', '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-min-5)^2', '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-min-20)^2', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-0)^1', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-0)^2', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-10)^1', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-10)^2', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-15)^2', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-20)^1', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-20)^2', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-max-0)^1', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-max-0)^2', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-max-10)^1', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-max-10)^2', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-max-20)^1', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-max-20)^2', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-min-0)^1', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-min-0)^2', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-min-10)^1', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-min-10)^2', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-min-20)^1', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-min-20)^2', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-max-10)^1', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-max-10)^2', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-max-20)^1', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-max-20)^2', '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-0)^2', '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-5)^2', '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-20)^2', '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-min-20)^2', '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-10) ...
# Group 67: ['(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-15)^1', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-15)^1', '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-15)^1']
# Group 68: ['lat']
# Group 69: ['lon']
# Group 70: ['LU_11_30', 'LU_21_30', 'LU_31_30', 'LU_41_30', 'LU_71_30', 'LU_81_30', 'LU_11_60']
# Group 71: ['LU_22_30', 'LU_23_30', 'LU_24_30', 'LU_42_30', 'LU_52_30', 'LU_82_30', 'LU_22_60']
# Group 72: ['LU_43_30', 'LU_43_60']
# Group 73: ['LU_90_30', 'LU_95_30', 'LU_90_60']
# Group 74: ['LU_21_60', 'LU_23_60', 'LU_24_60', 'LU_31_60', 'LU_41_60', 'LU_42_60', 'LU_52_60', 'LU_71_60', 'LU_81_60', 'LU_82_60']
# Group 75: ['LU_95_60']
# Group 76: ['canopy_25th_30', 'canopy_75th_30', 'canopy_25th_60', 'canopy_75th_60']
# Group 77: ['canopy_interval_0_0_30', 'canopy_interval_11_20_30', 'canopy_interval_1_10_30', 'canopy_interval_21_30_30', 'canopy_interval_31_40_30', 'canopy_interval_41_50_30', 'canopy_interval_51_60_30', 'canopy_interval_61_70_30', 'canopy_interval_71_80_30', 'canopy_interval_81_90_30', 'canopy_interval_91_100_30', 'canopy_interval_0_0_60', 'canopy_interval_11_20_60', 'canopy_interval_1_10_60', 'canopy_interval_21_30_60', 'canopy_interval_31_40_60', 'canopy_interval_41_50_60', 'canopy_interval_51_60_60', 'canopy_interval_61_70_60', 'canopy_interval_71_80_60', 'canopy_interval_81_90_60', 'canopy_interval_91_100_60']
# Group 78: ['canopy_mean_30', 'canopy_median_30', 'canopy_var_30', 'canopy_mean_60', 'canopy_median_60']
# Group 79: ['canopy_var_60']
# Group 80: ['length_proxy_30', 'length_proxy_60']
# Group 81: ['line_length_30', 'line_length_60']

# %%
groups
# Out:
# [['0'],
#  ['breaker_counts'],
#  ['fuse_counts'],
#  ['switch_counts'],
#  ['transformer_counts'],
#  ['recloser_counts'],
#  ['pole_counts'],
#  ['poly_ewkt'],
#  ['point_ewkt'],
#  ['grid_id'],
#  ['outage_count'],
#  ['SimStartDate'],
#  ['outage_start_time'],
#  ['outage_end_time'],
#  ['weather_start_time'],
#  ['weather_end_time'],
#  ['event_type'],
#  ['x'],
#  ['y'],
#  ['10 metre wind speed_m s**-1 (max)_lambert_level 10 m_cogt_5',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m_cogt_9',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m_cogt_13',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m_cogt_18',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m_gt_5',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m_gt_9',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m_gt_13',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m_gt_18',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m_gt_35',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max_var',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean_var',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean_var',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean_var',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min_var',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean_var',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean_var',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min_var',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-min_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-min_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-min_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-min_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-min_var',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-min_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-min_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-min_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-min_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-min_var',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-max_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-max_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-max_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-max_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-max_var',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-max_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-max_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-max_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-max_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-max_var',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m_var',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-min_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-min_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-min_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-min_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-min_var',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-min_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-min_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-min_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-min_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-min_var',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-max_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-max_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-max_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-max_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-max_var',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean_var',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max_var',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-max_sum',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-max_mean',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-max_max',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-max_min',
#   '10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-max_var',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-15)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-15)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max-15)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max-15)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-15)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-15)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-max-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-max-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-max-15)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-max-15)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-min-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-min-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-min-15)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-min-15)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-15)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-15)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-max-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-max-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-max-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-max-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-max-15)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-max-15)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min-15)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min-15)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-min-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-min-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-min-15)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-min-15)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-min-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-min-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-min-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-min-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-min-15)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-min-15)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-max-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-max-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-max-15)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-max-15)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-min-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-min-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-min-15)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-min-15)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-max-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-max-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-max-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-max-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-max-15)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-max-15)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max-15)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max-15)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-15)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-15)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min-5)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min-5)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min-15)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min-15)^2'],
#  ['Wind speed (gust)_m s**-1 (max)_lambert_level 10 m_gt_13',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m_gt_17',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m_gt_22',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m_gt_27',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m_gt_44',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max_var',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-min_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-min_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-min_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-min_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-min_var',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max_var',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean_var',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-min_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-min_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-min_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-min_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-min_var',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-min_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-min_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-min_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-min_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-min_var',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-min_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-min_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-min_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-min_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-min_var',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-max_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-max_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-max_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-max_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-max_var',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-mean_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-mean_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-mean_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-mean_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-mean_var',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-mean_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-mean_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-mean_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-mean_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-mean_var',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-max_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-max_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-max_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-max_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-max_var',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-max_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-max_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-max_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-max_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-max_var',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-mean_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-mean_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-mean_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-mean_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-mean_var',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-mean_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-mean_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-mean_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-mean_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-mean_var',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m_var',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-mean_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-mean_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-mean_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-mean_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-mean_var',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-min_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-min_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-min_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-min_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-min_var',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-min_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-min_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-min_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-min_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-min_var',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-max_sum',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-max_mean',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-max_max',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-max_min',
#   'Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-max_var',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-20)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-20)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max-20)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max-20)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-max-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-max-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-max-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-max-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-max-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-max-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-max-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-max-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-max-20)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-max-20)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-min-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-min-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-min-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-min-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-min-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-min-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-min-20)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-20)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-max-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-max-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-max-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-max-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-max-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-max-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-max-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-max-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-max-20)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-max-20)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-min-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-min-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-min-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-min-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-min-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-min-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-min-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-min-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-min-20)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-min-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-min-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-min-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-min-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-min-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-min-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-min-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-min-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-min-20)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-min-20)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-min-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-min-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-min-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-min-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-min-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-min-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-min-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-min-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-min-20)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-min-20)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-max-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-max-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-max-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-max-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-max-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-max-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-max-20)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-20)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-20)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-20)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-max-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-max-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-max-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-max-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-max-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-max-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-max-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-max-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-max-20)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-min-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-min-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-min-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-min-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-min-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-min-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-min-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-min-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-min-20)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-min-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-min-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-min-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-min-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-min-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-min-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-min-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-min-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-min-20)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-0)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-5)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-20)^1'],
#  ['221_221 (min)_lambert_levels 0-40000-filtered_2-mean_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_2-mean_mean',
#   '221_221 (min)_lambert_levels 0-40000-filtered_2-mean_max',
#   '221_221 (min)_lambert_levels 0-40000-filtered_2-mean_min',
#   '221_221 (min)_lambert_levels 0-40000-filtered_2-mean_var',
#   '4_4 (max)_lambert_level 0-filtered_2-mean_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_16-max_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_16-max_mean',
#   '220_220 (max)_lambert_levels 0-40000-filtered_16-max_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_16-max_min',
#   '220_220 (max)_lambert_levels 0-40000-filtered_16-max_var',
#   '221_221 (min)_lambert_levels 0-40000-filtered_32-mean_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_32-mean_mean',
#   '221_221 (min)_lambert_levels 0-40000-filtered_32-mean_max',
#   '221_221 (min)_lambert_levels 0-40000-filtered_32-mean_min',
#   '221_221 (min)_lambert_levels 0-40000-filtered_32-mean_var',
#   '220_220 (max)_lambert_levels 0-40000-filtered_2-min_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_2-min_mean',
#   '220_220 (max)_lambert_levels 0-40000-filtered_2-min_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_2-min_min',
#   '220_220 (max)_lambert_levels 0-40000-filtered_2-min_var',
#   '220_220 (max)_lambert_levels 0-40000-filtered_4-max_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_4-max_mean',
#   '220_220 (max)_lambert_levels 0-40000-filtered_4-max_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_4-max_min',
#   '220_220 (max)_lambert_levels 0-40000-filtered_4-max_var',
#   '221_221 (min)_lambert_levels 0-40000-filtered_2-max_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_2-max_mean',
#   '221_221 (min)_lambert_levels 0-40000-filtered_2-max_max',
#   '221_221 (min)_lambert_levels 0-40000-filtered_2-max_min',
#   '221_221 (min)_lambert_levels 0-40000-filtered_2-max_var',
#   '221_221 (min)_lambert_levels 0-40000-filtered_8-max_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_8-max_mean',
#   '221_221 (min)_lambert_levels 0-40000-filtered_8-max_max',
#   '221_221 (min)_lambert_levels 0-40000-filtered_8-max_min',
#   '221_221 (min)_lambert_levels 0-40000-filtered_8-max_var',
#   '220_220 (max)_lambert_levels 0-40000-filtered_24-max_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_24-max_mean',
#   '220_220 (max)_lambert_levels 0-40000-filtered_24-max_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_24-max_min',
#   '220_220 (max)_lambert_levels 0-40000-filtered_24-max_var',
#   '4_4 (max)_lambert_level 0-filtered_24-mean_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_32-max_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_32-max_mean',
#   '221_221 (min)_lambert_levels 0-40000-filtered_32-max_max',
#   '221_221 (min)_lambert_levels 0-40000-filtered_32-max_min',
#   '221_221 (min)_lambert_levels 0-40000-filtered_32-max_var',
#   '220_220 (max)_lambert_levels 0-40000-filtered_8-min_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_8-min_mean',
#   '220_220 (max)_lambert_levels 0-40000-filtered_8-min_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_8-min_min',
#   '220_220 (max)_lambert_levels 0-40000-filtered_8-min_var',
#   '221_221 (min)_lambert_levels 0-40000-filtered_16-min_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_16-min_mean',
#   '221_221 (min)_lambert_levels 0-40000-filtered_16-min_max',
#   '221_221 (min)_lambert_levels 0-40000-filtered_16-min_min',
#   '221_221 (min)_lambert_levels 0-40000-filtered_16-min_var',
#   '4_4 (max)_lambert_level 0-filtered_32-mean_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_32-min_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_32-min_mean',
#   '220_220 (max)_lambert_levels 0-40000-filtered_32-min_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_32-min_min',
#   '220_220 (max)_lambert_levels 0-40000-filtered_32-min_var',
#   '221_221 (min)_lambert_levels 0-40000-filtered_24-mean_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_24-mean_mean',
#   '221_221 (min)_lambert_levels 0-40000-filtered_24-mean_max',
#   '221_221 (min)_lambert_levels 0-40000-filtered_24-mean_min',
#   '221_221 (min)_lambert_levels 0-40000-filtered_24-mean_var',
#   '221_221 (min)_lambert_levels 0-40000-filtered_8-min_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_8-min_mean',
#   '221_221 (min)_lambert_levels 0-40000-filtered_8-min_max',
#   '221_221 (min)_lambert_levels 0-40000-filtered_8-min_min',
#   '221_221 (min)_lambert_levels 0-40000-filtered_8-min_var',
#   '220_220 (max)_lambert_levels 0-40000-filtered_32-mean_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_32-mean_mean',
#   '220_220 (max)_lambert_levels 0-40000-filtered_32-mean_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_32-mean_min',
#   '220_220 (max)_lambert_levels 0-40000-filtered_32-mean_var',
#   '220_220 (max)_lambert_levels 0-40000-filtered_16-mean_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_16-mean_mean',
#   '220_220 (max)_lambert_levels 0-40000-filtered_16-mean_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_16-mean_min',
#   '220_220 (max)_lambert_levels 0-40000-filtered_16-mean_var',
#   '220_220 (max)_lambert_levels 0-40000-filtered_2-max_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_2-max_mean',
#   '220_220 (max)_lambert_levels 0-40000-filtered_2-max_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_2-max_min',
#   '220_220 (max)_lambert_levels 0-40000-filtered_2-max_var',
#   '221_221 (min)_lambert_levels 0-40000-filtered_8-mean_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_8-mean_mean',
#   '221_221 (min)_lambert_levels 0-40000-filtered_8-mean_max',
#   '221_221 (min)_lambert_levels 0-40000-filtered_8-mean_min',
#   '221_221 (min)_lambert_levels 0-40000-filtered_8-mean_var',
#   '221_221 (min)_lambert_levels 0-40000-filtered_4-mean_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_4-mean_mean',
#   '221_221 (min)_lambert_levels 0-40000-filtered_4-mean_max',
#   '221_221 (min)_lambert_levels 0-40000-filtered_4-mean_min',
#   '221_221 (min)_lambert_levels 0-40000-filtered_4-mean_var',
#   '221_221 (min)_lambert_levels 0-40000-filtered_24-max_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_24-max_mean',
#   '221_221 (min)_lambert_levels 0-40000-filtered_24-max_max',
#   '221_221 (min)_lambert_levels 0-40000-filtered_24-max_min',
#   '221_221 (min)_lambert_levels 0-40000-filtered_24-max_var',
#   '220_220 (max)_lambert_levels 0-40000-filtered_4-min_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_4-min_mean',
#   '220_220 (max)_lambert_levels 0-40000-filtered_4-min_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_4-min_min',
#   '220_220 (max)_lambert_levels 0-40000-filtered_4-min_var',
#   '221_221 (min)_lambert_levels 0-40000-filtered_16-max_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_16-max_mean',
#   '221_221 (min)_lambert_levels 0-40000-filtered_16-max_max',
#   '221_221 (min)_lambert_levels 0-40000-filtered_16-max_min',
#   '221_221 (min)_lambert_levels 0-40000-filtered_16-max_var',
#   '74_74 (max)_lambert_level 0 200-filtered_2-mean_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_16-mean_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_16-mean_mean',
#   '221_221 (min)_lambert_levels 0-40000-filtered_16-mean_max',
#   '221_221 (min)_lambert_levels 0-40000-filtered_16-mean_min',
#   '221_221 (min)_lambert_levels 0-40000-filtered_16-mean_var',
#   '221_221 (min)_lambert_levels 0-40000-filtered_4-min_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_4-min_mean',
#   '221_221 (min)_lambert_levels 0-40000-filtered_4-min_max',
#   '221_221 (min)_lambert_levels 0-40000-filtered_4-min_min',
#   '221_221 (min)_lambert_levels 0-40000-filtered_4-min_var',
#   '221_221 (min)_lambert_levels 0-40000_sum',
#   '221_221 (min)_lambert_levels 0-40000_mean',
#   '221_221 (min)_lambert_levels 0-40000_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_32-max_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_32-max_mean',
#   '220_220 (max)_lambert_levels 0-40000-filtered_32-max_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_32-max_min',
#   '220_220 (max)_lambert_levels 0-40000-filtered_32-max_var',
#   '199_199 (max)_lambert_levels 5000-2000 m-filtered_24-mean_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_8-max_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_8-max_mean',
#   '220_220 (max)_lambert_levels 0-40000-filtered_8-max_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_8-max_min',
#   '220_220 (max)_lambert_levels 0-40000-filtered_8-max_var',
#   '220_220 (max)_lambert_levels 0-40000-filtered_16-min_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_16-min_mean',
#   '220_220 (max)_lambert_levels 0-40000-filtered_16-min_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_16-min_min',
#   '220_220 (max)_lambert_levels 0-40000-filtered_16-min_var',
#   '221_221 (min)_lambert_levels 0-40000-filtered_4-max_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_4-max_mean',
#   '221_221 (min)_lambert_levels 0-40000-filtered_4-max_max',
#   '221_221 (min)_lambert_levels 0-40000-filtered_4-max_min',
#   '221_221 (min)_lambert_levels 0-40000-filtered_4-max_var',
#   '220_220 (max)_lambert_levels 0-40000-filtered_8-mean_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_8-mean_mean',
#   '220_220 (max)_lambert_levels 0-40000-filtered_8-mean_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_8-mean_min',
#   '220_220 (max)_lambert_levels 0-40000-filtered_8-mean_var',
#   '199_199 (max)_lambert_levels 5000-2000 m-filtered_32-mean_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_32-min_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_32-min_mean',
#   '221_221 (min)_lambert_levels 0-40000-filtered_32-min_max',
#   '221_221 (min)_lambert_levels 0-40000-filtered_32-min_min',
#   '221_221 (min)_lambert_levels 0-40000-filtered_32-min_var',
#   '220_220 (max)_lambert_levels 0-40000-filtered_24-mean_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_24-mean_mean',
#   '220_220 (max)_lambert_levels 0-40000-filtered_24-mean_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_24-mean_min',
#   '220_220 (max)_lambert_levels 0-40000-filtered_24-mean_var',
#   '220_220 (max)_lambert_levels 0-40000-filtered_2-mean_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_2-mean_mean',
#   '220_220 (max)_lambert_levels 0-40000-filtered_2-mean_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_2-mean_min',
#   '220_220 (max)_lambert_levels 0-40000-filtered_2-mean_var',
#   '220_220 (max)_lambert_levels 0-40000-filtered_24-min_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_24-min_mean',
#   '220_220 (max)_lambert_levels 0-40000-filtered_24-min_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_24-min_min',
#   '220_220 (max)_lambert_levels 0-40000-filtered_24-min_var',
#   '221_221 (min)_lambert_levels 0-40000-filtered_24-min_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_24-min_mean',
#   '221_221 (min)_lambert_levels 0-40000-filtered_24-min_max',
#   '221_221 (min)_lambert_levels 0-40000-filtered_24-min_min',
#   '221_221 (min)_lambert_levels 0-40000-filtered_24-min_var',
#   '221_221 (min)_lambert_levels 0-40000-filtered_2-min_sum',
#   '221_221 (min)_lambert_levels 0-40000-filtered_2-min_mean',
#   '221_221 (min)_lambert_levels 0-40000-filtered_2-min_max',
#   '221_221 (min)_lambert_levels 0-40000-filtered_2-min_min',
#   '221_221 (min)_lambert_levels 0-40000-filtered_2-min_var',
#   '199_199 (max)_lambert_levels 5000-2000 m-filtered_2-mean_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_4-mean_sum',
#   '220_220 (max)_lambert_levels 0-40000-filtered_4-mean_mean',
#   '220_220 (max)_lambert_levels 0-40000-filtered_4-mean_max',
#   '220_220 (max)_lambert_levels 0-40000-filtered_4-mean_min',
#   '220_220 (max)_lambert_levels 0-40000-filtered_4-mean_var'],
#  ['HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-min_sum',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-min_mean',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-min_max',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-min_min',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-min_var',
#   'HOURLY_SNOW_ACCUM_RATE m/h-filtered_16-max_sum',
#   'HOURLY_SNOW_ACCUM_RATE m/h-filtered_16-max_mean',
#   'HOURLY_SNOW_ACCUM_RATE m/h-filtered_16-max_max',
#   'HOURLY_SNOW_ACCUM_RATE m/h-filtered_16-max_min',
#   'HOURLY_SNOW_ACCUM_RATE m/h-filtered_16-max_var',
#   'HOURLY_SNOW_ACCUM_RATE m/h-filtered_8-min_sum',
#   'HOURLY_SNOW_ACCUM_RATE m/h-filtered_8-min_mean',
#   'HOURLY_SNOW_ACCUM_RATE m/h-filtered_8-min_max',
#   'HOURLY_SNOW_ACCUM_RATE m/h-filtered_8-min_min',
#   'HOURLY_SNOW_ACCUM_RATE m/h-filtered_8-min_var',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_16-max_sum',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_16-max_mean',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_16-max_max',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_16-max_min',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_16-max_var',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_2-max_sum',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_2-max_mean',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_2-max_max',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_2-max_min',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_2-max_var',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h_sum',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h_min',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-max_sum',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-max_mean',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-max_max',
#   'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_8-max_min',
# ...
#   'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_16-max_3_hour_variation_max',
#   'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_16-mean_3_hour_variation_min',
#   'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_16-mean_3_hour_variation_max',
#   'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_4-max_3_hour_variation_min',
#   'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_32-max_3_hour_variation_min',
#   'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_24-mean_3_hour_variation_min',
#   'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_24-max_3_hour_variation_min',
#   'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_8-max_3_hour_variation_min',
#   'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_2-max_3_hour_variation_min',
#   'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_4-mean_3_hour_variation_min',
#   'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_2-mean_3_hour_variation_min',
#   'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_32-mean_3_hour_variation_min',
#   'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_8-mean_3_hour_variation_min',
#   'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_8-mean_3_hour_variation_max'],
#  ['2 metre temperature_K (instant)_lambert_level 2 m-filtered_2-min_3_hour_variation_max',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-mean_3_hour_variation_min',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-mean_3_hour_variation_max',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_2-mean_3_hour_variation_max',
#   '2 metre dewpoint temperature_K (instant)_lambert_level 2 m_3_hour_variation_min',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_24-min_3_hour_variation_min',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_24-min_3_hour_variation_max',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-min_3_hour_variation_min',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_16-min_3_hour_variation_max',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_8-mean_3_hour_variation_min',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_8-mean_3_hour_variation_max',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_4-min_3_hour_variation_min',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_4-min_3_hour_variation_max',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_32-mean_3_hour_variation_max',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_4-mean_3_hour_variation_min',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_4-mean_3_hour_variation_max',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_24-mean_3_hour_variation_max',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_8-min_3_hour_variation_min',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_8-min_3_hour_variation_max',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_32-min_3_hour_variation_min',
#   '2 metre temperature_K (instant)_lambert_level 2 m-filtered_32-min_3_hour_variation_max'],
#  ['2 metre relative humidity_% (instant)_lambert_level 2 m_3_hour_variation_min'],
#  ['Surface pressure_Pa (instant)_lambert_level 0_3_hour_variation_min',
#   'Surface pressure_Pa (instant)_lambert_level 0_3_hour_variation_max'],
#  ['Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa_3_hour_variation_min'],
#  ['(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-max-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-20)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-max-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-20)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-min-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-min-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-min-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-15)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-max-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-max-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-max-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-max-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-max-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-max-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-min-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-min-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-min-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-min-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-min-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-min-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-max-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-max-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-max-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-max-20)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-mean-20)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-min-20)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-20)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-20)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-max-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-max-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-max-20)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-min-20)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-max-20)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_8-min-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-min-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-min-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-min-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-min-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-min-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-min-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-min-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-min-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-min-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-min-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-max-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-max-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-max-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-max-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-max-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-max-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-min-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-min-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-min-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-min-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-min-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-min-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-max-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-max-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-max-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-max-20)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_4-min-20)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-10)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-10)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-15)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-15)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-20)^1',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_2-max-20)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-0)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-5)^2',
#   '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_2-mean-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_4-mean-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-15)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-0)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-0)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-15)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-20)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min-10)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min-10)^2',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min-20)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_8-min-20)^2'],
#  ['(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_16-mean-15)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-mean-15)^1',
#   '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-15)^1'],
#  ['lat'],
#  ['lon'],
#  ['LU_11_30',
#   'LU_21_30',
#   'LU_31_30',
#   'LU_41_30',
#   'LU_71_30',
#   'LU_81_30',
#   'LU_11_60'],
#  ['LU_22_30',
#   'LU_23_30',
#   'LU_24_30',
#   'LU_42_30',
#   'LU_52_30',
#   'LU_82_30',
#   'LU_22_60'],
#  ['LU_43_30', 'LU_43_60'],
#  ['LU_90_30', 'LU_95_30', 'LU_90_60'],
#  ['LU_21_60',
#   'LU_23_60',
#   'LU_24_60',
#   'LU_31_60',
#   'LU_41_60',
#   'LU_42_60',
#   'LU_52_60',
#   'LU_71_60',
#   'LU_81_60',
#   'LU_82_60'],
#  ['LU_95_60'],
#  ['canopy_25th_30', 'canopy_75th_30', 'canopy_25th_60', 'canopy_75th_60'],
#  ['canopy_interval_0_0_30',
#   'canopy_interval_11_20_30',
#   'canopy_interval_1_10_30',
#   'canopy_interval_21_30_30',
#   'canopy_interval_31_40_30',
#   'canopy_interval_41_50_30',
#   'canopy_interval_51_60_30',
#   'canopy_interval_61_70_30',
#   'canopy_interval_71_80_30',
#   'canopy_interval_81_90_30',
#   'canopy_interval_91_100_30',
#   'canopy_interval_0_0_60',
#   'canopy_interval_11_20_60',
#   'canopy_interval_1_10_60',
#   'canopy_interval_21_30_60',
#   'canopy_interval_31_40_60',
#   'canopy_interval_41_50_60',
#   'canopy_interval_51_60_60',
#   'canopy_interval_61_70_60',
#   'canopy_interval_71_80_60',
#   'canopy_interval_81_90_60',
#   'canopy_interval_91_100_60'],
#  ['canopy_mean_30',
#   'canopy_median_30',
#   'canopy_var_30',
#   'canopy_mean_60',
#   'canopy_median_60'],
#  ['canopy_var_60'],
#  ['length_proxy_30', 'length_proxy_60'],
#  ['line_length_30', 'line_length_60']]

# %%
# for every group of features select the one with best correlation with 'outage_count'

import math

selected_features = []
labels = data['outage_count'].copy()

for group in groups:
    if len(group) > 1:
        highest_corr = 0
        # print("Finding the best feature for group: ", key)
        for feat in group:
            #print("Calculating correlation for feature: ", feat)
            corr = labels.corr(data[feat])
            #print(feat, ': ', corr)
            if corr > highest_corr:
                highest_corr = corr
                selected_feature = feat

        print('Selected feature: ', selected_feature, ' with correlation: ', highest_corr)
        selected_features.append(selected_feature)
    else:
        print('Selected feature: ', group[0])
        selected_features.append(group[0])
    
display(selected_features)
# Out:
# Selected feature:  0
# Selected feature:  breaker_counts
# Selected feature:  fuse_counts
# Selected feature:  switch_counts
# Selected feature:  transformer_counts
# Selected feature:  recloser_counts
# Selected feature:  pole_counts
# Selected feature:  poly_ewkt
# Selected feature:  point_ewkt
# Selected feature:  grid_id
# Selected feature:  outage_count
# Selected feature:  SimStartDate
# Selected feature:  outage_start_time
# Selected feature:  outage_end_time
# Selected feature:  weather_start_time
# Selected feature:  weather_end_time
# Selected feature:  event_type
# Selected feature:  x
# Selected feature:  y
# Selected feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max-15)^1  with correlation:  0.15473662418296555
# Selected feature:  (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-max-15)^2  with correlation:  0.18967877249304627
# Selected feature:  220_220 (max)_lambert_levels 0-40000-filtered_32-max_min  with correlation:  0.103384155826812
# Selected feature:  HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_32-max_max  with correlation:  0.13864549069552812
# Selected feature:  AIR_DENSITY kg/m3-filtered_2-mean_var  with correlation:  0.05846121329843003
# Selected feature:  Snow depth_m (instant)_lambert_level 0-filtered_32-max_max  with correlation:  0.08813130967639567
# Selected feature:  4_4 (max)_lambert_level 0-filtered_2-mean_mean  with correlation:  0.10248649553315188
# Selected feature:  HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_32-max_max  with correlation:  0.13641526822820804
# Selected feature:  Total cloud cover_% (instant)_lambert_level 0-filtered_32-max_min  with correlation:  0.047404801004417074
# Selected feature:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_2-mean_var  with correlation:  0.062167055760448814
# Selected feature:  Total precipitation_kg m-2 (accum)_lambert_level 0_sum  with correlation:  0.07688416092553182
# Selected feature:  Surface pressure_Pa (instant)_lambert_level 0-filtered_16-max_var  with correlation:  0.09296251359224134
# Selected feature:  Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_8-max_3_hour_variation_max  with correlation:  0.04311815631922477
# Selected feature:  Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filtered_24-max_var  with correlation:  0.04926851845477252
# Selected feature:  Water equivalent of accumulated snow depth_kg m**-2 (instant)_lambert_level 0-filtered_32-max_max  with correlation:  0.07972819892723514
# Selected feature:  AIR_DENSITY kg/m3_var  with correlation:  0.06004428884802717
# Selected feature:  GUST_FORCE N-filtered_32-max_sum  with correlation:  0.1664320457486312
# Selected feature:  10 metre U wind component_m s**-1 (instant)_lambert_level 10 m-filtered_24-min_var  with correlation:  0.07861971247001295
# Selected feature:  Absolute vorticity_s**-1 (instant)_lambert_level 50000 Pa-filtered_16-max_mean  with correlation:  0.07771723118740581
# Selected feature:  Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_32-min_3_hour_variation_max  with correlation:  0.022184618104454188
# Selected feature:  Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_16-max_mean  with correlation:  0.08456517541087098
# Selected feature:  WIND_FORCE N-filtered_32-max_mean  with correlation:  0.12656894782537226
# Selected feature:  Surface pressure_Pa (instant)_lambert_level 0-filtered_8-max_var  with correlation:  0.09338207059127404
# Selected feature:  Surface pressure_Pa (instant)_lambert_level 0-filtered_8-max_var  with correlation:  0
# Selected feature:  HOURLY_WET_SNOW_ACCUM_RATE m/h_max  with correlation:  0.04371231201591452
# Selected feature:  199_199 (max)_lambert_levels 5000-2000 m-filtered_32-max_sum  with correlation:  0.05095097699271793
# Selected feature:  2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_2-max_var  with correlation:  0.09625178898761509
# Selected feature:  2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_2-max_var  with correlation:  0
# Selected feature:  220_220 (max)_lambert_levels 0-40000_sum  with correlation:  0.08334169523303174
# Selected feature:  WIND_FORCE N-filtered_16-max_var  with correlation:  0.09686361625517187
# Selected feature:  4_4 (max)_lambert_level 0_mean  with correlation:  0.10248539610405567
# Selected feature:  0_0 (instant)_lambert_level 0_mean  with correlation:  0.04977048975188625
# Selected feature:  Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_24-max_sum  with correlation:  0.14064384485479836
# Selected feature:  Total cloud cover_% (instant)_lambert_level 0_var
# Selected feature:  4_4 (max)_lambert_level 0_var  with correlation:  0.07489214694813692
# Selected feature:  GUST_FORCE N-filtered_16-mean_max  with correlation:  0.11006202036966996
# Selected feature:  0_0 (instant)_lambert_level 0_sum  with correlation:  0.04977048975188628
# Selected feature:  GUST_FORCE N_mean  with correlation:  0.1072656900317318
# Selected feature:  2 metre temperature_K (instant)_lambert_level 2 m_3_hour_variation_max  with correlation:  0.07642055168268647
# Selected feature:  199_199 (max)_lambert_levels 5000-2000 m_mean  with correlation:  0.025573246171701442
# Selected feature:  Total column integrated water vapour_kg m**-2 (instant)_lambert_level 0_var  with correlation:  0.01924344102355432
# Selected feature:  Convective inhibition_J kg-1 (instant)_lambert_level 0_3_hour_variation_max  with correlation:  0.034183565543284944
# Selected feature:  Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_16-max_3_hour_variation_max  with correlation:  0.04984680381169867
# Selected feature:  2 metre temperature_K (instant)_lambert_level 2 m-filtered_2-mean_3_hour_variation_max  with correlation:  0.07925119491625751
# Selected feature:  2 metre relative humidity_% (instant)_lambert_level 2 m_3_hour_variation_min
# Selected feature:  Surface pressure_Pa (instant)_lambert_level 0_3_hour_variation_max  with correlation:  0.06873754146672832
# Selected feature:  Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa_3_hour_variation_min
# Selected feature:  (Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-max-20)^2  with correlation:  0.17880257674048902
# Selected feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-15)^1  with correlation:  0.005752575019543953
# Selected feature:  lat
# Selected feature:  lon
# Selected feature:  (10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-15)^1  with correlation:  0
# Selected feature:  LU_23_30  with correlation:  0.16906159334322973
# Selected feature:  LU_23_30  with correlation:  0
# Selected feature:  LU_23_30  with correlation:  0
# Selected feature:  LU_23_60  with correlation:  0.18631902449635176
# Selected feature:  LU_95_60
# Selected feature:  LU_23_60  with correlation:  0
# Selected feature:  canopy_interval_11_20_60  with correlation:  0.1675290183343033
# Selected feature:  canopy_interval_11_20_60  with correlation:  0
# Selected feature:  canopy_var_60
# Selected feature:  length_proxy_30  with correlation:  0.3449743550547052
# Selected feature:  line_length_30  with correlation:  0.35189258758968606
# ['0',
#  'breaker_counts',
#  'fuse_counts',
#  'switch_counts',
#  'transformer_counts',
#  'recloser_counts',
#  'pole_counts',
#  'poly_ewkt',
#  'point_ewkt',
#  'grid_id',
#  'outage_count',
#  'SimStartDate',
#  'outage_start_time',
#  'outage_end_time',
#  'weather_start_time',
#  'weather_end_time',
#  'event_type',
#  'x',
#  'y',
#  '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max-15)^1',
#  '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-max-15)^2',
#  '220_220 (max)_lambert_levels 0-40000-filtered_32-max_min',
#  'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_32-max_max',
#  'AIR_DENSITY kg/m3-filtered_2-mean_var',
#  'Snow depth_m (instant)_lambert_level 0-filtered_32-max_max',
#  '4_4 (max)_lambert_level 0-filtered_2-mean_mean',
#  'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_32-max_max',
#  'Total cloud cover_% (instant)_lambert_level 0-filtered_32-max_min',
#  '2 metre temperature_K (instant)_lambert_level 2 m-filtered_2-mean_var',
#  'Total precipitation_kg m-2 (accum)_lambert_level 0_sum',
#  'Surface pressure_Pa (instant)_lambert_level 0-filtered_16-max_var',
#  'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_8-max_3_hour_variation_max',
#  'Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filtered_24-max_var',
#  'Water equivalent of accumulated snow depth_kg m**-2 (instant)_lambert_level 0-filtered_32-max_max',
#  'AIR_DENSITY kg/m3_var',
#  'GUST_FORCE N-filtered_32-max_sum',
#  '10 metre U wind component_m s**-1 (instant)_lambert_level 10 m-filtered_24-min_var',
#  'Absolute vorticity_s**-1 (instant)_lambert_level 50000 Pa-filtered_16-max_mean',
#  'Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_32-min_3_hour_variation_max',
#  'Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_16-max_mean',
#  'WIND_FORCE N-filtered_32-max_mean',
#  'Surface pressure_Pa (instant)_lambert_level 0-filtered_8-max_var',
#  'Surface pressure_Pa (instant)_lambert_level 0-filtered_8-max_var',
#  'HOURLY_WET_SNOW_ACCUM_RATE m/h_max',
#  '199_199 (max)_lambert_levels 5000-2000 m-filtered_32-max_sum',
#  '2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_2-max_var',
#  '2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_2-max_var',
#  '220_220 (max)_lambert_levels 0-40000_sum',
#  'WIND_FORCE N-filtered_16-max_var',
#  '4_4 (max)_lambert_level 0_mean',
#  '0_0 (instant)_lambert_level 0_mean',
#  'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_24-max_sum',
#  'Total cloud cover_% (instant)_lambert_level 0_var',
#  '4_4 (max)_lambert_level 0_var',
#  'GUST_FORCE N-filtered_16-mean_max',
#  '0_0 (instant)_lambert_level 0_sum',
#  'GUST_FORCE N_mean',
#  '2 metre temperature_K (instant)_lambert_level 2 m_3_hour_variation_max',
#  '199_199 (max)_lambert_levels 5000-2000 m_mean',
#  'Total column integrated water vapour_kg m**-2 (instant)_lambert_level 0_var',
#  'Convective inhibition_J kg-1 (instant)_lambert_level 0_3_hour_variation_max',
#  'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_16-max_3_hour_variation_max',
#  '2 metre temperature_K (instant)_lambert_level 2 m-filtered_2-mean_3_hour_variation_max',
#  '2 metre relative humidity_% (instant)_lambert_level 2 m_3_hour_variation_min',
#  'Surface pressure_Pa (instant)_lambert_level 0_3_hour_variation_max',
#  'Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa_3_hour_variation_min',
#  '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-max-20)^2',
#  '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-15)^1',
#  'lat',
#  'lon',
#  '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-15)^1',
#  'LU_23_30',
#  'LU_23_30',
#  'LU_23_30',
#  'LU_23_60',
#  'LU_95_60',
#  'LU_23_60',
#  'canopy_interval_11_20_60',
#  'canopy_interval_11_20_60',
#  'canopy_var_60',
#  'length_proxy_30',
#  'line_length_30']

# %%
print('Number of selected features: ', len(selected_features))
# Out:
# Number of selected features:  82

# %%
selected_features.remove('0')
selected_features.remove('point_ewkt')

# %%
selected_features
# Out:
# ['breaker_counts',
#  'fuse_counts',
#  'switch_counts',
#  'transformer_counts',
#  'recloser_counts',
#  'pole_counts',
#  'poly_ewkt',
#  'grid_id',
#  'outage_count',
#  'SimStartDate',
#  'outage_start_time',
#  'outage_end_time',
#  'weather_start_time',
#  'weather_end_time',
#  'event_type',
#  'x',
#  'y',
#  '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_32-max-15)^1',
#  '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_32-max-15)^2',
#  '220_220 (max)_lambert_levels 0-40000-filtered_32-max_min',
#  'HOURLY_WET_SNOW_ACCUM_RATE m/h-filtered_32-max_max',
#  'AIR_DENSITY kg/m3-filtered_2-mean_var',
#  'Snow depth_m (instant)_lambert_level 0-filtered_32-max_max',
#  '4_4 (max)_lambert_level 0-filtered_2-mean_mean',
#  'HOURLY_SNOW_DEPTH_WATER_EQUIV_ACCUM_RATE m-2/h-filtered_32-max_max',
#  'Total cloud cover_% (instant)_lambert_level 0-filtered_32-max_min',
#  '2 metre temperature_K (instant)_lambert_level 2 m-filtered_2-mean_var',
#  'Total precipitation_kg m-2 (accum)_lambert_level 0_sum',
#  'Surface pressure_Pa (instant)_lambert_level 0-filtered_16-max_var',
#  'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_8-max_3_hour_variation_max',
#  'Total column water (Vertically integrated total water (vapour + cloud water/ice))_kg m**-2 (instant)_lambert_level 0-filtered_24-max_var',
#  'Water equivalent of accumulated snow depth_kg m**-2 (instant)_lambert_level 0-filtered_32-max_max',
#  'AIR_DENSITY kg/m3_var',
#  'GUST_FORCE N-filtered_32-max_sum',
#  '10 metre U wind component_m s**-1 (instant)_lambert_level 10 m-filtered_24-min_var',
#  'Absolute vorticity_s**-1 (instant)_lambert_level 50000 Pa-filtered_16-max_mean',
#  'Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa-filtered_32-min_3_hour_variation_max',
#  'Total column-integrated condensate_kg m**-2 (instant)_lambert_level 0-filtered_16-max_mean',
#  'WIND_FORCE N-filtered_32-max_mean',
#  'Surface pressure_Pa (instant)_lambert_level 0-filtered_8-max_var',
#  'Surface pressure_Pa (instant)_lambert_level 0-filtered_8-max_var',
#  'HOURLY_WET_SNOW_ACCUM_RATE m/h_max',
#  '199_199 (max)_lambert_levels 5000-2000 m-filtered_32-max_sum',
#  '2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_2-max_var',
#  '2 metre relative humidity_% (instant)_lambert_level 2 m-filtered_2-max_var',
#  '220_220 (max)_lambert_levels 0-40000_sum',
#  'WIND_FORCE N-filtered_16-max_var',
#  '4_4 (max)_lambert_level 0_mean',
#  '0_0 (instant)_lambert_level 0_mean',
#  'Geometric vertical velocity_m s**-1 (avg)_lambert_levels 0.5-0.8 sigma value-filtered_24-max_sum',
#  'Total cloud cover_% (instant)_lambert_level 0_var',
#  '4_4 (max)_lambert_level 0_var',
#  'GUST_FORCE N-filtered_16-mean_max',
#  '0_0 (instant)_lambert_level 0_sum',
#  'GUST_FORCE N_mean',
#  '2 metre temperature_K (instant)_lambert_level 2 m_3_hour_variation_max',
#  '199_199 (max)_lambert_levels 5000-2000 m_mean',
#  'Total column integrated water vapour_kg m**-2 (instant)_lambert_level 0_var',
#  'Convective inhibition_J kg-1 (instant)_lambert_level 0_3_hour_variation_max',
#  'Convective inhibition_J kg-1 (instant)_lambert_level 0-filtered_16-max_3_hour_variation_max',
#  '2 metre temperature_K (instant)_lambert_level 2 m-filtered_2-mean_3_hour_variation_max',
#  '2 metre relative humidity_% (instant)_lambert_level 2 m_3_hour_variation_min',
#  'Surface pressure_Pa (instant)_lambert_level 0_3_hour_variation_max',
#  'Convective available potential energy_J kg-1 (instant)_lambert_levels 25500-0 Pa_3_hour_variation_min',
#  '(Wind speed (gust)_m s**-1 (max)_lambert_level 10 m-filtered_24-max-20)^2',
#  '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-15)^1',
#  'lat',
#  'lon',
#  '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-15)^1',
#  'LU_23_30',
#  'LU_23_30',
#  'LU_23_30',
#  'LU_23_60',
#  'LU_95_60',
#  'LU_23_60',
#  'canopy_interval_11_20_60',
#  'canopy_interval_11_20_60',
#  'canopy_var_60',
#  'length_proxy_30',
#  'line_length_30']

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt

alpha = 0.05

insignificant_cols = []
# Perform Pearson correlation test
for col in list(data[selected_features].select_dtypes(include = "float").columns):
    correlation_coefficient, p_value = stats.pearsonr(data[col], target)
    if p_value > alpha:
        insignificant_cols.append(col)

# %%
insignificant_cols
# Out:
# ['(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-15)^1',
#  '(10 metre wind speed_m s**-1 (max)_lambert_level 10 m-filtered_24-mean-15)^1']
